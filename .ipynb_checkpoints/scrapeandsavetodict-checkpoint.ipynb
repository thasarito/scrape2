# %%
from datetime import datetime
import requests
import numpy as np
import pandas as pd
import yaml
import re
from bs4 import BeautifulSoup
import wikitextparser as wtp
from ratelimit import rate_limited
from operator import *

def save_obj(obj, name ):
    import pickle
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
        
def load_obj(name ):
    import pickle
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
@rate_limited(1, 30)
def parseSquad(title):
    '''
    input: title of tournament
    output: dictionary of participants of that tournament
    '''
    headers = {
    'User-Agent': 'Data for Research',
    'From': 'terthasarit@live.com', 
    'Accept-Encoding': 'gzip'
    }
    titleurl = re.sub(' ', '%20', title)
    r = requests.get(url='http://liquipedia.net/dota2/api.php?action=parse&format=json&page=' + titleurl + '&prop=wikitext%7Ctext', headers=headers)
    json = r.json()
    wiki = json.get('parse').get('wikitext').get('*')
    wiki = re.sub('\n', '', wiki)
    parsed = wtp.parse(wiki)
    templates = parsed.templates
    squad = {}
    for t in templates:
        if str(t)[:11] == '{{TeamCard|':
            for ar in t.arguments:
                if (str(ar)[:5] == '|team'):
                    teamname = re.sub(r'\W+', '', ar.value).lower()
                    squad[teamname] = {}
                for i in range(1, 6):
                    if (str(ar)[:4] == '|p' + str(i) + '='):
                        squad[teamname]['pos' + str(i)] = re.sub(r'\W+', '', ar.value).lower()  
    return squad, json

# %%
def getEloDict(ifd):
    '''
    receive infomation dictionary of tournament and
    return elodict
    '''
    start = re.sub('/', '-', ifd['start'])
    end = re.sub('/', '-', ifd['end'])
    #rating of startdate from datdota and turn into list of dict
    urldat = 'http://www.datdota.com/api/ratings?date=' + start
    htmldat = requests.get(urldat)
    htmldat.encoding = 'utf-8'
    elo = BeautifulSoup(htmldat.text, "lxml")
    elodict = yaml.load(elo.text)
    startelolist = elodict['data']   
    #rating of enddate from datdota and turn into list of dict
    urldat = 'http://www.datdota.com/api/ratings?date=' + end
    htmldat = requests.get(urldat)
    htmldat.encoding = 'utf-8'
    elo = BeautifulSoup(htmldat.text, "lxml")
    elodict = yaml.load(elo.text)
    endelolist = elodict['data']
    return (startelolist, endelolist)

# %%
def compareAndPut(df, squad, ifd, startelodict, endelodict):
    for lqn, pdc in squad.items():
        try:
            teamName = comparedict[lqn]
        except KeyError:
            teamName = lqn
        j = 0
        for srt in startelodict:
            for ert in endelodict:
                if (teamName == re.sub(r'\W+', '', srt['teamName']).lower()) & (teamName == re.sub(r'\W+', '', ert['teamName']).lower()):
                    j += 1
                    for pos, id in pdc.items():
                        df = df.append({
                            'team': teamName,
                            'position': pos,
                            'id': id,
                            'tour': ifd['title'],
                            'prizeusd': ifd['prize'],
                            'start': ifd['start'],
                            'end': ifd['end'],
                            'startelo': srt['elo64']['current'],
                            'startglicko2mu': srt['glicko2']['mu'],
                            'startglicko2phi': srt['glicko2']['phi'],
                            'startglicko2rating': srt['glicko2']['rating'],
                            'endelo': ert['elo64']['current'],
                            'endglicko2mu': ert['glicko2']['mu'],
                            'endglicko2phi': ert['glicko2']['phi'],
                            'endglicko2rating': ert['glicko2']['rating']
                        }, ignore_index=True)
        if j == 0:
            for pos, id in pdc.items():
                if id == '':
                    continue
                else:
                    df = df.append({
                        'team': teamName,
                        'position': pos,
                        'id': id,
                        'tour': ifd['title'],
                        'prizeusd': ifd['prize'],
                        'start': ifd['start'],
                        'end': ifd['end'],
                        'startelo': np.nan,
                        'startglicko2mu': np.nan,
                        'startglicko2phi': np.nan,
                        'startglicko2rating': np.nan,
                        'endelo': np.nan,
                        'endglicko2mu': np.nan,
                        'endglicko2phi': np.nan,
                        'endglicko2rating': np.nan
                    }, ignore_index=True)
        
    return df

# %%
alltour = load_obj('/dict/touranddate')
comparedict = load_obj('/dict/lqtodat')

# %%
endti2 = '2012-09-02'
endti7 = '2017-08-02'

# %%
# %%time
errortitle = []
df = pd.DataFrame(columns=['team', 'position', 'id', 'tour', 'prizeusd', 'start', 'end',
                           'startelo', 'startglicko2mu', 'startglicko2phi', 'startglicko2rating', 'endelo', 'endglicko2mu', 'endglicko2phi', 'endglicko2rating'])
for turl, ifd in tourleft.items():
    try:
        if (pd.to_datetime(ifd['start']) > pd.to_datetime(endti2)) & (pd.to_datetime(ifd['end']) <= pd.to_datetime(endti7)):
            ptc, lqjson = parseSquad(turl)
            startelodict, endelodict = getEloDict(ifd)
            save_obj({'wikitext': lqjson, 'startelodict': startelodict, 'endelodict': endelodict}, re.sub(r'\W+', '', ifd['title']).lower() )
            df = compareAndPut(df, ptc, ifd, startelodict, endelodict)
    except:
        print(turl)
        errortitle = errortitle.append(turl)
# Out:
# Wall time: 34min 35s

# %%
turl
# Out:
# 'Dota 2 Radiant & Dire Cup/2015'

# %%
tourleft = alltour.copy()
for k, v in alltour.items():
    del tourleft[k]
    if k == 'Shanghai Dota 2 Open/1':
        break

# %%
for k, v in alltour.items():
    print(k)
# Out:
# The International/2011
# Electronic Sports World Cup 2011
# The Defense/Season 1
# DreamHack/2011/Winter
# Dota2 Star Championship
# Malaysia Invitational
# The Premier League/Season 1
# Dota2Replays Brawl
# Razer Dota 2 Tournament
# StarLadder/StarSeries/Season 1
# ProDOTA2 League/Season 1/Non Pro
# ProDOTA2 League/Season 1/Pro
# The Premier League/Season 2
# Gigabyte Dota 2 Masters
# GosuLeague/1
# StarLadder/StarSeries/Season 2
# GosuLeague/2
# DreamHack/2012/Summer
# The Defense/Season 2
# GosuLeague/3
# Alienware 2012 Battlegrounds
# Samsung European Encounter
# The International/2012
# WCG Asia 2012
# RaidCall Dota 2 League Season 1
# StarLadder/StarSeries/Season 3
# GosuLeague/4
# GosuLeague/4/Division 1
# The Premier League/Season 3
# G-1 Champions League Season 4
# Electronic Sports World Cup 2012
# GosuLeague/5
# GosuLeague/5/Division 1
# StarLadder/StarSeries/Season 4
# DreamHack/2012/Winter
# The Defense/Season 3
# World Cyber Games 2012
# Thor Open 2012
# RaidCall Dota 2 League Season 2
# ASUS Open 2012
# The Asia 2012
# G-League 2012 Season 2
# The Premier League/Season 4
# Pro Gamer League/2016/Summer
# The International/2016
# World Cyber Arena/2016/Europe Main Qualifier
# World Electronic Sports Games/2016/Middle East and Africa
# MPGL/Southeast Asian Championship
# Red Bull Heroicks
# Dota2 Professional League/Season 2/Secondary
# Shanghai Dota 2 Open/2
# Dota2 Professional League/Season 2/Top
# Mars Dota 2 League/2016
# World Cyber Arena/2016/Chinese Qualifiers/S3
# World Electronic Sports Games/2016/Europe CIS
# DreamLeague/Season 6/League Play
# Nanyang Dota 2 Championships/Cruise Cup/1
# Dota2 ACE/Provisional
# FACEIT/Invitational/1
# World Electronic Sports Games/2016/Americas
# ROG MASTERS/2016
# Northern Arena/2016/BEAT Invitational
# World Electronic Sports Games/2016/Asia Pacific
# World Cyber Arena/2016/America Qualifier
# The Summit/6
# DreamLeague/Season 6
# Boston Major/2016
# World Cyber Arena/2016
# China Top/2016
# ESL One/Genting/2017
# World Electronic Sports Games/2016
# Dota Pit League/Season 5
# Elimination Mode/3
# StarLadder/i-League StarSeries/Season 3
# Dota2 Professional League/Season 3/Top
# Dota 2 Asia Championships/2017
# Russian e-Sports Cup/2017
# Kiev Major/2017
# Mr. Cat Invitational/Europe
# DreamLeague/Season 7/EU Division
# StarLadder/i-League Invitational/2
# The Masters/2017/Manila
# DreamLeague/Season 7/NA Division
# ZOTAC Cup/Masters
# EPICENTER/2017
# The Summit/7
# Galaxy Battles/1
# Mars Dota 2 League/2017
# The Final Match/Season 1
# DreamLeague/Season 7
# The International/2017
# The International/2017/Special Events
# Dota2 Professional League/Season 4/Top
# StarLadder/i-League Invitational/3
# PGL Open/Bucharest/2017
# ESL One/Hamburg/2017
# Dota Pit League/Season 6
# Perfect World Masters/2017
# China Top/2017
# Adrenaline Cyber League/2017
# DreamLeague/Season 8
# ROG MASTERS/2017
# Mars Dota 2 League/Macau/2017
# The Summit/8
# Captains Draft/4
# Galaxy Battles/2
# ESL One/Genting/2018
# StarLadder/i-League Invitational/4
# ESL One/Katowice/2018
# PGL/Bucharest Major/2018
# GESC/Indonesia Minor/2018
# DreamLeague/Season 9
# Dota 2 Asia Championships/2018
# EPICENTER/2018
# GESC/Thailand Minor/2018

# %%
alltour['Shanghai Dota 2 Open/1']
# Out:
# {'end': '03/01/2016',
#  'prize': 61472,
#  'start': '01/01/2016',
#  'title': 'Shanghai Dota 2 Open #1'}

# %%
tourleft
# Out:
# {'Adrenaline Cyber League/2017': {'end': '22/11/2017',
#   'prize': 100000,
#   'start': '21/11/2017',
#   'title': 'Adrenaline Cyber League'},
#  'Boston Major/2016': {'end': '10/12/2016',
#   'prize': 3000000,
#   'start': '03/12/2016',
#   'title': 'The Boston Major 2016'},
#  'Captains Draft/3': {'end': '17/02/2016',
#   'prize': 124154,
#   'start': '19/01/2016',
#   'title': 'Captains Draft 3.0'},
#  'Captains Draft/4': {'end': '07/01/2018',
#   'prize': 300000,
#   'start': '04/01/2018',
#   'title': 'Captains Draft 4.0'},
#  'China Top/2016': {'end': '18/12/2016',
#   'prize': 229904,
#   'start': '17/12/2016',
#   'title': 'China Top 2016'},
#  'China Top/2017': {'end': '23/11/2017',
#   'prize': 'Nan',
#   'start': '19/11/2017',
#   'title': 'China Top 2017'},
#  'Dota 2 Asia Championships/2017': {'end': '04/04/2017',
#   'prize': 611997,
#   'start': '27/03/2017',
#   'title': 'Dota 2 Asia Championships 2017'},
#  'Dota 2 Asia Championships/2018': {'end': '07/04/2018',
#   'prize': 1000000,
#   'start': '30/03/2018',
#   'title': 'Dota 2 Asia Championships 2018'},
#  'Dota Pit League/Season 4': {'end': '20/03/2016',
#   'prize': 195274,
#   'start': '19/03/2016',
#   'title': 'Dota Pit League Season 4'},
#  'Dota Pit League/Season 5': {'end': '22/01/2017',
#   'prize': 139860,
#   'start': '20/01/2017',
#   'title': 'Dota Pit League Season 5'},
#  'Dota Pit League/Season 6': {'end': '05/11/2017',
#   'prize': 300000,
#   'start': '02/11/2017',
#   'title': 'AMD SAPPHIRE Dota PIT League'},
#  'Dota2 ACE/Provisional': {'end': '26/12/2016',
#   'prize': 60975.6,
#   'start': '16/10/2016',
#   'title': 'Dota2 ACE - Provisional'},
#  'Dota2 Professional League/Season 1': {'end': '17/07/2016',
#   'prize': 200000,
#   'start': '18/05/2016',
#   'title': 'Dota2 Professional League Season 1'},
#  'Dota2 Professional League/Season 2/Secondary': {'end': '13/12/2016',
#   'prize': 100000,
#   'start': '19/09/2016',
#   'title': 'Dota2 Professional League Season 2 - Secondary'},
#  'Dota2 Professional League/Season 2/Top': {'end': '31/12/2016',
#   'prize': 700000,
#   'start': '23/09/2016',
#   'title': 'Dota2 Professional League Season 2 - Top'},
#  'Dota2 Professional League/Season 3/Top': {'end': '16/04/2017',
#   'prize': 72595,
#   'start': '15/03/2017',
#   'title': 'Dota2 Professional League Season 3 (2017 S1) - Top'},
#  'Dota2 Professional League/Season 4/Top': {'end': '12/11/2017',
#   'prize': 143070,
#   'start': '30/09/2017',
#   'title': 'Dota2 Professional League Season 4 (2017 S2)- Top'},
#  'DreamLeague/Season 5': {'end': '22/05/2016',
#   'prize': 100000,
#   'start': '21/05/2016',
#   'title': 'DreamLeague Season 5'},
#  'DreamLeague/Season 6': {'end': '26/11/2016',
#   'prize': 185000,
#   'start': '25/11/2016',
#   'title': 'ASUS ROG DreamLeague Season 6'},
#  'DreamLeague/Season 6/League Play': {'end': '08/11/2016',
#   'prize': 56000,
#   'start': '11/10/2016',
#   'title': 'DreamLeague Season 6 League Play'},
#  'DreamLeague/Season 7': {'end': '22/07/2017',
#   'prize': 175000,
#   'start': '21/07/2017',
#   'title': 'DreamLeague Season 7'},
#  'DreamLeague/Season 7/EU Division': {'end': '21/05/2017',
#   'prize': 56000,
#   'start': '04/05/2017',
#   'title': 'DreamLeague Season 7 EU Division'},
#  'DreamLeague/Season 7/NA Division': {'end': '31/05/2017',
#   'prize': 12000,
#   'start': '30/05/2017',
#   'title': 'DreamLeague Season 7 NA Division'},
#  'DreamLeague/Season 8': {'end': '03/12/2017',
#   'prize': 1000000,
#   'start': '01/12/2017',
#   'title': 'DreamLeague Season 8'},
#  'DreamLeague/Season 9': {'end': '25/03/2018',
#   'prize': 300000,
#   'start': '21/03/2018',
#   'title': 'DreamLeague Season 9'},
#  'EPICENTER/2016': {'end': '15/05/2016',
#   'prize': 500000,
#   'start': '09/05/2016',
#   'title': 'EPICENTER 2016'},
#  'EPICENTER/2017': {'end': '11/06/2017',
#   'prize': 500000,
#   'start': '04/06/2017',
#   'title': 'EPICENTER 2017'},
#  'EPICENTER/2018': {'end': '06/05/2018',
#   'prize': 1000000,
#   'start': '27/04/2018',
#   'title': 'EPICENTER XL'},
#  'ESL One/Frankfurt/2016': {'end': '19/06/2016',
#   'prize': 314545,
#   'start': '17/06/2016',
#   'title': 'ESL One Frankfurt 2016'},
#  'ESL One/Genting/2017': {'end': '08/01/2017',
#   'prize': 250000,
#   'start': '06/01/2017',
#   'title': 'ESL One Genting 2017'},
#  'ESL One/Genting/2018': {'end': '28/01/2018',
#   'prize': 400000,
#   'start': '23/01/2018',
#   'title': 'ESL One Genting 2018'},
#  'ESL One/Hamburg/2017': {'end': '29/10/2017',
#   'prize': 1000000,
#   'start': '26/10/2017',
#   'title': 'ESL One Hamburg 2017'},
#  'ESL One/Katowice/2018': {'end': '25/02/2018',
#   'prize': 1000000,
#   'start': '20/02/2018',
#   'title': 'ESL One Katowice 2018'},
#  'ESL One/Manila/2016': {'end': '24/04/2016',
#   'prize': 250000,
#   'start': '22/04/2016',
#   'title': 'ESL One Manila 2016'},
#  'Elimination Mode/3': {'end': '17/02/2017',
#   'prize': 25000,
#   'start': '11/02/2017',
#   'title': 'Elimination Mode 3.0'},
#  'FACEIT/Invitational/1': {'end': '19/10/2016',
#   'prize': 25000,
#   'start': '17/10/2016',
#   'title': 'FACEIT Invitational'},
#  'G-League 2016': {'end': '09/07/2016',
#   'prize': 58359.6,
#   'start': '30/06/2016',
#   'title': 'G-League 2016'},
#  'GESC/Indonesia Minor/2018': {'end': '18/03/2018',
#   'prize': 300000,
#   'start': '15/03/2018',
#   'title': 'GESC: Indonesia Dota2 Minor'},
#  'GESC/Thailand Minor/2018': {'end': '12/05/2018',
#   'prize': 300000,
#   'start': '09/05/2018',
#   'title': 'GESC: Thailand Dota2 Minor'},
#  'Galaxy Battles/1': {'end': '18/06/2017',
#   'prize': 150000,
#   'start': '15/06/2017',
#   'title': 'Galaxy Battles'},
#  'Galaxy Battles/2': {'end': '21/01/2018',
#   'prize': 500000,
#   'start': '19/01/2018',
#   'title': 'Galaxy Battles II: Emerging Worlds'},
#  'Global Grand Masters': {'end': '26/07/2016',
#   'prize': 50000,
#   'start': '03/07/2016',
#   'title': 'Global Grand Masters'},
#  'Kiev Major/2017': {'end': '30/04/2017',
#   'prize': 3000000,
#   'start': '24/04/2017',
#   'title': 'The Kiev Major 2017'},
#  'MPGL/Southeast Asian Championship': {'end': '11/09/2016',
#   'prize': 50000,
#   'start': '09/09/2016',
#   'title': 'MPGL Southeast Asian Championship'},
#  'Manila Major/2016': {'end': '12/06/2016',
#   'prize': 3000000,
#   'start': '03/06/2016',
#   'title': 'The Manila Major 2016'},
#  'Mars Dota 2 League/2016': {'end': '02/10/2016',
#   'prize': 250000,
#   'start': '28/09/2016',
#   'title': 'Mars Dota 2 League 2016 Autumn'},
#  'Mars Dota 2 League/2017': {'end': '09/07/2017',
#   'prize': 250000,
#   'start': '05/07/2017',
#   'title': 'Mars Dota 2 League 2017'},
#  'Mars Dota 2 League/Macau/2017': {'end': '10/12/2017',
#   'prize': 300000,
#   'start': '08/12/2017',
#   'title': 'MDL Macau'},
#  'MarsTV Dota 2 League/2015/Winter': {'end': '31/01/2016',
#   'prize': 277668,
#   'start': '27/01/2016',
#   'title': 'MarsTV Dota 2 League 2015 Winter'},
#  'Mr. Cat Invitational/Europe': {'end': '18/05/2017',
#   'prize': 50000,
#   'start': '02/05/2017',
#   'title': 'Mr. Cat Invitational Europe'},
#  'Nanyang Dota 2 Championships/Cruise Cup/1': {'end': '16/10/2016',
#   'prize': 44579.84,
#   'start': '14/10/2016',
#   'title': 'Nanyang Dota 2 Championships  - Cruise Cup #1'},
#  'Nanyang Dota 2 Championships/Season 2': {'end': '10/07/2016',
#   'prize': 201270,
#   'start': '06/07/2016',
#   'title': 'Nanyang Dota 2 Championships Season 2'},
#  'National Electronic Arena/2016': {'end': '03/07/2016',
#   'prize': 195351,
#   'start': '02/07/2016',
#   'title': 'National Electronic Arena 2016'},
#  'Northern Arena/2016/BEAT Invitational': {'end': '13/11/2016',
#   'prize': 100000,
#   'start': '10/11/2016',
#   'title': 'Northern Arena BEAT Invitational'},
#  'PGL Open/Bucharest/2017': {'end': '22/10/2017',
#   'prize': 300000,
#   'start': '19/10/2017',
#   'title': 'PGL Open Bucharest'},
#  'PGL/Bucharest Major/2018': {'end': '11/03/2018',
#   'prize': 1000000,
#   'start': '04/03/2018',
#   'title': 'The Bucharest Major'},
#  'Perfect World Masters/2017': {'end': '26/11/2017',
#   'prize': 300000,
#   'start': '19/11/2017',
#   'title': 'Perfect World Masters'},
#  'Pro Gamer League/2016/Summer': {'end': '24/07/2016',
#   'prize': 100000,
#   'start': '23/07/2016',
#   'title': 'Pro Gamer League 2016 (PGL 2016) - Summer'},
#  'ROG MASTERS/2016': {'end': '13/11/2016',
#   'prize': 150000,
#   'start': '10/11/2016',
#   'title': 'ROG MASTERS 2016'},
#  'ROG MASTERS/2017': {'end': '10/12/2017',
#   'prize': 235000,
#   'start': '07/12/2017',
#   'title': 'ROG MASTERS 2017'},
#  'Red Bull Heroicks': {'end': '18/09/2016',
#   'prize': 'Nan',
#   'start': '17/09/2016',
#   'title': 'Red Bull Heroicks'},
#  'Russian e-Sports Cup/2016': {'end': '22/01/2017',
#   'prize': 42750,
#   'start': '09/04/2016',
#   'title': 'Russian e-Sports Cup 2016'},
#  'Russian e-Sports Cup/2017': {'end': '28/05/2017',
#   'prize': 56620,
#   'start': '01/04/2017',
#   'title': 'Russian e-Sports Cup 2017'},
#  'Shanghai Dota 2 Open/2': {'end': '08/10/2016',
#   'prize': 77911.6,
#   'start': '20/09/2016',
#   'title': 'Shanghai Dota 2 Open #2'},
#  'Shanghai Major/2016': {'end': '06/03/2016',
#   'prize': 3000000,
#   'start': '25/02/2016',
#   'title': 'The Shanghai Major 2016'},
#  'StarLadder/i-League Invitational/1': {'end': '17/04/2016',
#   'prize': 100000,
#   'start': '14/04/2016',
#   'title': 'StarLadder i-League Invitational Season 1'},
#  'StarLadder/i-League Invitational/2': {'end': '21/05/2017',
#   'prize': 100000,
#   'start': '18/05/2017',
#   'title': 'StarLadder i-League Invitational Season 2'},
#  'StarLadder/i-League Invitational/3': {'end': '15/10/2017',
#   'prize': 300000,
#   'start': '12/10/2017',
#   'title': 'StarLadder i-League Invitational Season 3'},
#  'StarLadder/i-League Invitational/4': {'end': '04/02/2018',
#   'prize': 300000,
#   'start': '01/02/2018',
#   'title': 'StarLadder i-League Invitational Season 4'},
#  'StarLadder/i-League StarSeries/Season 1': {'end': '17/01/2016',
#   'prize': 302227,
#   'start': '13/01/2016',
#   'title': 'SL i-League StarSeries Season 1'},
#  'StarLadder/i-League StarSeries/Season 2': {'end': '24/07/2016',
#   'prize': 300000,
#   'start': '21/07/2016',
#   'title': 'SL i-League StarSeries Season 2'},
#  'StarLadder/i-League StarSeries/Season 3': {'end': '26/02/2017',
#   'prize': 300000,
#   'start': '23/02/2017',
#   'title': 'StarLadder i-League StarSeries Season 3'},
#  'The Final Match/Season 1': {'end': '09/07/2017',
#   'prize': 50000,
#   'start': '07/07/2017',
#   'title': 'The Final Match Season 1'},
#  'The International/2016': {'end': '13/08/2016',
#   'prize': 20770460,
#   'start': '02/08/2016',
#   'title': 'The International 2016'},
#  'The International/2017': {'end': '12/08/2017',
#   'prize': 24787916,
#   'start': '02/08/2017',
#   'title': 'The International 2017'},
#  'The International/2017/Special Events': {'end': '10/08/2017',
#   'prize': 100000,
#   'start': '10/08/2017',
#   'title': 'The International 2017: Special Events'},
#  'The Masters/2017/Manila': {'end': '28/05/2017',
#   'prize': 250000,
#   'start': '25/05/2017',
#   'title': 'The Manila Masters'},
#  'The Summit/5': {'end': '17/07/2016',
#   'prize': 101044,
#   'start': '13/07/2016',
#   'title': 'The Summit 5'},
#  'The Summit/6': {'end': '20/11/2016',
#   'prize': 100000,
#   'start': '16/11/2016',
#   'title': 'The Summit 6'},
#  'The Summit/7': {'end': '18/06/2017',
#   'prize': 100000,
#   'start': '14/06/2017',
#   'title': 'DOTA Summit 7'},
#  'The Summit/8': {'end': '17/12/2017',
#   'prize': 300000,
#   'start': '13/12/2017',
#   'title': 'DOTA Summit 8'},
#  'VPGame Pro League/Season 2': {'end': '31/07/2016',
#   'prize': 45198,
#   'start': '20/07/2016',
#   'title': 'VPGame Pro League Season 2'},
#  'WePlay Dota2 League/Season 3': {'end': '01/05/2016',
#   'prize': 208239,
#   'start': '28/04/2016',
#   'title': 'WePlay Dota2 League Season 3'},
#  'World Cyber Arena/2016': {'end': '16/12/2016',
#   'prize': 589252,
#   'start': '14/12/2016',
#   'title': 'World Cyber Arena 2016'},
#  'World Cyber Arena/2016/America Qualifier': {'end': '13/11/2016',
#   'prize': 55000,
#   'start': '11/11/2016',
#   'title': 'World Cyber Arena 2016 AM Qualifiers'},
#  'World Cyber Arena/2016/Chinese Qualifiers/S1': {'end': '19/05/2016',
#   'prize': 61100,
#   'start': '19/03/2016',
#   'title': 'World Cyber Arena 2016 Chinese Qualifiers S1'},
#  'World Cyber Arena/2016/Chinese Qualifiers/S2': {'end': '25/09/2016',
#   'prize': 59956,
#   'start': '13/06/2016',
#   'title': 'World Cyber Arena 2016 Chinese Qualifiers S2'},
#  'World Cyber Arena/2016/Chinese Qualifiers/S3': {'end': '12/11/2016',
#   'prize': 59683,
#   'start': '05/10/2016',
#   'title': 'World Cyber Arena 2016 Chinese Qualifiers S3'},
#  'World Cyber Arena/2016/Europe Main Qualifier': {'end': '01/09/2016',
#   'prize': 54500,
#   'start': '23/08/2016',
#   'title': 'World Cyber Arena 2016 EU Main Qualifier'},
#  'World Cyber Arena/2016/SEA Qualifiers/S1': {'end': '21/05/2016',
#   'prize': 61108,
#   'start': '29/04/2016',
#   'title': 'World Cyber Arena 2016 SEA Qualifiers'},
#  'World Electronic Sports Games/2016': {'end': '15/01/2017',
#   'prize': 1500000,
#   'start': '12/01/2017',
#   'title': 'World Electronic Sports Games 2016'},
#  'World Electronic Sports Games/2016/Americas': {'end': '23/10/2016',
#   'prize': 73918.5713,
#   'start': '21/10/2016',
#   'title': 'World Electronic Sports Games 2016 Americas Finals'},
#  'World Electronic Sports Games/2016/Asia Pacific': {'end': '13/11/2016',
#   'prize': 73350,
#   'start': '10/11/2016',
#   'title': 'World Electronic Sports Games 2016 Asia Pacific Finals'},
#  'World Electronic Sports Games/2016/Europe CIS': {'end': '09/10/2016',
#   'prize': 74926,
#   'start': '06/10/2016',
#   'title': 'World Electronic Sports Games 2016 Europe & CIS Finals'},
#  'World Electronic Sports Games/2016/Middle East and Africa': {'end': '28/08/2016',
#   'prize': 74910,
#   'start': '26/08/2016',
#   'title': 'World Electronic Sports Games 2016 Middle East & Africa Finals'},
#  'ZOTAC Cup/Masters': {'end': '03/06/2017',
#   'prize': 100000,
#   'start': '30/05/2017',
#   'title': 'ZOTAC Cup Masters'}}

# %%
def correction(urllist):
    for turl in urllist:
        ifd = alltour[turl]
        ptc, lqjson = parseSquad(turl)
        startelodict, endelodict = getEloDict(ifd)
        save_obj({'wikitext': lqjson, 'startelodict': startelodict, 'endelodict': endelodict}, re.sub(r'\W+', '', ifd['title']).lower() )

# %%
turl = 'Dota 2 Radiant %26 Dire Cup/2015'
ifd = alltour['Dota 2 Radiant & Dire Cup/2015']
ptc, lqjson = parseSquad(turl)
startelodict, endelodict = getEloDict(ifd)
save_obj({'wikitext': lqjson, 'startelodict': startelodict, 'endelodict': endelodict}, re.sub(r'\W+', '', ifd['title']).lower() )

# %%
urllist = ['Dota 2 Radiant %26 Dire Cup/2015']

# %%
correction(urllist)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-ca1568b10068> in <module>()
# ----> 1 correction(urllist)
#
# <ipython-input-26-3ea59b699ee0> in correction(urllist)
#       1 def correction(urllist):
#       2     for turl in urllist:
# ----> 3         ifd = alltour[turl]
#       4         ptc, lqjson = parseSquad(turl)
#       5         startelodict, endelodict = getEloDict(ifd)
#
# KeyError: 'Dota 2 Radiant %26 Dire Cup/2015'

# %%
len(alltour)
# Out:
# 304

# %%
i = 0

# %%
for turl, ifd in alltour.items():
    if (pd.to_datetime(ifd['start']) > pd.to_datetime(endti2)) & (pd.to_datetime(ifd['end']) <= pd.to_datetime(endti7)):
        print(turl)
# Out:
# StarLadder/StarSeries/Season 1
# RaidCall Dota 2 League Season 1
# StarLadder/StarSeries/Season 3
# G-1 Champions League Season 4
# StarLadder/StarSeries/Season 4
# DreamHack/2012/Winter
# The Defense/Season 3
# World Cyber Games 2012
# RaidCall Dota 2 League Season 2
# ASUS Open 2012
# The Asia 2012
# G-League 2012 Season 2
# The Premier League/Season 4
# StarLadder/StarSeries/Season 5
# Armaggeddon Dota 2 Grand Slam Asia 2013
# WePlay Dota2 League/Season 1
# DreamHack/2013/Invitational
# G-1 Champions League Season 5
# ESL Major Series One/Spring/Main Event
# Ritmix Russian DOTA 2 League
# Techlabs Cup/2013/Season 1
# Curse Dota 2 Invitational
# AMD Premier League/Season 1
# Dota 2 Super League
# Rapture Gaming Network League 2013/2014
# StarLadder/StarSeries/Season 6
# The Premier League/Season 5
# RaidCall Dota 2 League Season 3
# The Defense/Season 4
# American Dota League/Season 1
# DreamHack/2013/Summer
# Alienware Cup
# ESL Major Series One/Summer/Main Event
# Corsair Gaming Summer Dota 2 Tournament 2013
# Nexon Starter League
# E2MAX L33t Championship
# ECL 2013/Season
# AMD Premier League/Season 2
# The International/2013
# The International/2013/Solo Tournament
# The International/2013/All-Star Match
# Techlabs Cup/2013/Season 2
# StarLadder/StarSeries/Season 7
# ESL Major Series One/Fall/Main Event
# Sina Cup Supernova Dota 2 Open/Season 1
# WePlay Dota2 League/Season 2
# 2013 WPC ACE Dota 2 League
# Techlabs Cup/2013/Season 3
# Nexon Sponsorship League/Season 1
# Dota 2 Champions League/Season 1
# MLG/2013/Fall Season/Invitational
# Fragbite Masters 2013
# Electronic Sports World Cup 2013
# DreamLeague/Kick-Off Season
# National Electronic Sports Tournament 2013
# Techlabs Cup/2013/Finals
# MLG/2013/Fall Season/Championship
# StarLadder/StarSeries/Season 8
# Sina Cup Supernova Dota 2 Open/Season 2
