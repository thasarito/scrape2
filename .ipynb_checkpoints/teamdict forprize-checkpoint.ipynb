# %%
from datetime import datetime
import requests
import numpy as np
import pandas as pd
import yaml
import re
from bs4 import BeautifulSoup
import wikitextparser as wtp
from ratelimit import rate_limited
from operator import *

def save_obj(obj, name ):
    import pickle
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
        
def load_obj(name ):
    import pickle
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

def easyText(t):
    return re.sub(r'\W+', '', str(t)).lower()

# %%
r = requests.get(url='http://liquipedia.net/dota2/api.php?action=ask&query=[[%3A%2B]]+[[Has+age%3A%3A>0]]|%3FHas+id|%3FHas+role|%3FHas+birth+day|%3FHas+name|%3FHas+nationality|sort%3DHas+id|limit%3D500&format=json')
json2 = r.json()

# %%
df = pd.DataFrame(columns=['cog', 'name', 'id', 'dob'])

# %%
for lname, ldata in json2.get('query').get('results').items():
    po = ldata.get('printouts')
    pid = ldata.get('fulltext')
    try:
        cog = po.get('Has nationality')[0]
    except IndexError:
        cog = 'Nan' 
    try:
        dob = pd.Timestamp.date(pd.to_datetime(po.get('Has birth day')[0]['timestamp'], unit='s'))
    except IndexError:
        dob = 'Nan'
    try:
        name = po.get('Has name')[0]
    except IndexError:
        name = 'Nan'        
    df = df.append({'cog': cog, 'name': name, 'id': pid, 'dob': dob}, ignore_index=True)

# %%
df.to_csv('dob.csv', index=False, encoding='utf-8')

# %%
titlelist = []
for lname, ldata in json2.get('query').get('results').items():
    pid = ldata.get('fulltext')
    titlelist.append(pid)

# %%
union = set(titlelist).union(titlelistall)

# %%
union
# Out:
# {'.Ark',
#  '13abyKnight',
#  '1437',
#  '290',
#  '2GD',
#  '33',
#  '343',
#  '4DR',
#  '5400',
#  '7ckngMad',
#  '820',
#  '86',
#  '897',
#  '9pasha',
#  'ADTR',
#  'ALOHADANCE',
#  'ALWAYSWANNAFLY',
#  'ARS-ART',
#  'AabBAA',
#  'Ab1ng',
#  'Abed',
#  'Accel',
#  'Ace',
#  'AdmiralBulldog',
#  'Admiration',
#  'Adong',
#  'Afoninje',
#  'AfrOmoush',
#  'AfterLife',
#  'Agressif',
#  'Ahfu',
#  'Ahjit',
#  'Air',
#  'Akke',
#  'Alex',
#  'Ame',
#  'Ana',
#  'AnneeDroid',
#  'Another',
#  'Apemother',
#  'Arise',
#  'Ariunbolor',
#  'Armel',
#  'Arms',
#  'ArsZeeqq',
#  'Arteezy',
#  'Artes',
#  'Artstyle',
#  'Attacker',
#  'Atun',
#  'Atze',
#  'Aui 2000',
#  'Aville',
#  'Awoke',
#  'Ax.Mo',
#  'Axx',
#  'Axypa',
#  'Ayesee',
#  'Ayo',
#  'B',
#  'BLink',
#  'BOne7',
#  'BYB',
#  'Baga',
#  'Balsam',
#  'Banana',
#  'BananaSlamJamma',
#  'Barash',
#  'Bashruk',
#  'Basskip',
#  'Bdiz',
#  'Beesa',
#  'Ben',
#  'Benhur',
#  'Benjaz',
#  'Bignum',
#  'Bimbo',
#  'Biryu',
#  'Biver',
#  'Black^',
#  'Blazemon',
#  'Blitz',
#  'Blizzy',
#  'Bloody Nine',
#  'Blowyourbrain',
#  'BoBoKa',
#  'Bok',
#  'Boombacs',
#  'Boombell',
#  'Boris',
#  'Boxi',
#  'Brax',
#  'BuLba',
#  'Bubu',
#  'BungsellRotee',
#  'BurNIng',
#  'Buugi',
#  'BzzIsPerfect',
#  'C4t',
#  'CC&C',
#  'CYso',
#  'CanceL^^',
#  'Capitalist',
#  'CartMaN',
#  'CaspeRRR',
#  'Cast',
#  'CemaTheSlayeR',
#  'Chains',
#  'Chalice',
#  'ChaoYue',
#  'Chappie',
#  'Chessie',
#  'Chibix',
#  'Chrillee',
#  'Chshrct',
#  'ChuaN',
#  'Chuvash',
#  'Clairvoyance',
#  'ComeWithMe',
#  'Cookie bear',
#  'Cooman',
#  'Corey',
#  'Costabile',
#  'Cr1t-',
#  'Crazy',
#  'Crio J',
#  'Crydasia',
#  'Crystallize',
#  'Cty',
#  'CyNiCaL',
#  'Cys',
#  'DD',
#  'DDR',
#  'DDX-',
#  'DJ',
#  'DXM',
#  'DancingDragon',
#  'Ddc',
#  'DeMoN',
#  'Dendi',
#  'Ditya Ra',
#  'DkPhobos',
#  'Dnz',
#  'Doctor',
#  'Dog 7',
#  'Dogf1ghts',
#  'Draskyl',
#  'Drayich',
#  'Dread',
#  'Dreamocel',
#  'DreamyU',
#  'Droog',
#  'DuBu',
#  'DurpDurp',
#  'Duster',
#  'Dutch Freak',
#  'EGM',
#  'EL lisasH',
#  'ELeVeN',
#  'END',
#  'Eagle',
#  'Ecnart',
#  'Eosin',
#  'Era',
#  'Eri Neeman',
#  'Eskillz',
#  'Etakaka',
#  'EternaLEnVy',
#  'Ewe',
#  'Excalibur',
#  'Exotic Deer',
#  'FLUFFNSTUFF',
#  'FaN',
#  'Faith',
#  'Faith bian',
#  'Fata',
#  'Fear',
#  'Feaver',
#  'Febby',
#  'Feero',
#  'Fenrir',
#  'Ferrari 430',
#  'Fervian',
#  'Fey',
#  'Fishbone',
#  'Five',
#  'Flens',
#  'Flow',
#  'Fly',
#  'Fly.',
#  'Flyby',
#  'FlyingZebra',
#  'Flysolo',
#  'Fng',
#  'Fogged',
#  'Fonte',
#  'Forev',
#  'Foxx',
#  'Fran',
#  'FrancisLee',
#  'Freeze',
#  'Frigoleet',
#  'Fronz',
#  'Frost',
#  'Fun',
#  'Funn1k',
#  'Funzii',
#  'Fusheng',
#  'Fy',
#  'Fyms',
#  'FzFz',
#  'G',
#  'G0g1',
#  'GGwpLanaya',
#  'GH',
#  'Gabbi',
#  'Gambling',
#  'Garder',
#  'Gareth',
#  'Garter',
#  'Gedrox',
#  'GeneRaL',
#  'Ghostik',
#  'GiGA',
#  'Gintoki',
#  'Gio',
#  'GoDz',
#  'Goblak',
#  'Goddam',
#  'Godot',
#  'Gorec',
#  'Gorgc',
#  'GranDGranT',
#  'Greedy',
#  'Gudii',
#  'Guvara',
#  'H4nn1',
#  'HANNAH MONTANA',
#  'HFn',
#  'Hana',
#  'Handsken',
#  'Hao',
#  'Heen',
#  'Heromu',
#  'HesteJoe-Rotten',
#  'Hex0r',
#  'HooNji',
#  'Hook (player)',
#  'Hugo',
#  'Hy',
#  'Hyhy',
#  'Hym',
#  'ILLusionisT',
#  'ILTW',
#  'INsania',
#  'Ice (player)',
#  'Iceberg',
#  'Iceice',
#  'Iceiceice',
#  'Icy',
#  'Ifrit',
#  'Illidan',
#  'InJuly',
#  'Inflame',
#  'Inkvizitor',
#  'Inmate',
#  'Inverno',
#  'Ixmike88',
#  'J4',
#  'JUST',
#  'Jabbz',
#  'Jabz',
#  'Jackal',
#  'Jacko',
#  'James',
#  'Jenkins',
#  'JerAx',
#  'Jericho',
#  'Jerry',
#  'JessieVash',
#  'Jeyo',
#  'Jhoven',
#  'JiaJia',
#  'Jigglebilly',
#  'Jixing',
#  'JoHnNy',
#  'Jonassomfan',
#  'Joraal',
#  'JotM',
#  'Jubei',
#  'Julz',
#  'June',
#  'JyC',
#  'KBBQ',
#  'KSi',
#  'KYxY',
#  'KaHT',
#  'KaNG',
#  'Kabu',
#  'Kai',
#  'Kaka',
#  'Kebap',
#  'Kecik Imba',
#  'Kefka',
#  'KeyaNo',
#  'Keyser',
#  'KheZu',
#  'Kikoni',
#  'Kim0',
#  'KingJ',
#  'KingR',
#  'Kingrd',
#  'Kingteka',
#  'Kipspul',
#  'Klasynky',
#  'Klotz22',
#  'KoaLa',
#  'Korok',
#  'KotLGuy',
#  'Kotarō Hayama',
#  'Kpoptosis',
#  'Kuku',
#  'KuroKy',
#  'KvH',
#  'KyT',
#  'KyrieDepra',
#  'L0lik O',
#  'LD',
#  'LaKelz',
#  'LaNm',
#  'Lacoste',
#  'Lanaro',
#  'Lance (Player)',
#  'Le',
#  'LeBronDota',
#  'LeoStyle-',
#  'Ler GG',
#  'Li',
#  'Liekkas',
#  'LighTofHeaveN',
#  'Lil',
#  'Lil kin6',
#  'Limmp',
#  'Lin',
#  'Link',
#  'Liposa',
#  'LizZard',
#  'Loda',
#  'LongDD',
#  'Longb',
#  'Loomdun',
#  'Lpc',
#  'LuLu^^',
#  'Lubby',
#  'Luft',
#  'Luminous',
#  'Luo',
#  'Luobo',
#  'Lwy',
#  'Lyrical',
#  'MATUMBAMAN',
#  'MJW',
#  'MKSos',
#  'MMY',
#  'MP',
#  'MSS',
#  'MaGoma',
#  'MaNia',
#  'Machine',
#  'Madara',
#  'Maden',
#  'Maelk',
#  'MagE-',
#  'Mag~',
#  'Mambos',
#  'Mandy',
#  'Mango Banana',
#  'Mantis',
#  'MarSu',
#  'March (Korean player)',
#  'Masakary',
#  'Masoku',
#  'Mason',
#  'Masquerade',
#  'Massacre',
#  'Mastermind',
#  'Matrim',
#  'Matthew',
#  'Maut',
#  'Maybe',
#  'Maybe Next Time',
#  'MdL (Alperen Arslan)',
#  'MeTTpuM',
#  'MelodyLovers',
#  'Melonzz',
#  'Meracle',
#  'Merlini',
#  'MiCKe',
#  'MiGGel',
#  'MiHawk',
#  'MiLAN',
#  'MiSeRy',
#  'MidOne',
#  'Mikasa',
#  'Mikey',
#  'MinD ContRoL',
#  'Minerva',
#  'Mini',
#  'Miposhka',
#  'Miracle-',
#  'Mirakel',
#  'Misha',
#  'Mitch',
#  'MoZuN',
#  'Mofi',
#  'Monet',
#  'Moo',
#  'Moogy',
#  'Mool',
#  'Moon (Kam Boon Seng)',
#  'MoonMeander',
#  'Moonlight',
#  'Mrrr',
#  'MtR',
#  'Mtrx4u',
#  'Mu',
#  'Mushi',
#  'MusiCa',
#  'MyPro',
#  'Mynuts',
#  'N0tail',
#  'NO Chanc3',
#  'NS',
#  'Nafari',
#  'Nahaz',
#  'Nando',
#  'NeaR',
#  'Nedbone',
#  'Nemphy',
#  'Neqroman',
#  'Net (player)',
#  'Newsham',
#  'Nexus',
#  'Nikobaby',
#  'Nine',
#  'Ninjaboogie',
#  'Niqua',
#  'Nisha',
#  'Nix',
#  'Nj',
#  'NoFear',
#  'Noia',
#  'Nokky',
#  'Nono',
#  'Noone',
#  'Noxville',
#  'NutZ',
#  'ODPixel',
#  'Ohaiyo',
#  'Old chicken',
#  'OmegaPwner',
#  'Op',
#  'Ori',
#  'Origami',
#  'Owa',
#  'PAADA',
#  'PARIS',
#  'PGG',
#  'PSM',
#  'PaS',
#  'Pablo',
#  'Pain',
#  'Pajkatt',
#  'Palantimos',
#  'Pandaego',
#  'Paparazi灬',
#  'Papita',
#  'PatSoul',
#  'Patos',
#  'Piao',
#  'Pikachu',
#  'PimpmuckL',
#  'Pingvincek',
#  'Pinoy',
#  'PlayHard',
#  'Poloson',
#  'Ppd',
#  'PrettyHaw',
#  'Primo',
#  'Puer tea',
#  'Puppey',
#  'Purge (Kevin Godec)',
#  'PwN',
#  'PyrionFlax',
#  'Q',
#  'QO',
#  'QQQ',
#  'QwisTa',
#  'RAMZES666',
#  'ROtK',
#  'RR',
#  'Rabbit',
#  'RampaGe',
#  'Ran',
#  'Rapy',
#  'Raven',
#  'Rayuur',
#  'ReaLaxXx',
#  'Red',
#  'Redeye',
#  'Reesion',
#  'Reisen',
#  'Resolut1on',
#  'Retribution',
#  'Rime',
#  'Riser',
#  'Ritsu',
#  'RmN-',
#  'Roddgeee',
#  'RodjER',
#  'Rong',
#  'Runec',
#  'RyOyr',
#  'Ryoya',
#  'RyuUboruZ',
#  'Ryuya',
#  'Ryze',
#  'S4',
#  'SANKE',
#  'SCripted',
#  'SKANKS224',
#  'SLiCKz',
#  'STABA',
#  'SUNSfan',
#  'SVG',
#  'Sag',
#  'Saksa',
#  'Sam H',
#  'SanSheng',
#  'Santa',
#  'Scabo',
#  'Scandal',
#  'Sccc',
#  'Scofield',
#  'Sealkid',
#  'Sedoy',
#  'SeleCT',
#  'Seleri',
#  'September',
#  'SexyBamboe',
#  'Sh4dowehhh',
#  'Shachlo',
#  'Shade',
#  'Shadow (player)',
#  'Shaneomad',
#  'Sharky',
#  'Sheever',
#  'Shiibbyy',
#  'Shiki',
#  'Shining',
#  'Silent',
#  'SingSing',
#  'SirActionSlacks',
#  'Skemberlu',
#  'Skrff',
#  'SkyLark',
#  'Slander',
#  'SlashStrike',
#  'Slayer',
#  'SmAsH',
#  'Sneyking',
#  'Snoopy',
#  'SoNNeikO',
#  'Solen',
#  'Solo',
#  'StingeR',
#  'Sugar baby',
#  'SumaiL',
#  'Sune',
#  'Sunlight',
#  'Super',
#  'Super (Su Peng)',
#  'Swiftending',
#  'Syeonix',
#  'Sylar',
#  'SyndereN',
#  'TC',
#  'Taiga',
#  'Tavo',
#  'Teehee',
#  'Therence',
#  'Thiolicor',
#  'TidesofTime',
#  'Timado',
#  'Tims',
#  'TobiWan',
#  'Trixi',
#  'Tudi',
#  'UNiVeRsE',
#  'UnderShock',
#  'V0ja',
#  'V1lat',
#  'VANSKOR',
#  'VanN',
#  'Vandersar',
#  'Velo',
#  'Victoria',
#  'Vigoss',
#  'W33',
#  'Waixi',
#  'Waytosexy',
#  'Wejustzik',
#  'Weppas',
#  'White',
#  'WinteR',
#  'WwD',
#  'WwieWambo',
#  'XBOCT',
#  'XFreedom',
#  'XRag',
#  'XaKoH',
#  'Xepher',
#  'Xiao2lei',
#  'Xiao8',
#  'XtiNcT',
#  'Xxs',
#  'Xy-',
#  'Xz',
#  'YUI',
#  'YYF',
#  'Y`',
#  'Yabyoo',
#  'Yaj',
#  'Yang',
#  'Yao',
#  'YaphetS',
#  'YapzOr',
#  'Yim',
#  'Yoky-',
#  'Yol',
#  'ZExBinGo',
#  'ZSMJ',
#  'Zai',
#  'Zayac',
#  'ZeroPerfect',
#  'Zhou',
#  'Ztok',
#  'Zyori',
#  'Женя',
#  '闷油瓶'}

# %%
@rate_limited(1, 2)
def requestQuery(title):
    headers = {
    'User-Agent': 'Data for Research',
    'From': 'terthasarit@live.com', 
    'Accept-Encoding': 'gzip'
    }
    r = requests.get(url='http://liquipedia.net/dota2/api.php?action=query&format=json&prop=redirects&titles=' + title, headers=headers)
    json = r.json()
    return json

# %%
save_obj(AlternateIdDict, '/dict/AlternateIdDict')

# %%
AlternateIdDict = {}

# %%
# %%time
for title in union:
    json = requestQuery(title)
    for pageid, ldata in json.get('query').get('pages').items():
        mainid = easyText(ldata['title'])
        try:
            AlternateIdDict[mainid] = mainid
            for altid in ldata['redirects']:
                AlternateIdDict[easyText(altid['title'])] = mainid
        except KeyError:
            AlternateIdDict[mainid] = mainid
# Out:
# Wall time: 21min 39s

# %%
AlternateIdDict
# Out:
# {'123456': 'xiao2lei',
#  '13abyknight': '13abyknight',
#  '1437': '1437',
#  '290': '290',
#  '2gd': '2gd',
#  '2lei': 'xiao2lei',
#  '33': '33',
#  '333': 'liekkas',
#  '343': '343',
#  '357': 'qqq',
#  '430': 'ferrari430',
#  '4dr': '4dr',
#  '5400': '5400',
#  '633': 'bzzisperfect',
#  '716': 'owa',
#  '747': 'ryoya',
#  '7ckngmad': '7ckngmad',
#  '820': '820',
#  '86': '86',
#  '876': 'mksos',
#  '897': '897',
#  '9pasha': '9pasha',
#  '9pashaebashu': '9pasha',
#  'aaabbbaaa': 'aabbaa',
#  'aabbaa': 'aabbaa',
#  'ab1ng': 'ab1ng',
#  'abed': 'abed',
#  'accel': 'accel',
#  'ace': 'ace',
#  'aczino': 'scofield',
#  'adam': '343',
#  'admiralbulldog': 'admiralbulldog',
#  'admiration': 'admiration',
#  'adong': 'adong',
#  'adtr': 'adtr',
#  'afoninje': 'afoninje',
#  'afromoush': 'afromoush',
#  'afterlife': 'afterlife',
#  'agressif': 'agressif',
#  'ahfu': 'ahfu',
#  'ahjit': 'ahjit',
#  'air': 'air',
#  'airmangataosenai': 'illidan',
#  'akke': 'akke',
#  'alex': 'alex',
#  'alohadance': 'alohadance',
#  'alwayswannafly': 'alwayswannafly',
#  'ame': 'ame',
#  'ana': 'ana',
#  'andrew': 'jubei',
#  'anneedroid': 'anneedroid',
#  'another': 'another',
#  'apemother': 'apemother',
#  'ar1se': 'arise',
#  'aria': 'jiajia',
#  'arise': 'arise',
#  'ariunbolor': 'ariunbolor',
#  'ark': 'ark',
#  'armel': 'armel',
#  'arms': 'arms',
#  'arsart': 'arsart',
#  'arszeeqq': 'arszeeqq',
#  'arteezy': 'arteezy',
#  'artes': 'artes',
#  'artstyle': 'artstyle',
#  'attacker': 'attacker',
#  'atun': 'atun',
#  'atuuuuuun': 'atun',
#  'atze': 'atze',
#  'aui': 'aui2000',
#  'aui2000': 'aui2000',
#  'aville': 'aville',
#  'awoke': 'awoke',
#  'axmo': 'axmo',
#  'axx': 'axx',
#  'axypa': 'axypa',
#  'ayesee': 'ayesee',
#  'ayo': 'ayo',
#  'azcino': 'scofield',
#  'b': 'b',
#  'babyknight': '13abyknight',
#  'baga': 'baga',
#  'bakemono': 'feero',
#  'balloon': 'yim',
#  'balsam': 'balsam',
#  'bamboe': 'sexybamboe',
#  'banana': 'banana',
#  'bananaslamjamma': 'bananaslamjamma',
#  'bang': 'stinger',
#  'barash': 'barash',
#  'barashik': 'barash',
#  'bashruk': 'bashruk',
#  'basskip': 'basskip',
#  'bdiz': 'bdiz',
#  'beaverknight': 'singsing',
#  'beesa': 'beesa',
#  'ben': 'ben',
#  'benhur': 'benhur',
#  'benjaz': 'benjaz',
#  'bennoxvillesteenhuisen': 'noxville',
#  'bigdaddy': 'n0tail',
#  'bignum': 'bignum',
#  'bimbo': 'bimbo',
#  'bingo': 'zexbingo',
#  'biryu': 'biryu',
#  'biver': 'biver',
#  'black': 'black',
#  'blazemon': 'blazemon',
#  'bleek': 'b',
#  'blink': 'blink',
#  'blitz': 'blitz',
#  'blizzy': 'blizzy',
#  'bloodynine': 'bloodynine',
#  'blowyourbrain': 'blowyourbrain',
#  'boboka': 'boboka',
#  'bok': 'bok',
#  'bokerino': 'bok',
#  'bone7': 'bone7',
#  'boombacs': 'boombacs',
#  'boombell': 'boombell',
#  'boris': 'boris',
#  'boxi': 'boxi',
#  'brax': 'brax',
#  'bsj': 'bananaslamjamma',
#  'bubu': 'bubu',
#  'bubu3': 'bubu',
#  'bulba': 'bulba',
#  'bulldog': 'admiralbulldog',
#  'bungsellrotee': 'bungsellrotee',
#  'burning': 'burning',
#  'buugi': 'buugi',
#  'byb': 'byb',
#  'bzz': 'bzzisperfect',
#  'bzzisperfect': 'bzzisperfect',
#  'c4t': 'c4t',
#  'calamity': 'ryuya',
#  'cancel': 'cancel',
#  'capitalist': 'capitalist',
#  'captaingivemeball': 'q',
#  'cartman': 'cartman',
#  'casperrr': 'casperrr',
#  'cast': 'cast',
#  'cc': 'cc',
#  'cema': 'cematheslayer',
#  'cematheslayer': 'cematheslayer',
#  'chad': 'b',
#  'chains': 'chains',
#  'chalice': 'chalice',
#  'chao': 'yui',
#  'chaoyue': 'chaoyue',
#  'chappie': 'chappie',
#  'chessie': 'chessie',
#  'chibix': 'chibix',
#  'chibix33': 'chibix',
#  'chrillee': 'chrillee',
#  'chrissy': 'dj',
#  'chshrct': 'chshrct',
#  'chuan': 'chuan',
#  'chuvash': 'chuvash',
#  'clairvoyance': 'clairvoyance',
#  'comewithme': 'comewithme',
#  'conman': 'skanks224',
#  'cookiebear': 'cookiebear',
#  'cooman': 'cooman',
#  'corey': 'corey',
#  'costabile': 'costabile',
#  'cr1t': 'cr1t',
#  'crazy': 'crazy',
#  'crioj': 'crioj',
#  'cryasia': 'crydasia',
#  'crydasia': 'crydasia',
#  'crystallize': 'crystallize',
#  'crz': 'crazy',
#  'cty': 'cty',
#  'cwm': 'comewithme',
#  'cy': 'yim',
#  'cynical': 'cynical',
#  'cys': 'cys',
#  'cyso': 'cyso',
#  'dai': 'mmy',
#  'dakota': 'kotlguy',
#  'dancingdragon': 'dancingdragon',
#  'dd': 'dd',
#  'ddc': 'ddc',
#  'ddr': 'ddr',
#  'ddx': 'ddx',
#  'demon': 'demon',
#  'dendi': 'dendi',
#  'devastating': 'james',
#  'dityara': 'dityara',
#  'dj': 'dj',
#  'dkphobos': 'dkphobos',
#  'dnz': 'dnz',
#  'doctor': 'doctor',
#  'dog7': 'dog7',
#  'dogf1ghts': 'dogf1ghts',
#  'dogfight': 'dogf1ghts',
#  'doney': 'egm',
#  'doni': 'egm',
#  'dotacapitalist': 'capitalist',
#  'draskyl': 'draskyl',
#  'drayich': 'drayich',
#  'drayswe': 'drayich',
#  'dread': 'dread',
#  'dream': 'solen',
#  'dreamocel': 'dreamocel',
#  'dreamyu': 'dreamyu',
#  'dreamyu丶': 'dreamyu',
#  'droog': 'droog',
#  'dubu': 'dubu',
#  'durka': 'gareth',
#  'durpdurp': 'durpdurp',
#  'duster': 'duster',
#  'dutchfreak': 'dutchfreak',
#  'dxm': 'dxm',
#  'døden': 'miggel',
#  'eagle': 'eagle',
#  'ecnart': 'ecnart',
#  'ee': 'eternalenvy',
#  'eesama': 'eternalenvy',
#  'egm': 'egm',
#  'eleven': 'eleven',
#  'ellisash': 'ellisash',
#  'end': 'end',
#  'eosin': 'eosin',
#  'era': 'era',
#  'erineeman': 'erineeman',
#  'eskillz': 'eskillz',
#  'etakaka': 'etakaka',
#  'eterna7': 'mikasa',
#  'eternalenvy': 'eternalenvy',
#  'ewe': 'ewe',
#  'excalibur': 'excalibur',
#  'exoticdeer': 'exoticdeer',
#  'fadeplayer': 'pain',
#  'faith': 'faith',
#  'faithbian': 'faithbian',
#  'fan': 'fan',
#  'fanofsoyeon': 'gudii',
#  'fata': 'fata',
#  'fear': 'fear',
#  'feaver': 'feaver',
#  'febby': 'febby',
#  'feero': 'feero',
#  'fenrir': 'fenrir',
#  'ferrari': 'ferrari430',
#  'ferrari430': 'ferrari430',
#  'fervian': 'fervian',
#  'fey': 'fey',
#  'fishbone': 'fishbone',
#  'five': 'five',
#  'flee': 'francislee',
#  'flens': 'flens',
#  'flow': 'flow',
#  'fluff': 'fluffnstuff',
#  'fluffnstuff': 'fluffnstuff',
#  'fly': 'fly',
#  'flyby': 'flyby',
#  'flyingzebra': 'flyingzebra',
#  'flysolo': 'flysolo',
#  'fng': 'fng',
#  'fogged': 'fogged',
#  'fonte': 'fonte',
#  'forev': 'forev',
#  'foxx': 'foxx',
#  'foxxx': 'foxx',
#  'fran': 'fran',
#  'francislee': 'francislee',
#  'frangay': 'francislee',
#  'frangray': 'francislee',
#  'freeze': 'freeze',
#  'frigoleet': 'frigoleet',
#  'fronz': 'fronz',
#  'frost': 'frost',
#  'fuckineh': 'costabile',
#  'fuckingmad': '7ckngmad',
#  'fuckneh': 'costabile',
#  'fun': 'fun',
#  'funn1k': 'funn1k',
#  'funzii': 'funzii',
#  'fusheng': 'fusheng',
#  'fy': 'fy',
#  'fyms': 'fyms',
#  'fzfz': 'fzfz',
#  'g': 'g',
#  'g0g1': 'g0g1',
#  'gabbi': 'gabbi',
#  'gambling': 'gambling',
#  'garder': 'garder',
#  'gareth': 'gareth',
#  'garter': 'garter',
#  'gazeod': 'end',
#  'gbcasts': 'gareth',
#  'gedrox': 'gedrox',
#  'general': 'general',
#  'ggwplanaya': 'ggwplanaya',
#  'gh': 'gh',
#  'ghostik': 'ghostik',
#  'giga': 'giga',
#  'gintoki': 'gintoki',
#  'gio': 'gio',
#  'goblak': 'goblak',
#  'goblin': 'goblak',
#  'god': 'g',
#  'goddam': 'goddam',
#  'godot': 'godot',
#  'godz': 'godz',
#  'gorec': 'gorec',
#  'gorets': 'gorec',
#  'gorgc': 'gorgc',
#  'grandgrant': 'grandgrant',
#  'greedy': 'greedy',
#  'grimocel': 'dreamocel',
#  'guardian': 'garder',
#  'gudii': 'gudii',
#  'guvara': 'guvara',
#  'h4nn1': 'h4nn1',
#  'hana': 'hana',
#  'handsken': 'handsken',
#  'hannahmontana': 'hannahmontana',
#  'hao': 'hao',
#  'heen': 'heen',
#  'heromu': 'heromu',
#  'hestejoerotten': 'hestejoerotten',
#  'hex0r': 'hex0r',
#  'hexor': 'hex0r',
#  'hfn': 'hfn',
#  'hfnk3': 'hfn',
#  'hhh': 'q',
#  'hook': 'hookplayer',
#  'hookplayer': 'hookplayer',
#  'hoonji': 'hoonji',
#  'hugo': 'hugo',
#  'hy': 'hy',
#  'hyhy': 'hyhy',
#  'hym': 'hym',
#  'iceberg': 'iceberg',
#  'iceice': 'iceice',
#  'iceiceice': 'iceiceice',
#  'iceplayer': 'iceplayer',
#  'iconoclast': 'matrim',
#  'icy': 'icy',
#  'ifrit': 'ifrit',
#  'illidan': 'illidan',
#  'illusionist': 'illusionist',
#  'iltw': 'iltw',
#  'inflame': 'inflame',
#  'injuly': 'injuly',
#  'inkvizitor': 'inkvizitor',
#  'inmate': 'inmate',
#  'innocence': 'y',
#  'insania': 'insania',
#  'inverno': 'inverno',
#  'ixmike': 'ixmike88',
#  'ixmike88': 'ixmike88',
#  'j3r1ch0': 'jericho',
#  'j4': 'j4',
#  'jab': 'jabz',
#  'jabbz': 'jabbz',
#  'jabz': 'jabz',
#  'jack0': 'jacko',
#  'jackal': 'jackal',
#  'jacko': 'jacko',
#  'james': 'james',
#  'jason': 'fun',
#  'jay': 'bimbo',
#  'jenkins': 'jenkins',
#  'jenya': 'женя',
#  'jerax': 'jerax',
#  'jericho': 'jericho',
#  'jerry': 'jerry',
#  'jessievash': 'jessievash',
#  'jeyo': 'jeyo',
#  'jhoven': 'jhoven',
#  'jiajia': 'jiajia',
#  'jigglebilly': 'jigglebilly',
#  'jixing': 'jixing',
#  'johnny': 'johnny',
#  'jonassomfan': 'jonassomfan',
#  'jonathanberg': 'loda',
#  'joraal': 'joraal',
#  'jotm': 'jotm',
#  'jubei': 'jubei',
#  'july': 'gambling',
#  'julz': 'julz',
#  'june': 'june',
#  'just': 'just',
#  'jyc': 'jyc',
#  'kabu': 'kabu',
#  'kaht': 'kaht',
#  'kai': 'kai',
#  'kaka': 'kaka',
#  'kal': 'hana',
#  'kamma': 'freeze',
#  'kaneki': 'jabz',
#  'kang': 'kang',
#  'kbbq': 'kbbq',
#  'kbbqdota': 'kbbq',
#  'kebap': 'kebap',
#  'kecikimba': 'kecikimba',
#  'kefka': 'kefka',
#  'key': 'sag',
#  'keyano': 'keyano',
#  'keyser': 'keyser',
#  'keysersoze': 'keyser',
#  'khezu': 'khezu',
#  'kikoni': 'kikoni',
#  'kim0': 'kim0',
#  'kimo': 'kim0',
#  'kingj': 'kingj',
#  'kingr': 'kingr',
#  'kingrd': 'kingrd',
#  'kingteka': 'kingteka',
#  'kips': 'kipspul',
#  'kipspul': 'kipspul',
#  'kky': 'kuroky',
#  'klasynky': 'klasynky',
#  'klotz': 'klotz22',
#  'klotz22': 'klotz22',
#  'koala': 'koala',
#  'koreanbbq': 'kbbq',
#  'korok': 'korok',
#  'kotaro': 'kotarōhayama',
#  'kotarohayama': 'kotarōhayama',
#  'kotarōhayama': 'kotarōhayama',
#  'kotlguy': 'kotlguy',
#  'kpoptosis': 'kpoptosis',
#  'krtk': 'kingteka',
#  'ksi': 'ksi',
#  'kuku': 'kuku',
#  'kuro': 'kuroky',
#  'kuroky': 'kuroky',
#  'kvh': 'kvh',
#  'kyle': 'melonzz',
#  'kyriedepra': 'kyriedepra',
#  'kyt': 'kyt',
#  'kyxy': 'kyxy',
#  'l0liko': 'l0liko',
#  'lacoste': 'lacoste',
#  'lakalz': 'lakelz',
#  'lakelz': 'lakelz',
#  'lanaro': 'lanaro',
#  'lanceplayer': 'lanceplayer',
#  'lanm': 'lanm',
#  'ld': 'ld',
#  'le': 'le',
#  'lebrondota': 'lebrondota',
#  'lebronmp3': 'lebrondota',
#  'leostyle': 'leostyle',
#  'lergg': 'lergg',
#  'leumik': 'kim0',
#  'li': 'li',
#  'liekkas': 'liekkas',
#  'lightofheaven': 'lightofheaven',
#  'lighttofheaven': 'lightofheaven',
#  'lil': 'lil',
#  'lilhardy': 'lil',
#  'lilkin6': 'lilkin6',
#  'limmp': 'limmp',
#  'lin': 'lin',
#  'link': 'link',
#  'linklink': 'link',
#  'liposa': 'liposa',
#  'lizzard': 'lizzard',
#  'loda': 'loda',
#  'loh': 'lightofheaven',
#  'lolik': 'l0liko',
#  'longb': 'longb',
#  'longdd': 'longdd',
#  'loomdun': 'loomdun',
#  'lost': 'lightofheaven',
#  'lpc': 'lpc',
#  'lubby': 'lubby',
#  'lucifer': 'iceiceice',
#  'luffy': 'near',
#  'luft': 'luft',
#  'lulu': 'lulu',
#  'luminous': 'luminous',
#  'luminousinverse': 'luminous',
#  'luo': 'luo',
#  'luobo': 'luobo',
#  'lwy': 'lwy',
#  'lyrical': 'lyrical',
#  'lyricalgangst3r': 'lyrical',
#  'lyricalgangster': 'lyrical',
#  'm99jy': 'victoria',
#  'machine': 'machine',
#  'madara': 'madara',
#  'maden': 'maden',
#  'madmiration': 'admiration',
#  'madshka': '7ckngmad',
#  'maelk': 'maelk',
#  'mag': 'mag',
#  'mage': 'mage',
#  'magoma': 'magoma',
#  'mambos': 'mambos',
#  'mandy': 'mandy',
#  'mangobanana': 'mangobanana',
#  'mangochineseplayer': 'dogf1ghts',
#  'mania': 'mania',
#  'mantis': 'mantis',
#  'maomi': 'magoma',
#  'marchkoreanplayer': 'marchkoreanplayer',
#  'marsc': 'fran',
#  'marsu': 'marsu',
#  'masakary': 'masakary',
#  'masoku': 'masoku',
#  'mason': 'mason',
#  'masquerade': 'masquerade',
#  'massacre': 'massacre',
#  'masterkenchiro': 'slayer',
#  'mastermind': 'mastermind',
#  'matrim': 'matrim',
#  'matteru': 'mtr',
#  'matthew': 'matthew',
#  'matu': 'matumbaman',
#  'matumbaman': 'matumbaman',
#  'maut': 'maut',
#  'maybe': 'maybe',
#  'maybenexttime': 'maybenexttime',
#  'mdlalperenarslan': 'mdlalperenarslan',
#  'meen': 'kai',
#  'melodylovers': 'melodylovers',
#  'melonzz': 'melonzz',
#  'mentalprotector': 'mp',
#  'meracle': 'meracle',
#  'merlini': 'merlini',
#  'mettpum': 'mettpum',
#  'micke': 'micke',
#  'midone': 'midone',
#  'miduan': 'midone',
#  'miggel': 'miggel',
#  'mihawk': 'mihawk',
#  'mikasa': 'mikasa',
#  'mikey': 'mikey',
#  'milan': 'milan',
#  'mindcontrol': 'mindcontrol',
#  'minerva': 'minerva',
#  'mini': 'mini',
#  'minoz': 'kotarōhayama',
#  'miposhka': 'miposhka',
#  'miracle': 'miracle',
#  'mirakel': 'mirakel',
#  'misery': 'misery',
#  'misha': 'misha',
#  'mitch': 'mitch',
#  'mjw': 'mjw',
#  'mksos': 'mksos',
#  'mlcke': 'micke',
#  'mmy': 'mmy',
#  'mnt': 'maybenexttime',
#  'mofi': 'mofi',
#  'mojostormstout': 'mss',
#  'monet': 'monet',
#  'moo': 'moo',
#  'moogy': 'moogy',
#  'mool': 'mool',
#  'moonkamboonseng': 'moonkamboonseng',
#  'moonlight': 'moonlight',
#  'moonmeander': 'moonmeander',
#  'mozun': 'mozun',
#  'mp': 'mp',
#  'mrliukeal': 'lpc',
#  'mrrr': 'mrrr',
#  'mss': 'mss',
#  'mtr': 'mtr',
#  'mtrix4u': 'mtrx4u',
#  'mtrx4u': 'mtrx4u',
#  'mu': 'mu',
#  'mushi': 'mushi',
#  'musica': 'musica',
#  'mydreamlife': 'mdlalperenarslan',
#  'mynuts': 'mynuts',
#  'mypro': 'mypro',
#  'n0fear': 'nofear',
#  'n0tail': 'n0tail',
#  'nafari': 'nafari',
#  'nahaz': 'nahaz',
#  'nana': 'moonkamboonseng',
#  'nando': 'nando',
#  'nb': 'ninjaboogie',
#  'near': 'near',
#  'ned': 'nedbone',
#  'nedbone': 'nedbone',
#  'nemphy': 'nemphy',
#  'neo': 'sag',
#  'neqroman': 'neqroman',
#  'netplayer': 'netplayer',
#  'newsham': 'newsham',
#  'nexus': 'nexus',
#  'nfr': 'nafari',
#  'nikobaby': 'nikobaby',
#  'nine': 'nine',
#  'ninjaboogie': 'ninjaboogie',
#  'niqua': 'niqua',
#  'nisha': 'nisha',
#  'nix': 'nix',
#  'nj': 'nj',
#  'nochanc3': 'nochanc3',
#  'nofear': 'nofear',
#  'noia': 'noia',
#  'nokky': 'nokky',
#  'nono': 'nono',
#  'noone': 'noone',
#  'notail': 'n0tail',
#  'nox': 'frost',
#  'noxville': 'noxville',
#  'noxvilleza': 'noxville',
#  'ns': 'ns',
#  'nuts': 'mynuts',
#  'nutz': 'nutz',
#  'nuz': 'lanm',
#  'odpixel': 'odpixel',
#  'ohaiyo': 'ohaiyo',
#  'ohy': 'ohaiyo',
#  'oldchicken': 'oldchicken',
#  'oldeleven': 'eleven',
#  'omegapwner': 'omegapwner',
#  'op': 'op',
#  'ori': 'ori',
#  'origami': 'origami',
#  'owa': 'owa',
#  'oy': 'boombell',
#  'paada': 'paada',
#  'pablo': 'pablo',
#  'pain': 'pain',
#  'pajkatt': 'pajkatt',
#  'palantimos': 'palantimos',
#  'pandaego': 'pandaego',
#  'paparazi': 'paparazi灬',
#  'paparazi灬': 'paparazi灬',
#  'papita': 'papita',
#  'paris': 'paris',
#  'pas': 'pas',
#  'patos': 'patos',
#  'patsoul': 'patsoul',
#  'pegasus': 'demon',
#  'pgg': 'pgg',
#  'piao': 'piao',
#  'pikachu': 'pikachu',
#  'pimpmuckl': 'pimpmuckl',
#  'pingvincek': 'pingvincek',
#  'pinoy': 'pinoy',
#  'pis': 'yaphets',
#  'playhard': 'playhard',
#  'plt': 'lanm',
#  'plzgogame': 'pgg',
#  'polo': 'raven',
#  'poloson': 'poloson',
#  'ppd': 'ppd',
#  'prettyhaw': 'prettyhaw',
#  'primo': 'primo',
#  'psm': 'psm',
#  'puertea': 'puertea',
#  'puppey': 'puppey',
#  'puretea': 'puertea',
#  'purgecaster': 'purgekevingodec',
#  'purgekevingodec': 'purgekevingodec',
#  'pwn': 'pwn',
#  'pyrionflax': 'pyrionflax',
#  'q': 'q',
#  'qigugu': 'another',
#  'qo': 'qo',
#  'qqq': 'qqq',
#  'qwista': 'qwista',
#  'rabbit': 'rabbit',
#  'ragingpotato': 'bimbo',
#  'rampage': 'rampage',
#  'ramzes': 'ramzes666',
#  'ramzes666': 'ramzes666',
#  'ran': 'ran',
#  'rapy': 'rapy',
#  'raven': 'raven',
#  'rayur': 'rayuur',
#  'rayuur': 'rayuur',
#  'realaxxx': 'realaxxx',
#  'red': 'red',
#  'redeye': 'redeye',
#  'reesion': 'reesion',
#  'reisen': 'reisen',
#  'resolut1on': 'resolut1on',
#  'resolution': 'resolut1on',
#  'resonance': 'minerva',
#  'retribution': 'retribution',
#  'rime': 'rime',
#  'riser': 'riser',
#  'ritsu': 'ritsu',
#  'rmn': 'rmn',
#  'roddgee': 'roddgeee',
#  'roddgeee': 'roddgeee',
#  'rodjer': 'rodjer',
#  'rong': 'rong',
#  'rose': '1437',
#  'rotk': 'rotk',
#  'rotkxb': 'rotk',
#  'rr': 'rr',
#  'rtz': 'arteezy',
#  'runec': 'runec',
#  'ryo': 'ryoyr',
#  'ryoya': 'ryoya',
#  'ryoyr': 'ryoyr',
#  'ryuu': 'ryuuboruz',
#  'ryuuboruz': 'ryuuboruz',
#  'ryuya': 'ryuya',
#  'ryze': 'ryze',
#  's224j': 'skanks224',
#  's4': 's4',
#  'sag': 'sag',
#  'sakata': 'fran',
#  'saksa': 'saksa',
#  'sala': 'paparazi灬',
#  'samh': 'samh',
#  'sangsang': 'white',
#  'sanke': 'sanke',
#  'sansheng': 'sansheng',
#  'santa': 'santa',
#  'scabo': 'scabo',
#  'scabomütze': 'scabo',
#  'scandal': 'scandal',
#  'sccc': 'sccc',
#  'scofield': 'scofield',
#  'scripted': 'scripted',
#  'se7en': 'liekkas',
#  'sealkid': 'sealkid',
#  'sedoy': 'sedoy',
#  'select': 'select',
#  'seleri': 'seleri',
#  'sen': 'guvara',
#  'sep': 'september',
#  'september': 'september',
#  'setsu': 'shade',
#  'sevenchineseplayer': 'liekkas',
#  'sexybamboe': 'sexybamboe',
#  'sguali': 'li',
#  'sh4doweh': 'sh4dowehhh',
#  'sh4dowehhh': 'sh4dowehhh',
#  'shachlo': 'shachlo',
#  'shade': 'shade',
#  'shadowplayer': 'shadowplayer',
#  'shane': 'shaneomad',
#  'shaneomad': 'shaneomad',
#  'shangtou': 'agressif',
#  'sharky': 'sharky',
#  'sheever': 'sheever',
#  'sheezry': 'dreamyu',
#  'shiibbyy': 'shiibbyy',
#  'shiki': 'shiki',
#  'shining': 'shining',
#  'silent': 'silent',
#  'simbaaa': 'fly',
#  'sing': 'singsing',
#  'singsing': 'singsing',
#  'siractionslacks': 'siractionslacks',
#  'sixsixsix': 'ramzes666',
#  'skanks224': 'skanks224',
#  'skemberlu': 'skemberlu',
#  'skrff': 'skrff',
#  'skylark': 'skylark',
#  'slander': 'slander',
#  'slashstrike': 'slashstrike',
#  'slayer': 'slayer',
#  'slickz': 'slickz',
#  'smallrong': 'rong',
#  'smash': 'smash',
#  'smile': 'arsart',
#  'sneyking': 'sneyking',
#  'snoopy': 'snoopy',
#  'sockshka': 'paris',
#  'solen': 'solen',
#  'solo': 'solo',
#  'sololineabuse': 'solo',
#  'somnus': 'maybe',
#  'somnus丶m': 'maybe',
#  'sonneiko': 'sonneiko',
#  'sora': 'atun',
#  'sryfox': 'red',
#  'staba': 'staba',
#  'stinger': 'stinger',
#  'stst': 'taiga',
#  'sugarbaby': 'sugarbaby',
#  'suma1l': 'sumail',
#  'sumail': 'sumail',
#  'sune': 'sune',
#  'sunlight': 'sunlight',
#  'sunsfan': 'sunsfan',
#  'super': 'super',
#  'superpengsu': 'supersupeng',
#  'supersupeng': 'supersupeng',
#  'svg': 'svg',
#  'swiftending': 'swiftending',
#  'swindle': 'melonzz',
#  'swindlemelonzz': 'melonzz',
#  'swindlezz': 'melonzz',
#  'sydm': 'mikasa',
#  'syeonix': 'syeonix',
#  'sylar': 'sylar',
#  'synderen': 'synderen',
#  'taiga': 'taiga',
#  'tamemywild': 'crazy',
#  'tavo': 'tavo',
#  'tc': 'tc',
#  'teehee': 'teehee',
#  'thebigbadbird': 'eagle',
#  'thecapitalist': 'capitalist',
#  'thecoon': '33',
#  'therence': 'therence',
#  'thiolicor': 'thiolicor',
#  'tidesoftime': 'tidesoftime',
#  'timado': 'timado',
#  'tims': 'tims',
#  'tmw': 'crazy',
#  'tobi': 'tobiwan',
#  'tobiwan': 'tobiwan',
#  'tratata': 'vigoss',
#  'trixi': 'trixi',
#  'tudi': 'tudi',
#  'twitchtvw33haa': 'w33',
#  'undersh0ck': 'undershock',
#  'undershock': 'undershock',
#  'universe': 'universe',
#  'userevilbloodyrabbitbullseye': 'solo',
#  'userklasynky': 'klasynky',
#  'userlerlergg': 'lergg',
#  'userseavesillusionist': 'illusionist',
#  'userw11woaville': 'aville',
#  'uuu9': 'moogy',
#  'v0ja': 'v0ja',
#  'v1lat': 'v1lat',
#  'vandersar': 'vandersar',
#  'vann': 'vann',
#  'vanskor': 'vanskor',
#  'vash': 'jessievash',
#  'velo': 'velo',
#  'victoria': 'victoria',
#  'vigoss': 'vigoss',
#  'w33': 'w33',
#  'w33haa': 'w33',
#  'waixi': 'waixi',
#  'warnut': 'nutz',
#  'warnutz': 'nutz',
#  'wayto': 'waytosexy',
#  'waytosexy': 'waytosexy',
#  'wejustzik': 'wejustzik',
#  'weppas': 'weppas',
#  'whisper': 'lin',
#  'white': 'white',
#  'winter': 'winter',
#  'wwd': 'wwd',
#  'wwiewambo': 'wwiewambo',
#  'wyt': 'liekkas',
#  'wzayac': 'zayac',
#  'x': 'mmy',
#  'xakoh': 'xakoh',
#  'xboct': 'xboct',
#  'xcalibur': 'excalibur',
#  'xepher': 'xepher',
#  'xfreedom': 'xfreedom',
#  'xi': 'luo',
#  'xiao2le': 'xiao2lei',
#  'xiao2lei': 'xiao2lei',
#  'xiao8': 'xiao8',
#  'xiaod': 'yao',
#  'xiaogongzhu': 'james',
#  'xiaotuji': 'rabbit',
#  'xltt': 'chaoyue',
#  'xmusica': 'musica',
#  'xrag': 'xrag',
#  'xran': 'ran',
#  'xtinct': 'xtinct',
#  'xxs': 'xxs',
#  'xy': 'xy',
#  'xz': 'xz',
#  'y': 'y',
#  'yabyoo': 'yabyoo',
#  'yaj': 'yaj',
#  'yang': 'yang',
#  'yangzhouhaiyang': 'yang',
#  'yao': 'yao',
#  'yaphets': 'yaphets',
#  'yapzor': 'yapzor',
#  'yim': 'yim',
#  'yinnocence': 'y',
#  'yj': 'end',
#  'yoky': 'yoky',
#  'yol': 'yol',
#  'yrg': 'rampage',
#  'ysimlvvivi': 'shadowplayer',
#  'yui': 'yui',
#  'yuno': 'paparazi灬',
#  'yyf': 'yyf',
#  'zai': 'zai',
#  'zayac': 'zayac',
#  'zeroperfect': 'zeroperfect',
#  'zexbingo': 'zexbingo',
#  'zhou': 'zhou',
#  'zp': 'zeroperfect',
#  'zrd': 'faithbian',
#  'zsmj': 'zsmj',
#  'ztok': 'ztok',
#  'zy': 'blink',
#  'zyf': 'end',
#  'zyori': 'zyori',
#  'zyp': 'y',
#  'женя': 'женя',
#  '上头': 'agressif',
#  '嘉嘉': 'jiajia',
#  '小红': 'red',
#  '幼崽': 'another',
#  '折纸折纸': 'origami',
#  '机枪兵': 'op',
#  '跳刀跳刀': 'blink',
#  '跳刀跳刀丶': 'blink',
#  '闷油瓶': '闷油瓶',
#  '队长给我球': 'q',
#  '飘杰': 'piao'}

# %%
 json.get('query').get('results')['N0tail']

# %%
len(df)

# %%
def AlternateIdDict(AlternateIdDict, json):
    for pageid, ldata in json.get('query').get('pages').items():
        mainid = easyText(ldata['title'])
        try:
            AlternateIdDict[mainid] = mainid
            for altid in ldata['redirects']:
                AlternateIdDict[easyText(altid['title'])] = mainid
        except KeyError:
            AlternateIdDict[mainid] = mainid
    return AlternateIdDict

# %%
df['idlow'] = df.id

# %%
df.idlow = df.idlow.str.replace(r'\W+', '').str.lower()

# %%
df[df['player'] == 'kpii']

# %%
df.to_csv('idanddob.csv', index=False)
