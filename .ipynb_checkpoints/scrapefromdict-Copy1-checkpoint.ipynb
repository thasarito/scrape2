# %%
from datetime import datetime
import requests
import numpy as np
import pandas as pd
import yaml
import re
from bs4 import BeautifulSoup
import wikitextparser as wtp
from ratelimit import rate_limited
from operator import *

def save_obj(obj, name ):
    import pickle
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
        
def load_obj(name ):
    import pickle
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# def parseSquadandPrize(tourdict):
#     '''
#     input: title of tournament
#     output: dictionary of participants of that tournament
#     '''
#     json = tourdict['wikitext']
#     wiki = json.get('parse').get('wikitext').get('*')
#     wiki = re.sub('\n', '', wiki)
#     parsed = wtp.parse(wiki)
#     templates = parsed.templates
#     squad = {}
#     for t in templates:
#         if str(t)[:11] == '{{TeamCard|':
#             for ar in t.arguments:
#                 if (str(ar)[:5] == '|team'):
#                     teamname = re.sub(r'\W+', '', ar.value).lower()
#                     squad[teamname] = {}
#                 for i in range(1, 6):
#                     if (str(ar)[:4] == '|p' + str(i) + '='):
#                         pid = re.sub(r'\W+', '', ar.value).lower()
#                         try:
#                             pid = AlternateIdDict[re.sub(r'\W+', '', ar.value).lower()]
#                         except KeyError:
#                             pid = re.sub(r'\W+', '', ar.value).lower()
#                         squad[teamname]['pos' + str(i)] = re.sub(r'\W+', '', pid).lower()
#                     if (str(ar)[:7] == '|p' + str(i) + 'link'):
#                         squad[teamname]['pos' + str(i)] = squad[teamname]['pos' + str(i)] + ' haslink'
#         if str(t)[:12] == '{{prize pool':
#             for ar in t.arguments:
#                 if (str(ar)[:6] == '|place'):
#                     place = ar.value
#                 if (str(ar)[:9] == '|usdprize'):
#                     usdprize = ar.value
#                 if str(ar)[1:] == ar.value:
#                     teamshort = re.sub(r' ', '', ar.value)
#                     try:
#                         teamEz = teamEasy[teamshort]
#                     except KeyError:
#                         teamEz = teamshort
#                     teamEz = re.sub(r'\W+|_', '', teamEz).lower()
#                     try:
#                         squad[teamEz]['usdprize'] = usdprize
#                         squad[teamEz]['place'] = place
#                     except KeyError:
#                         continue
#     return squad

# %%
def parseSquadandPrize(tourdict):
    '''
    input: title of tournament
    output: dictionary of participants of that tournament
    '''
    json = tourdict['wikitext']
    wiki = json.get('parse').get('wikitext').get('*')
    wiki = re.sub('\n', '', wiki)
    parsed = wtp.parse(wiki)
    templates = parsed.templates
    squad = {}
    listteamprize = []
    for t in templates:
        if str(t)[:12] == '{{prize pool':
            for ar in t.arguments:
                if (str(ar)[:6] == '|place'):
                    place = ar.value
                if (str(ar)[:9] == '|usdprize'):
                    usdprize = ar.value           
                if str(ar)[1:] == ar.value:
                    teamshort = re.sub(r' ', '', ar.value)
                    try:
                        teamEz = teamEasy[teamshort]
                    except KeyError:
                        teamEz = teamshort
                    teamEz = re.sub(r'\W+|_', '', teamEz).lower()
                    try:
                        squad[teamEz] = {}
                        listteamprize.append(teamEz)
                        squad[teamEz]['usdprize'] = usdprize
                        squad[teamEz]['place'] = place
                    except KeyError:
                        continue 
        if str(t)[:11] == '{{TeamCard|':
            for ar in t.arguments:
                if (str(ar)[:5] == '|team'):
                    teamname = re.sub(r'\W+', '', ar.value).lower()
                    here = False
                    try:
                        squad[teamname]
                    except KeyError:
                        for teamprize in listteamprize:
                            if (teamname in teamprize) or (teamprize in teamname):
                                squad[teamname] = squad[teamprize]
                                here = True
                                break
                        if not here:
                            print(teamname)
                            print(listteamprize)
                            ip = input()
                            if ip == 'break':
                                break
                            squad[teamname] = squad[ip]
                            here = False
                for i in range(1, 6):
                    if (str(ar)[:4] == '|p' + str(i) + '='): 
                        pid = re.sub(r'\W+', '', ar.value).lower()
                        try:
                            pid = AlternateIdDict[re.sub(r'\W+', '', ar.value).lower()]
                        except KeyError:
                            pid = re.sub(r'\W+', '', ar.value).lower()
                        squad[teamname]['pos' + str(i)] = re.sub(r'\W+', '', pid).lower()
                    if (str(ar)[:7] == '|p' + str(i) + 'link'):
                        squad[teamname]['pos' + str(i)] = squad[teamname]['pos' + str(i)] + ' haslink'                                          
    return squad

# %%
tourdict = load_obj('forelo/' + re.sub(r'\W+', '', '2013 WPC ACE Dota 2 League'.lower() ))

# %%
json = tourdict['wikitext']
wiki = json.get('parse').get('wikitext').get('*')
wiki = re.sub('\n', '', wiki)
parsed = wtp.parse(wiki)
templates = parsed.templates
squad = {}
listteamprize = []
for t in templates:
    if str(t)[:12] == '{{prize pool':
        for ar in t.arguments:
            if (str(ar)[:6] == '|place'):
                place = ar.value
            if (str(ar)[:9] == '|usdprize'):
                usdprize = ar.value           
            if str(ar)[1:] == ar.value:
                teamshort = re.sub(r' ', '', ar.value)
                try:
                    teamEz = teamEasy[teamshort]
                except KeyError:
                    teamEz = teamshort
                teamEz = re.sub(r'\W+|_', '', teamEz).lower()
                try:
                    squad[teamEz] = {}
                    listteamprize.append(teamEz)
                    squad[teamEz]['usdprize'] = usdprize
                    squad[teamEz]['place'] = place
                except KeyError:
                    continue 
    if str(t)[:11] == '{{TeamCard|':
        for ar in t.arguments:
            if (str(ar)[:5] == '|team'):
                teamname = re.sub(r'\W+', '', ar.value).lower()
                here = False
                try:
                    squad[teamname]
                except KeyError:
                    for teamprize in listteamprize:
                        if (teamname in teamprize) or (teamprize in teamname):
                            squad[teamname] = squad[teamprize]
                            here = True
                            break
                    if not here:
                        print(teamname)
                        print(listteamprize)
                        ip = input()
                        if ip == 'break':
                            break
                        squad[teamname] = squad[ip]
                        here = False
            for i in range(1, 6):
                if (str(ar)[:4] == '|p' + str(i) + '='): 
                    pid = re.sub(r'\W+', '', ar.value).lower()
                    try:
                        pid = AlternateIdDict[re.sub(r'\W+', '', ar.value).lower()]
                    except KeyError:
                        pid = re.sub(r'\W+', '', ar.value).lower()
                    squad[teamname]['pos' + str(i)] = re.sub(r'\W+', '', pid).lower()
                if (str(ar)[:7] == '|p' + str(i) + 'link'):
                    squad[teamname]['pos' + str(i)] = squad[teamname]['pos' + str(i)] + ' haslink'
# Out:
# heartgettogether
# ['teamdk', 'invictusgaming', 'vicigaming', 'lgdgaming', 'tongfu', 'lgdinternational', 'risingstars', 'rattlesnake', 'hypergloryteam', 'tongfuwanzhou']
# hypergloryteam

# %%
squad
# Out:
# {'heartgettogether': {'place': '7-10',
#   'pos1': 'xiaolv',
#   'pos2': 'red',
#   'pos3': 'seven haslink',
#   'pos4': 'xy',
#   'pos5': 'cyss',
#   'usdprize': '3,305.60 '},
#  'hypergloryteam': {'place': '7-10',
#   'pos1': 'xiaolv',
#   'pos2': 'red',
#   'pos3': 'seven haslink',
#   'pos4': 'xy',
#   'pos5': 'cyss',
#   'usdprize': '3,305.60 '},
#  'invictusgaming': {'place': '2 ',
#   'pos1': 'hao',
#   'pos2': 'ferrari_430',
#   'pos3': 'yyf',
#   'pos4': 'banana',
#   'pos5': 'faith',
#   'usdprize': '49,584 '},
#  'lgdgaming': {'place': '4 ',
#   'pos1': 'rabbit',
#   'pos2': 'xiao8',
#   'pos3': 'yao',
#   'pos4': 'ddc',
#   'pos5': 'dd',
#   'usdprize': '3,305.60 '},
#  'lgdinternational': {'place': '5-6 ',
#   'pos1': 'black',
#   'pos2': 'pajkatt',
#   'pos3': 'misery',
#   'pos4': 'brax',
#   'pos5': 'xfreedom',
#   'usdprize': '3,305.60 '},
#  'rattlesnake': {'place': '7-10',
#   'pos1': 'luo',
#   'pos2': 'johnny',
#   'pos3': 'icy',
#   'pos4': 'lin',
#   'pos5': 'sag',
#   'usdprize': '3,305.60 '},
#  'risingstars': {'place': '7-10',
#   'pos1': 'meracle',
#   'pos2': 'cty',
#   'pos3': 'kingj',
#   'pos4': 'qqq',
#   'pos5': 'xdd',
#   'usdprize': '3,305.60 '},
#  'teamdk': {'place': '1 ',
#   'pos1': 'burning',
#   'pos2': 'mushi',
#   'pos3': 'iceiceice',
#   'pos4': 'lanm',
#   'pos5': 'mmy',
#   'usdprize': '165,280 '},
#  'tongfu': {'place': '5-6 ',
#   'pos1': 'zhou',
#   'pos2': 'mu',
#   'pos3': 'xtt',
#   'pos4': 'zsmj',
#   'pos5': 'sansheng',
#   'usdprize': '3,305.60 '},
#  'tongfuwanzhou': {'place': '7-10',
#   'pos1': 'cjz',
#   'pos2': 'moogy',
#   'pos3': 'mtsty',
#   'pos4': 'an',
#   'pos5': 'merry',
#   'usdprize': '3,305.60 '},
#  'vicigaming': {'place': '3 ',
#   'pos1': 'mikasa',
#   'pos2': 'super',
#   'pos3': 'rotk',
#   'pos4': 'fenrir',
#   'pos5': 'fy',
#   'usdprize': '16,528 '}}

# %%
for lqn, pdc in squad.items():
    try:
        teamName = comparedict[lqn]
    except KeyError:
        teamName = lqn
    j = 0
    place = pdc.pop('place')
    prize = pdc.pop('usdprize')
    for srt in startelodict:
        for ert in endelodict:
            if (teamName == re.sub(r'\W+', '', srt['teamName']).lower()) & (teamName == re.sub(r'\W+', '', ert['teamName']).lower()):
                j += 1
                for pos, id in pdc.items():
                    df = df.append({
                        'team': teamName,
                        'pos': pos,
                        'id': id,
                        'tour': ifd['title'],
                        'prizepool': ifd['prize'],
                        'place': place,
                        'prize': prize,
                        'start': ifd['start'],
                        'end': ifd['end'],
                        'startelo': srt['elo64']['current'],
                        'startglicko2mu': srt['glicko2']['mu'],
                        'startglicko2phi': srt['glicko2']['phi'],
                        'startglicko2rating': srt['glicko2']['rating'],
                        'endelo': ert['elo64']['current'],
                        'endglicko2mu': ert['glicko2']['mu'],
                        'endglicko2phi': ert['glicko2']['phi'],
                        'endglicko2rating': ert['glicko2']['rating']
                    }, ignore_index=True)
    if j == 0:
        for pos, id in pdc.items():
            if id == '':
                continue
            else:
                df = df.append({
                    'team': teamName,
                    'pos': pos,
                    'id': id,
                    'tour': ifd['title'],
                    'prizepool': ifd['prize'],
                    'place': place,
                    'prize': prize,                        
                    'start': ifd['start'],
                    'end': ifd['end'],
                    'startelo': np.nan,
                    'startglicko2mu': np.nan,
                    'startglicko2phi': np.nan,
                    'startglicko2rating': np.nan,
                    'endelo': np.nan,
                    'endglicko2mu': np.nan,
                    'endglicko2phi': np.nan,
                    'endglicko2rating': np.nan
                }, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-247-5b4b01cdc804> in <module>()
#       5         teamName = lqn
#       6     j = 0
# ----> 7     place = pdc.pop('place')
#       8     prize = pdc.pop('usdprize')
#       9     for srt in startelodict:
#
# KeyError: 'place'

# %%
df
# Out:
#                 team   pos             id                        tour  \
# 0             teamdk  pos1        burning  2013 WPC ACE Dota 2 League
# 1             teamdk  pos2          mushi  2013 WPC ACE Dota 2 League
# 2             teamdk  pos3      iceiceice  2013 WPC ACE Dota 2 League
# 3             teamdk  pos4           lanm  2013 WPC ACE Dota 2 League
# 4             teamdk  pos5            mmy  2013 WPC ACE Dota 2 League
# 5     invictusgaming  pos1            hao  2013 WPC ACE Dota 2 League
# 6     invictusgaming  pos2    ferrari_430  2013 WPC ACE Dota 2 League
# 7     invictusgaming  pos3            yyf  2013 WPC ACE Dota 2 League
# 8     invictusgaming  pos4         banana  2013 WPC ACE Dota 2 League
# 9     invictusgaming  pos5          faith  2013 WPC ACE Dota 2 League
# 10        vicigaming  pos1         mikasa  2013 WPC ACE Dota 2 League
# 11        vicigaming  pos2          super  2013 WPC ACE Dota 2 League
# 12        vicigaming  pos3           rotk  2013 WPC ACE Dota 2 League
# 13        vicigaming  pos4         fenrir  2013 WPC ACE Dota 2 League
# 14        vicigaming  pos5             fy  2013 WPC ACE Dota 2 League
# 15         lgdgaming  pos1         rabbit  2013 WPC ACE Dota 2 League
# 16         lgdgaming  pos2          xiao8  2013 WPC ACE Dota 2 League
# 17         lgdgaming  pos3            yao  2013 WPC ACE Dota 2 League
# 18         lgdgaming  pos4            ddc  2013 WPC ACE Dota 2 League
# 19         lgdgaming  pos5             dd  2013 WPC ACE Dota 2 League
# 20            tongfu  pos1           zhou  2013 WPC ACE Dota 2 League
# 21            tongfu  pos2             mu  2013 WPC ACE Dota 2 League
# 22            tongfu  pos3            xtt  2013 WPC ACE Dota 2 League
# 23            tongfu  pos4           zsmj  2013 WPC ACE Dota 2 League
# 24            tongfu  pos5       sansheng  2013 WPC ACE Dota 2 League
# 25  lgdinternational  pos1          black  2013 WPC ACE Dota 2 League
# 26  lgdinternational  pos2        pajkatt  2013 WPC ACE Dota 2 League
# 27  lgdinternational  pos3         misery  2013 WPC ACE Dota 2 League
# 28  lgdinternational  pos4           brax  2013 WPC ACE Dota 2 League
# 29  lgdinternational  pos5       xfreedom  2013 WPC ACE Dota 2 League
# 30       risingstars  pos1        meracle  2013 WPC ACE Dota 2 League
# 31       risingstars  pos2            cty  2013 WPC ACE Dota 2 League
# 32       risingstars  pos3          kingj  2013 WPC ACE Dota 2 League
# 33       risingstars  pos4            qqq  2013 WPC ACE Dota 2 League
# 34       risingstars  pos5            xdd  2013 WPC ACE Dota 2 League
# 35       rattlesnake  pos1            luo  2013 WPC ACE Dota 2 League
# 36       rattlesnake  pos2         johnny  2013 WPC ACE Dota 2 League
# 37       rattlesnake  pos3            icy  2013 WPC ACE Dota 2 League
# 38       rattlesnake  pos4            lin  2013 WPC ACE Dota 2 League
# 39       rattlesnake  pos5            sag  2013 WPC ACE Dota 2 League
# 40    hypergloryteam  pos1         xiaolv  2013 WPC ACE Dota 2 League
# 41    hypergloryteam  pos2            red  2013 WPC ACE Dota 2 League
# 42    hypergloryteam  pos3  seven haslink  2013 WPC ACE Dota 2 League
# 43    hypergloryteam  pos4             xy  2013 WPC ACE Dota 2 League
# 44    hypergloryteam  pos5           cyss  2013 WPC ACE Dota 2 League
# 45     tongfuwanzhou  pos1            cjz  2013 WPC ACE Dota 2 League
# 46     tongfuwanzhou  pos2          moogy  2013 WPC ACE Dota 2 League
# 47     tongfuwanzhou  pos3          mtsty  2013 WPC ACE Dota 2 League
# 48     tongfuwanzhou  pos4             an  2013 WPC ACE Dota 2 League
# 49     tongfuwanzhou  pos5          merry  2013 WPC ACE Dota 2 League
#
#    prizepool place      prize       start         end     startelo  \
# 0     247920    1    165,280   22/09/2013  01/01/2014          NaN
# 1     247920    1    165,280   22/09/2013  01/01/2014          NaN
# 2     247920    1    165,280   22/09/2013  01/01/2014          NaN
# 3     247920    1    165,280   22/09/2013  01/01/2014          NaN
# 4     247920    1    165,280   22/09/2013  01/01/2014          NaN
# 5     247920    2     49,584   22/09/2013  01/01/2014  1308.652268
# 6     247920    2     49,584   22/09/2013  01/01/2014  1308.652268
# 7     247920    2     49,584   22/09/2013  01/01/2014  1308.652268
# 8     247920    2     49,584   22/09/2013  01/01/2014  1308.652268
# 9     247920    2     49,584   22/09/2013  01/01/2014  1308.652268
# 10    247920    3     16,528   22/09/2013  01/01/2014  1161.996451
# 11    247920    3     16,528   22/09/2013  01/01/2014  1161.996451
# 12    247920    3     16,528   22/09/2013  01/01/2014  1161.996451
# 13    247920    3     16,528   22/09/2013  01/01/2014  1161.996451
# 14    247920    3     16,528   22/09/2013  01/01/2014  1161.996451
# 15    247920    4   3,305.60   22/09/2013  01/01/2014  1143.366931
# 16    247920    4   3,305.60   22/09/2013  01/01/2014  1143.366931
# 17    247920    4   3,305.60   22/09/2013  01/01/2014  1143.366931
# 18    247920    4   3,305.60   22/09/2013  01/01/2014  1143.366931
# 19    247920    4   3,305.60   22/09/2013  01/01/2014  1143.366931
# 20    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 21    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 22    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 23    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 24    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 25    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 26    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 27    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 28    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 29    247920  5-6   3,305.60   22/09/2013  01/01/2014          NaN
# 30    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 31    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 32    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 33    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 34    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 35    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 36    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 37    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 38    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 39    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 40    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 41    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 42    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 43    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 44    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 45    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 46    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 47    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 48    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
# 49    247920  7-10  3,305.60   22/09/2013  01/01/2014          NaN
#
#     startglicko2mu  startglicko2phi  startglicko2rating       endelo  \
# 0              NaN              NaN                 NaN          NaN
# 1              NaN              NaN                 NaN          NaN
# 2              NaN              NaN                 NaN          NaN
# 3              NaN              NaN                 NaN          NaN
# 4              NaN              NaN                 NaN          NaN
# 5      1805.174940        46.594590         1688.688466  1419.738737
# 6      1805.174940        46.594590         1688.688466  1419.738737
# 7      1805.174940        46.594590         1688.688466  1419.738737
# 8      1805.174940        46.594590         1688.688466  1419.738737
# 9      1805.174940        46.594590         1688.688466  1419.738737
# 10     1742.083194        68.089501         1571.859442  1333.029995
# 11     1742.083194        68.089501         1571.859442  1333.029995
# 12     1742.083194        68.089501         1571.859442  1333.029995
# 13     1742.083194        68.089501         1571.859442  1333.029995
# 14     1742.083194        68.089501         1571.859442  1333.029995
# 15     1797.687595        44.943471         1685.328918  1202.543102
# 16     1797.687595        44.943471         1685.328918  1202.543102
# 17     1797.687595        44.943471         1685.328918  1202.543102
# 18     1797.687595        44.943471         1685.328918  1202.543102
# 19     1797.687595        44.943471         1685.328918  1202.543102
# 20             NaN              NaN                 NaN          NaN
# 21             NaN              NaN                 NaN          NaN
# 22             NaN              NaN                 NaN          NaN
# 23             NaN              NaN                 NaN          NaN
# 24             NaN              NaN                 NaN          NaN
# 25             NaN              NaN                 NaN          NaN
# 26             NaN              NaN                 NaN          NaN
# 27             NaN              NaN                 NaN          NaN
# 28             NaN              NaN                 NaN          NaN
# 29             NaN              NaN                 NaN          NaN
# 30             NaN              NaN                 NaN          NaN
# 31             NaN              NaN                 NaN          NaN
# 32             NaN              NaN                 NaN          NaN
# 33             NaN              NaN                 NaN          NaN
# 34             NaN              NaN                 NaN          NaN
# 35             NaN              NaN                 NaN          NaN
# 36             NaN              NaN                 NaN          NaN
# 37             NaN              NaN                 NaN          NaN
# 38             NaN              NaN                 NaN          NaN
# 39             NaN              NaN                 NaN          NaN
# 40             NaN              NaN                 NaN          NaN
# 41             NaN              NaN                 NaN          NaN
# 42             NaN              NaN                 NaN          NaN
# 43             NaN              NaN                 NaN          NaN
# 44             NaN              NaN                 NaN          NaN
# 45             NaN              NaN                 NaN          NaN
# 46             NaN              NaN                 NaN          NaN
# 47             NaN              NaN                 NaN          NaN
# 48             NaN              NaN                 NaN          NaN
# 49             NaN              NaN                 NaN          NaN
#
#     endglicko2mu  endglicko2phi  endglicko2rating
# 0            NaN            NaN               NaN
# 1            NaN            NaN               NaN
# 2            NaN            NaN               NaN
# 3            NaN            NaN               NaN
# 4            NaN            NaN               NaN
# 5    1852.291497      37.107515       1759.522708
# 6    1852.291497      37.107515       1759.522708
# 7    1852.291497      37.107515       1759.522708
# 8    1852.291497      37.107515       1759.522708
# 9    1852.291497      37.107515       1759.522708
# 10   1852.656054      39.053085       1755.023341
# 11   1852.656054      39.053085       1755.023341
# 12   1852.656054      39.053085       1755.023341
# 13   1852.656054      39.053085       1755.023341
# 14   1852.656054      39.053085       1755.023341
# 15   1830.067954      38.108197       1734.797461
# 16   1830.067954      38.108197       1734.797461
# 17   1830.067954      38.108197       1734.797461
# 18   1830.067954      38.108197       1734.797461
# 19   1830.067954      38.108197       1734.797461
# 20           NaN            NaN               NaN
# 21           NaN            NaN               NaN
# 22           NaN            NaN               NaN
# 23           NaN            NaN               NaN
# 24           NaN            NaN               NaN
# 25           NaN            NaN               NaN
# 26           NaN            NaN               NaN
# 27           NaN            NaN               NaN
# 28           NaN            NaN               NaN
# 29           NaN            NaN               NaN
# 30           NaN            NaN               NaN
# 31           NaN            NaN               NaN
# 32           NaN            NaN               NaN
# 33           NaN            NaN               NaN
# 34           NaN            NaN               NaN
# 35           NaN            NaN               NaN
# 36           NaN            NaN               NaN
# 37           NaN            NaN               NaN
# 38           NaN            NaN               NaN
# 39           NaN            NaN               NaN
# 40           NaN            NaN               NaN
# 41           NaN            NaN               NaN
# 42           NaN            NaN               NaN
# 43           NaN            NaN               NaN
# 44           NaN            NaN               NaN
# 45           NaN            NaN               NaN
# 46           NaN            NaN               NaN
# 47           NaN            NaN               NaN
# 48           NaN            NaN               NaN
# 49           NaN            NaN               NaN

# %%
def getEloDict(tourdict):
    return (tourdict['startelodict'], tourdict['endelodict'])

# %%
def compareAndPut(df, squad, ifd, startelodict, endelodict):
    for lqn, pdc in squad.items():
        try:
            teamName = comparedict[lqn]
        except KeyError:
            teamName = lqn
        j = 0
        place = pdc.pop('place')
        prize = pdc.pop('usdprize')
        for srt in startelodict:
            for ert in endelodict:
                if (teamName == re.sub(r'\W+', '', srt['teamName']).lower()) & (teamName == re.sub(r'\W+', '', ert['teamName']).lower()):
                    j += 1
                    for pos, id in pdc.items():
                        df = df.append({
                            'team': teamName,
                            'pos': pos,
                            'id': id,
                            'tour': ifd['title'],
                            'prizepool': ifd['prize'],
                            'place': place,
                            'prize': prize,
                            'start': ifd['start'],
                            'end': ifd['end'],
                            'startelo': srt['elo64']['current'],
                            'startglicko2mu': srt['glicko2']['mu'],
                            'startglicko2phi': srt['glicko2']['phi'],
                            'startglicko2rating': srt['glicko2']['rating'],
                            'endelo': ert['elo64']['current'],
                            'endglicko2mu': ert['glicko2']['mu'],
                            'endglicko2phi': ert['glicko2']['phi'],
                            'endglicko2rating': ert['glicko2']['rating']
                        }, ignore_index=True)
        if j == 0:
            for pos, id in pdc.items():
                if id == '':
                    continue
                else:
                    df = df.append({
                        'team': teamName,
                        'pos': pos,
                        'id': id,
                        'tour': ifd['title'],
                        'prizepool': ifd['prize'],
                        'place': place,
                        'prize': prize,                        
                        'start': ifd['start'],
                        'end': ifd['end'],
                        'startelo': np.nan,
                        'startglicko2mu': np.nan,
                        'startglicko2phi': np.nan,
                        'startglicko2rating': np.nan,
                        'endelo': np.nan,
                        'endglicko2mu': np.nan,
                        'endglicko2phi': np.nan,
                        'endglicko2rating': np.nan
                    }, ignore_index=True)
        
    return df

# %%
alltour2 = {}

# %%
alltour2['2013 WPC ACE Dota 2 League'] = alltour['2013 WPC ACE Dota 2 League']

# %%
alltour2
# Out:
# {'2013 WPC ACE Dota 2 League': {'end': '01/01/2014',
#   'prize': 247920,
#   'start': '22/09/2013',
#   'title': '2013 WPC ACE Dota 2 League'}}

# %%
alltour = load_obj('/dict/touranddate')
comparedict = load_obj('/dict/lqtodat')
AlternateIdDict = load_obj('/dict/AlternateIdDict')

# %%
endti2 = '2012-09-02'
endti7 = '2017-08-12'

# %%
ifd
# Out:
# {'end': '21/10/2012',
#  'prize': 15000,
#  'start': '17/09/2012',
#  'title': 'StarLadder StarSeries Season 3'}

# %%
# %%time
errortitle = []
df = pd.DataFrame(columns=['team', 'pos', 'id', 'tour', 'prizepool', 'place', 'prize', 'start', 'end',
                           'startelo', 'startglicko2mu', 'startglicko2phi', 'startglicko2rating', 'endelo', 'endglicko2mu', 'endglicko2phi', 'endglicko2rating'])
for turl, ifd in alltour2.items():
    try:
        if (pd.to_datetime(ifd['start'], format='%d/%m/%Y') > pd.to_datetime(endti2)) & (pd.to_datetime(ifd['end'], format='%d/%m/%Y') <= pd.to_datetime(endti7)):
            easyTourTitle = re.sub(r'\W+', '', ifd['title']).lower()
            tourdict = load_obj('forelo/' + easyTourTitle )
            ptc = parseSquadandPrize(tourdict)
            startelodict, endelodict = getEloDict(tourdict)
            print(ifd)
            df = compareAndPut(df, ptc, ifd, startelodict, endelodict)
    except:
        print(turl)
        errortitle = errortitle.append(turl)
# Out:
# heartgettogether
# ['teamdk', 'invictusgaming', 'vicigaming', 'lgdgaming', 'tongfu', 'lgdinternational', 'risingstars', 'rattlesnake', 'hypergloryteam', 'tongfuwanzhou']
# hypergloryteam
# {'title': '2013 WPC ACE Dota 2 League', 'start': '22/09/2013', 'end': '01/01/2014', 'prize': 247920}
# 2013 WPC ACE Dota 2 League
# Wall time: 3.43 s

# %%
df
# Out:
# Empty DataFrame
# Columns: [team, pos, id, tour, prizepool, place, prize, start, end, startelo, startglicko2mu, startglicko2phi, startglicko2rating, endelo, endglicko2mu, endglicko2phi, endglicko2rating]
# Index: []

# %%
#Clean Data
df = df[df['id'] != '']
df.loc[(df['id'] == 'g haslink'), 'id'] = 'g'
df.loc[(df['id'] == 'noone haslink'), 'id'] = 'noone'
df.loc[(df['id'].str[:8] == 'paparazi'), 'id'] = 'paparazi'
df.pos = pd.to_numeric(df.pos.str[-1])

# %%
#df[['team', 'pos', 'id', 'tour', 'prizeusd', 'start', 'startelo', 'end', 'endelo']].to_csv('elo.csv', encoding='utf-8', index=False)
#df[['team', 'pos', 'id', 'tour', 'prizeusd', 'start', 'startglicko2mu', 'startglicko2phi', 'startglicko2rating', 'end', 'endglicko2mu', 'endglicko2phi', 'endglicko2rating']].to_csv('glicko.csv', encoding='utf-8', index=False)

# %%
# %%time
errortitle = []
for turl, ifd in alltour.items():
    try:
        if (pd.to_datetime(ifd['start'], format='%d/%m/%Y') > pd.to_datetime(endti2)) & (pd.to_datetime(ifd['end'], format='%d/%m/%Y') <= pd.to_datetime(endti7)):
            easyTourTitle = re.sub(r'\W+', '', ifd['title']).lower()
            tourdict = load_obj('forelo/' + easyTourTitle )
            json = tourdict['wikitext']
            wiki = json.get('parse').get('wikitext').get('*')
            wiki = re.sub('\n', '', wiki)
            parsed = wtp.parse(wiki)
            templates = parsed.templates
            squad = {}
            listteamcard = []
            listteamprize = []            
            for t in templates:
                if str(t)[:11] == '{{TeamCard|':
                    for ar in t.arguments:
                        if (str(ar)[:5] == '|team'):
                            teamname = re.sub(r'\W+', '', ar.value).lower()
                            listteamcard.append(teamname)
                if str(t)[:12] == '{{prize pool':
                    for ar in t.arguments:
                        if (str(ar)[:6] == '|place'):
                            place = ar.value
                        if (str(ar)[:9] == '|usdprize'):
                            usdprize = ar.value           
                        if str(ar)[1:] == ar.value:
                            teamshort = re.sub(r' ', '', ar.value)
                            try:
                                teamEz = teamEasy[teamshort]
                            except KeyError:
                                teamEz = teamshort
                            listteamprize.append(re.sub(r'\W+|_', '', teamEz).lower())
        has = set(listteamprize).intersection(listteamcard)
        set(listteamprize).difference(has)
        print(easyTourTitle)
        print('team that match         : ' + str(has))
        print('listteamprize not match : ' + str(set(listteamprize).difference(has)))
        print('listteamcard not match  : ' + str(set(listteamcard).difference(has)))
        print('-' * 10)

    except:
        print(turl)
        errortitle = errortitle.append(turl)
# Out:
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# wcgasianchampionship2012
# team that match         : {'ampmwonosobo', 'lof', 'mineski', '1stvn', 'orangeesports'}
# listteamprize not match : {'mith', 'veilteam'}
# listteamcard not match  : {'mithtrust', 'veil'}
# ----------
# raidcalldota2leagueseason1
# team that match         : {'teamempire', 'quanticgaming', 'fnatic', 'pulseesports', 'wehazasian', 'teamdignitas', 'evilgeniuses', 'teamzero'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# starladderstarseriesseason3
# team that match         : {'virtuspro', 'meetyourmakers', 'teamempire', 'natusvincere', 'pulseesports', 'moscowfive'}
# listteamprize not match : {'gdteam'}
# listteamcard not match  : {'absolutelegends', 'thegdbteam'}
# ----------
# gosuleagueseason4
# team that match         : set()
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# gosuleagueseason4division1
# team that match         : {'meetyourmakers', 'gamersleague', 'darer', 'natusvincere', 'teamshakira', 'nextkz', 'mousesports', 'kaipi'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# thepremierleagueseason3
# team that match         : {'absolutelegends', 'meetyourmakers', 'eclypsia', 'teamempire', 'virtuspro', 'notidehunter', 'fnatic', 'pulseesports', 'mousesports', 'teamdignitas'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# g1championsleagueseason4
# team that match         : {'ftfc', 'lgdgaming', 'tongfu', 'natural9', 'invictusgaming', 'evilgeniuses', 'mufc', 'orangeesports', 'teamdk'}
# listteamprize not match : {'flash'}
# listteamcard not match  : {'flashesports'}
# ----------
# electronicsportsworldcup2012
# team that match         : {'worldwargame', 'natusvincere', 'teamshakira', 'imaginarygaming', 'baranetgaming', 'scutagaming', 'teamdignitas', 'casualgaming'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# gosuleagueseason5
# team that match         : set()
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# gosuleagueseason5division1
# team that match         : {'teamempire', 'natusvincere', 'pulseesports', 'dddota', 'nextkz', 'mousesports', 'kaipi', 'svenhunterz'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# starladderstarseriesseason4
# team that match         : {'absolutelegends', 'virtuspro', 'teamempire', 'notidehunter', 'natusvincere', 'fnatic', 'pulseesports', 'iluminate', 'dddota', 'xx5gaming', 'wehazasian', 'mousesports', '3dmax', 'svenhunterz', 'lionspride'}
# listteamprize not match : {'fubar'}
# listteamcard not match  : {'sfubars'}
# ----------
# dreamhackwinter2012
# team that match         : {'absolutelegends', 'teamempire', 'skyhigh', 'notidehunter', 'natusvincere', 'fnatic', 'pulseesports', '3dmax', 'wehazasian', 'mousesports', '4friendschrillee', 'sweetnchina', 'teamdignitas', 'evilgeniuses'}
# listteamprize not match : {'r3d', 'oot'}
# listteamcard not match  : {'outoftangos', 'rigg3d'}
# ----------
# thedefenseseason3
# team that match         : {'natusvincere', 'neximpetus', 'paingaming', 'rootgaming', 'wehazasian', 'romyandtherest', 'gameruniversity', 'kaipi', 'fnaticna', 'notidehunter', 'redefiningmadness', 'mousesports', '4friendschrillee', 'iccup', 'absolutelegends', 'hwagaming', 'dddota', '3dmax', 'teamdignitas', 'lionspride', 'evilgeniuses', 'virtuspro', 'teamempire', 'nextkz', 'teamliquid', 'wheninmood', 'turtlemasters', 'svenhunterz', 'qwert12345', 'baguette'}
# listteamprize not match : {'fnatic', 'xx5'}
# listteamcard not match  : {'xx5gaming', 'fnaticeu'}
# ----------
# worldcybergames2012
# team that match         : {'lof', 'devilmice', 'invictusgaming', 'mousesports', 'uashechki', 'elitehomeplayers', 'orangeesports', 'teamdk'}
# listteamprize not match : {'mineskikorea'}
# listteamcard not match  : {'mineskikor'}
# ----------
# thoropen2012
# team that match         : {'fnatic', '4friendschrillee', 'pulseesports', 'notidehunter'}
# listteamprize not match : set()
# listteamcard not match  : {'outoftangos', 'rootgaming', 'teamgo', 'gamdota'}
# ----------
# raidcalldota2leagueseason2
# team that match         : {'virtuspro', 'teamempire', 'notidehunter', 'natusvincere', 'dddota', 'redefiningmadness', 'teamliquid', 'mousesports', '3dmax', 'teamdignitas', 'evilgeniuses'}
# listteamprize not match : {'fnatic'}
# listteamcard not match  : {'fnaticeu'}
# ----------
# asusopen2012finals
# team that match         : {'virtuspro', 'teamempire', 'natusvincere', 'wzrivpaketi', 'iluminate', 'iccup'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# theasia2012
# team that match         : {'lgdgaming', 'teamzenith', 'pagibigtnc', 'teamrevival', 'joenet', 'natural9', '1stvn', 'mufc', 'orangeesports'}
# listteamprize not match : {'mith', 'elunes'}
# listteamcard not match  : {'mithtrust', 'teamelunes'}
# ----------
# gleague2012season2
# team that match         : {'vicigaming', 'lgdgaming', 'lgdinternational', 'tongfu', 'invictusgaming', 'mufc', 'teamdk', 'forlove'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# thepremierleagueseason4
# team that match         : {'absolutelegends', 'virtuspro', 'teamempire', 'teamliquid', 'alliance', 'mousesports', 'kaipi', 'teamdignitas', 'rox'}
# listteamprize not match : {'fnatic'}
# listteamcard not match  : {'fnaticeu'}
# ----------
# starladderstarseriesseason5
# team that match         : {'absolutelegends', 'virtuspro', 'teamempire', 'powerrangers', 'notidehunter', 'natusvincere', '4friendschrillee', '3dclan', 'dddota', 'tcmgaming', 'rox', 'freedomoftheaction', 'mousesports', '3dmax', 'lionspride'}
# listteamprize not match : {'fnatic'}
# listteamcard not match  : {'fnaticeu'}
# ----------
# armaggeddondota2grandslamasia2013
# team that match         : {'awake', 'applebananacucumber'}
# listteamprize not match : {'departure'}
# listteamcard not match  : {'harrosh', 'gizmogaming', 'genuinenessofgeeks', 'gameware', 'firstdeparture', 'thekade', 'neolutionindonesia', 'sobliquegamings', 'pacificesports', 'srinbins', 'tlerreborn', 'gangsterblaque'}
# ----------
# weplaydota2leagueseason1
# team that match         : {'natusvincere', 'qpadredpandas', 'teamliquid', 'alliance', 'mousesports', 'teamdignitas', 'evilgeniuses'}
# listteamprize not match : {'skilldifference', 'aurochs', 'tcmgaming', 'keitagaming', 'alacademy', 'rootgaming', 'kaipi', 'fnaticna', 'rox', 'netolic', 'dust', 'eosin', 'theretry', '4friendschrillee', 'artykgaming', 'iccup', 'absolutelegends', 'isurus', 'fnatic', 'ratinthedark', 'imperium', '3dmax', 'lionspride', 'teamempire', 'nextkz'}
# listteamcard not match  : {'fnaticeu'}
# ----------
# dreamhackdota2invitational
# team that match         : set()
# listteamprize not match : set()
# listteamcard not match  : {'virtuspro', 'teamempire', 'qpadredpandas', 'fnaticeu', 'teamliquid', 'alliance', 'mousesports', 'teamdignitas'}
# ----------
# g1championsleagueseason5
# team that match         : {'lgdgaming', 'teamliquid', 'alliance', 'invictusgaming', 'orangeesports', 'teamdk'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# raidcallemsonespringseason
# team that match         : {'absolutelegends', 'virtuspro', 'teamempire', 'natusvincere', 'ratinthedark', 'teamliquid', 'tcmgaming', 'alliance', 'mousesports', 'kaipi', 'fnaticna', 'rox'}
# listteamprize not match : {'fnatic', 'eosin', 'infinity', 'dd'}
# listteamcard not match  : {'eosin4', 'dddota', 'fnaticeu', 'infinitygaming'}
# ----------
# ritmixrussiandota2league
# team that match         : {'virtuspro', 'teamempire', 'notidehunter', 'teamliquid', 'mousesports', 'teamdignitas', 'rox'}
# listteamprize not match : {'fnatic'}
# listteamcard not match  : {'fnaticeu'}
# ----------
# techlabscup2013season1
# team that match         : {'virtuspro', 'teamempire', 'iccup', 'natusvincere'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# cursedota2invitational
# team that match         : {'teamempire', 'natusvincere', 'qpadredpandas', 'teamliquid', 'mousesports', 'evilgeniuses', 'teamdignitas', 'rox'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# amdpremierleagueseason1
# team that match         : {'teamzenith', 'tongfu', 'risingstars', 'mufc'}
# listteamprize not match : set()
# listteamcard not match  : {'mineski', 'tellmewhy', 'firstdeparture', 'invasionesports', 'tncproteam', 'akma', 'orangeesports', 'vicigaming', 'sunnysideup', 'mithtrust', 'rattlesnake', 'joenet', 'neolutioninternational', 'malayallstars', 'netolicsg', 'gameware'}
# ----------
# dota2superleague
# team that match         : {'vicigaming', 'lgdgaming', 'lgdinternational', 'risingstars', 'tongfu', 'rattlesnake', 'invictusgaming', 'orangeesports', 'teamdk', 'forlove'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# rapturegamingnetworkleague20132014
# team that match         : {'awake', 'teamzenith', 'mineski', 'risingstars', 'rattlesnake', 'titan', 'firstdeparture', 'teamimpervious', 'orangeesports'}
# listteamprize not match : {'mith'}
# listteamcard not match  : {'mithtrust'}
# ----------
# starladderstarseriesseason6
# team that match         : {'virtuspro', 'teamempire', 'powerrangers', 'kaipi', 'natusvincere', 'fnatic', 'quanticgaming', 'zrage', 'qpadredpandas', 'tcmgaming', 'oslikgaming', 'alliance', 'mousesports', '4friendschrillee', 'iccup'}
# listteamprize not match : {'rox'}
# listteamcard not match  : {'roxkis'}
# ----------
# thepremierleagueseason5
# team that match         : {'virtuspro', 'alliance', 'mousesports', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# raidcalldota2leagueseason3
# team that match         : {'virtuspro', 'natusvincere', 'fnatic', 'teamliquid', 'alliance', 'mousesports', 'teamdignitas', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# thedefenseseason4
# team that match         : {'absolutelegends', 'virtuspro', 'teamempire', 'quanticgaming', 'fnatic', 'natusvincere', '4friendschrillee', 'zrage', 'nextkz', 'lionspride', 'teamliquid', 'keitagaming', 'alliance', 'mousesports', 'kaipi', 'artykgaming', 'teamdignitas', 'evilgeniuses', 'iccup'}
# listteamprize not match : {'rox'}
# listteamcard not match  : {'roxkis'}
# ----------
# americandotaleagueseason1
# team that match         : {'smeagol', 'teamliquid', 'denialesports', 'paingaming', 'insightesports', 'typicalmistakes', 'teamdignitas', 'evilgeniuses'}
# listteamprize not match : {'painint'}
# listteamcard not match  : {'paingamingint'}
# ----------
# dreamhacksummer2013
# team that match         : {'virtuspro', 'uebelstgamyng', 'natusvincere', 'fnatic', 'quanticgaming', 'lionspride', 'teamliquid', 'tcmgaming', 'keitagaming', 'alliance', 'infernitygaming', 'mousesports', 'flipsid3tactics', '4friendschrillee', 'teamdignitas', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# alienwarecup
# team that match         : {'teamzenith', 'lgdgaming', 'lgdinternational', 'natusvincere', 'rattlesnake', 'tongfu', 'invictusgaming', 'mufc', 'orangeesports', 'teamdk'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# raidcallemsonesummerseason
# team that match         : {'fnatic', 'dargoneblaydes', 'ratinthedark', 'imaginarygaming', 'infernitygaming', 'mousesports', 'flipsid3tactics', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : {'4friendschrillee', 'quanticgaming', 'keitagaming', 'alliance', 'netolicgaming', 'rox'}
# ----------
# corsairgamingsummertournament2013
# team that match         : {'fnatic', 'virtuspro', 'mousesports'}
# listteamprize not match : set()
# listteamcard not match  : {'uebelstgamyng', 'roxkis', 'keitagaming', 'tcmgaming', 'kaipi', 'teamdignitas', 'evilgeniuses', 'teamempire', 'nextkz', 'denialesports', 'flipsid3tactics', '4friendschrillee', 'iccup'}
# ----------
# nexonstarterleague
# team that match         : {'fxopenesports', 'symphony', 'birdgang', 'dcrux', 'bestmagicskill', 'deserteagle', 'eyesoftiger', 'kelloggtigerpower'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# e2maxl33tchampionship
# team that match         : {'joenet', 'orangeesports'}
# listteamprize not match : {'mith', 'teamzenith'}
# listteamcard not match  : {'zenith', 'mineski', 'firstdeparture', 'myonmyon', 'insidiousidol', 'mufc', 'isgvindicate', 'mithtrust', 'ultimate', 'lowyatnetesports2', 'lowyatnetesports', 'netolicsg', 'duskbin', 'ipod2'}
# ----------
# redbullecl2013dota2season
# team that match         : {'vicigaming', 'lgdgaming', 'lgdinternational', 'risingstars', 'tongfu', 'rattlesnake', 'esportsmuxi', 'royalclub', 'invictusgaming', 'orangeesports', 'teamdk'}
# listteamprize not match : {'xpy'}
# listteamcard not match  : {'xiaopengyou'}
# ----------
# amdpremierleagueseason2
# team that match         : {'vicigaming', 'fxopenesports', 'teamzenith', 'mineski', 'risingstars', 'rattlesnake', 'esportsmuxi', 'tellmewhy', 'joenet', '1stvn', 'mufc', 'orangeesports', 'neoesg7'}
# listteamprize not match : {'mith', 'gizmo', 'netolic'}
# listteamcard not match  : {'mithtrust', 'netolicgaming', 'gizmogaming'}
# ----------
# theinternational2013
# team that match         : {'orangeesports', 'virtuspro', 'teamzenith', 'lgdgaming', 'lgdinternational', 'tongfu', 'fnatic', 'rattlesnake', 'natusvincere', 'teamliquid', 'alliance', 'invictusgaming', 'mousesports', 'mufc', 'teamdignitas', 'teamdk'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# theinternational2013solotournament
# team that match         : set()
# listteamprize not match : {'s4', 'mu', 'xiao8', 'mushi', 'fata', 'ferrari430', 'dendi', 'iceiceice'}
# listteamcard not match  : set()
# ----------
# theinternational2013allstarmatch
# team that match         : {'internationalallstarteama', 'internationalallstarteamb'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# techlabscup2013season2
# team that match         : {'terribleterribledamage', 'powerrangers', 'rox', 'cascade'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# starladderstarseriesseason7
# team that match         : {'virtuspro', 'teamempire', 'powerrangers', 'natusvincere', 'fnatic', 'quanticgaming', 'nextkz', 'teammenacefi', 'aspera', 'alliance', 'poseidon', '4friendschrillee', 'rattlesnakeint', 'rox'}
# listteamprize not match : {'uebelst', 'duzagaming'}
# listteamcard not match  : {'uebelstgamyng', 'duza'}
# ----------
# raidcallemsonefallseason
# team that match         : {'vicigaming', 'natusvincere', 'fnatic', 'sigmaint', 'teamone', 'startale', 'alliance', 'teamaaa'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# sinacupsupernovadota2openseason1
# team that match         : {'lgdgaming', 'invictusgaming', 'tongfu'}
# listteamprize not match : set()
# listteamcard not match  : {'vicigaming', 'mineski', 'ogurayui', 'rattlesnake', 'newelement'}
# ----------
# weplaydota2leagueseason2
# team that match         : {'virtuspro', 'teamempire', 'speedgamingint', 'natusvincere', 'fnatic', 'revengeesports', 'dts2010', 'nextkz', 'poseidon', 'teamliquid', 'theretry', 'scaryfacez', 'alliance', 'rox', 'flipsid3tactics', '4friendschrillee', 'cascade', 'teamdignitas', 'evilgeniuses'}
# listteamprize not match : {'ssd'}
# listteamcard not match  : {'superstrongdinosaurs'}
# ----------
# 2013wpcacedota2league
# team that match         : {'vicigaming', 'lgdgaming', 'lgdinternational', 'risingstars', 'tongfu', 'rattlesnake', 'tongfuwanzhou', 'invictusgaming', 'teamdk'}
# listteamprize not match : {'hypergloryteam'}
# listteamcard not match  : {'heartgettogether'}
# ----------
# techlabscup2013season3
# team that match         : {'almet', 'powerrangers', 'natusvincere'}
# listteamprize not match : {'dd'}
# listteamcard not match  : {'dddota'}
# ----------
# nexonsponsorshipleagueseason1
# team that match         : {'ave', 'moonlightunited', 'aceonline', 'mvphot6ix', 'startale', 'forourutopia', 'eyesoftiger', 'seasonone', 'fastgg', 'underrateds', 'sushiandyasha', 'virtualthrone'}
# listteamprize not match : {'symphony', 'njkids', 'victorylight', 'placebum'}
# listteamcard not match  : {'svictorylights', 'splacebums', 'symphonydota', 'teamnjkids'}
# ----------
# dota2championsleagueseason1
# team that match         : {'virtuspro', 'speedgamingint', 'natusvincere', 'fnatic', 'sigmaint', 'teamliquid', 'alliance', 'mousesports', 'teamdignitas', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# mlgfallinvitational
# team that match         : {'typicalmistakes', 'nom', 'teamdignitas'}
# listteamprize not match : {'joikernaught'}
# listteamcard not match  : {'thejoikernaught'}
# ----------
# fragbitemasters2013
# team that match         : {'speedgamingint', 'fiskestanga', 'youboat', 'qpadredpandas', 'ursastroithramm', 'warmaker', 'powerrangers', 'saftkalaspojkarna', 'alliance', 'mousesports', '4friendschrillee', 'fnatic', 'terribleterribledamage', 'cedenullis', 'sigmaint', 'gabepls', 'sigmafr', 'teamdignitas', 'evilgeniuses', 'virtuspro', 'nobigdeal', 'aheadgaming', 'stayfree', 'heheunited', 'teammenacefi', 'turtlemasters', 'duzagaming'}
# listteamprize not match : {'prop', 'ssd', 'gillette', 'kawaii', 'rox'}
# listteamcard not match  : {'superstrongdinosaurs', 'teamproperty', 'roxkis', 'mycarrycantbethiskawaii', 'teamgillette'}
# ----------
# electronicsportsworldcup2013
# team that match         : {'minion', 'teamempire', 'energyesports', 'anarchist', 'sigmaint', 'insightesports', 'teammuhan', 'zerorespect', 'teamaaa', '4friendschrillee', 'reasongaming', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# asusrogdreamleaguekickoffseason
# team that match         : {'virtuspro', 'natusvincere', 'fnatic', 'teamliquid', 'alliance', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# nationalelectronicsportstournament2013
# team that match         : {'vicigaming', 'lgdgaming', 'risingstars', 'tongfu', 'rattlesnake', 'invictusgaming', 'goatishsoul', 'teamdk'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# techlabscup2013grandfinals
# team that match         : {'virtuspro', 'teamempire', 'powerrangers', 'natusvincere'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# mlgchampionshipcolumbus
# team that match         : {'speedgamingint', 'natusvincere', 'fnatic', 'teamdk', 'sigmaint', 'teamliquid', 'prettyboyswag', 'alliance', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# starladderstarseriesseason8
# team that match         : {'virtuspro', 'teamempire', 'powerrangers', 'natusvincere', 'fnatic', 'qpadredpandas', 'nextkz', 'sigmaint', 'aspera', 'theretry', 'oslikgaming', 'alliance', 'mousesports', 'poseidon', '4friendschrillee', 'rox'}
# listteamprize not match : {'f3ru', 'ssd'}
# listteamcard not match  : {'flipsid3ru', 'superstrongdinosaurs'}
# ----------
# sinacupsupernovadota2openseason2
# team that match         : {'vicigaming', 'lgdgaming', 'lgdinternational', 'tongfu', 'newelement', 'titan', 'dtclub', 'tongfuwanzhou', 'invictusgaming', 'teamdk', 'forlove'}
# listteamprize not match : {'hypergloryteam'}
# listteamcard not match  : {'heartgettogether'}
# ----------
# nexonsponsorshipleagueseason2
# team that match         : {'5inqo', 'mvpphoenix', 'mvphot6ix', 'forourutopia', 'eyesoftiger', 'fulltilt', 'nonstopdominate', 'virtualthrone'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# netolicproleague4west
# team that match         : {'fnatic', 'mousesports'}
# listteamprize not match : {'rox'}
# listteamcard not match  : {'virtuspro', 'superstrongdinosaurs', 'teamempire', 'revengeesports', 'roxkis', 'evilgeniuses'}
# ----------
# gleague2013
# team that match         : {'vicigaming', 'lgdgaming', 'speedgamingint', 'tongfu', 'titan', 'dtclub', 'invictusgaming', 'teamdk'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# fengyundota2tournament
# team that match         : {'vicigaming', 'mvpphoenix', 'lgdgaming', 'speedgamingint', 'teamsubvert', 'tongfu', 'newelement', 'titan', 'dtclub', 'firstdeparture', 'tongfuwanzhou', 'startale', 'invictusgaming', 'teamdk', 'forlove'}
# listteamprize not match : {'hypergloryteam'}
# listteamcard not match  : {'heartgettogether'}
# ----------
# asiancybergames
# team that match         : {'mineski', 'titan', 'startale', 'spiritgaming', 'rexregum'}
# listteamprize not match : {'mith', 'oblique', 'revival', 'fd'}
# listteamcard not match  : {'mithtrust', 'teamrevival', 'firstdeparture', 'obliquegaming'}
# ----------
# redbullecl2013grandfinals
# team that match         : {'titan', 'invictusgaming', 'teamdk', 'tongfu'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# pinnaclesportsproam
# team that match         : {'sigmaint'}
# listteamprize not match : {'rox'}
# listteamcard not match  : {'speedgamingint', 'revengeesports', 'fnatic', 'roxkis', 'oslikgaming', 'prettyboyswag', 'teamempire', 'powerrangers', 'heheunited', 'nextkz', 'teamliquid', 'relax', 'mousesports', 'sqreenssquad', '4friendschrillee'}
# ----------
# nexonsponsorshipleagueseason3
# team that match         : {'5inqo', 'mvphot6ix', 'dontdierem1kz', 'eothammer', 'allinuz', 'eotdrill', 'teamangrybird'}
# listteamprize not match : {'zephyr'}
# listteamcard not match  : {'teamzephyr'}
# ----------
# dota2leagueseason4
# team that match         : {'fnatic', 'alliance', 'lgdgaming', 'vicigaming'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# electronicsportsprimeshocktherapycup
# team that match         : {'speedgamingint', 'teamempire', 'fnatic', 'sigmaint', 'teamliquid', 'sadboys', 'teamehug'}
# listteamprize not match : {'rox'}
# listteamcard not match  : {'roxkis'}
# ----------
# mlgtkoeurope
# team that match         : {'virtuspro', 'teamempire', 'powerrangers', 'natusvincere', 'fnatic', 'nextkz', 'sigmaint'}
# listteamprize not match : {'rox'}
# listteamcard not match  : {'roxkis'}
# ----------
# mlgtkoamerica
# team that match         : {'swagenteiger', 'revengeesports', 'cloud9', 'teamliquid', 'denialesports', 'teamehug', 'evilgeniuses'}
# listteamprize not match : {'psst'}
# listteamcard not match  : {'poolsorcerysometangoes'}
# ----------
# dota2championsleagueseason2
# team that match         : {'virtuspro', 'teamempire', 'powerrangers', 'natusvincere', 'fnatic', 'cloud9', 'teamliquid', 'alliance'}
# listteamprize not match : {'rox', 'sigma'}
# listteamcard not match  : {'sigmaint', 'roxkis'}
# ----------
# koreandotaleague
# team that match         : {'mvpphoenix'}
# listteamprize not match : {'zephyr'}
# listteamcard not match  : {'teamzephyr', 'monkeyspanner', 'birdgang', 'teamfw', 'mvphot6ix', 'teamnemesis', 'missionsuccess', 'eothammer', '5inq'}
# ----------
# koreandotaleaguetier1
# team that match         : {'mvpphoenix', 'birdgang'}
# listteamprize not match : {'5inqo', 'zephyr'}
# listteamcard not match  : {'teamzephyr', '5inq'}
# ----------
# xmgcaptainsdraftinvitational
# team that match         : {'fnatic', 'alliance', 'teamliquid', 'natusvincere'}
# listteamprize not match : {'sigmaint', 'rox'}
# listteamcard not match  : {'sigma', 'roxkis'}
# ----------
# netolicproleague5east
# team that match         : {'vicigaming', 'lgdgaming', 'invictusgaming'}
# listteamprize not match : set()
# listteamcard not match  : {'titan', 'cnbcn', 'scythegaming', 'arrowgaming', 'newbee'}
# ----------
# sinacupsupernovadota2openseason3
# team that match         : {'vicigaming', 'lgdgaming', 'newelement', 'titan', 'dtclub', 'cnbcn', 'invictusgaming', 'newbee', 'no8network', 'cisgame', 'teamdk'}
# listteamprize not match : {'hypergloryteam'}
# listteamcard not match  : {'heartgettogether'}
# ----------
# asusrogdreamleagueseason1
# team that match         : {'virtuspro', 'meetyourmakers', 'teamempire', 'natusvincere', 'fnatic', 'cloud9', 'sigmaint', 'teamliquid', 'alliance', 'rox', 'mousesports', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# starladderstarseriesseason9
# team that match         : {'mvpphoenix', 'teamempire', 'natusvincere', 'teamdk', 'alliance', 'rox', 'invictusgaming', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# monsterenergyinvitational
# team that match         : {'cloud9', 'teamliquid', 'teamehug', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# ecl2014spring
# team that match         : {'vicigaming', 'lgdgaming', 'hypergloryteam', 'newelement', 'teamdk', 'dtclub', 'cnbcn', 'speedgamingcn', 'invictusgaming', 'newbee', 'cisgame', 'tongfuwanzhou'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# excellentmoscowcupseason1
# team that match         : {'virtuspro', 'meetyourmakers', 'teamempire', 'powerrangers', 'dreamteam168', 'nextkz', 'oslikgaming', 'relax', 'awaregaming', 'rox'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# wpc2014
# team that match         : {'vicigaming', 'cloud9', 'titan', 'dtclub', 'alliance', 'invictusgaming', 'newbee', 'teamdk'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# hyperxd2lwesternchallenge
# team that match         : {'teamempire', 'natusvincere', 'fnatic', 'cloud9', 'teamliquid', 'alliance', 'evilgeniuses', 'rox'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# fragbitemasters2014
# team that match         : {'meetyourmakers', 'teamempire', 'powerrangers', 'fnatic', 'trickedesport', 'nextkz', 'sigmaint', 'teamliquid', 'vastcast', 'turtlemasters', '4friendschrillee', 'teamdog', 'rox'}
# listteamprize not match : {'mmc'}
# listteamcard not match  : {'monomaniac'}
# ----------
# techlabscup2014season1
# team that match         : {'virtuspro', 'teamempire', 'nextkz', 'rox'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# americandotaleagueseason2
# team that match         : {'isurusgaming', 'osirisgaming', 'uniongaming', 'top5', 'sneakynyxassassins', 'revengeesports', 'shadowsofthepast', 'teamliquid', 'mousesports', 'teamehug'}
# listteamprize not match : {'noearth', 'natusvincerenorthamerica', 'cnb'}
# listteamcard not match  : {'cnbesportsclub', 'noearthspirit', 'navinorthamerica'}
# ----------
# wvwnationalelectronicsportsclassicapril
# team that match         : {'vicigaming', 'talentcn', 'lgdgaming', 'hypergloryteam', 'paacn', 'onmb', 'newelement', 'dtclub', 'abcba', 'ti9champion', 'invictusgaming', 'orenda', 'newbee', 'cisgame', 'tongfuwanzhou', 'blhh'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# dota2championsleagueseason3
# team that match         : {'virtuspro', 'meetyourmakers', 'teamempire', 'powerrangers', 'dreamteam168', 'natusvincere', 'fnatic', 'nextkz', 'alliance', 'rox', 'evilgeniuses'}
# listteamprize not match : {'relax'}
# listteamcard not match  : {'relaxyouredoingfine'}
# ----------
# dreamhackbucharestinvitational
# team that match         : {'fnatic', 'alliance', 'fluffybears', 'cloud9'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# koreadotaleagueseason2
# team that match         : {'mvpphoenix', 'pokerface'}
# listteamprize not match : set()
# listteamcard not match  : {'teamzephyr', 'noanswer', 'monkeyspanner', 'mvphot6ix', 'dagonfive', 'teammuhan', 'rave', 'getouts'}
# ----------
# koreadotaleagueseason2tier1
# team that match         : {'mvpphoenix', 'rave', 'pokerface'}
# listteamprize not match : {'zephyr'}
# listteamcard not match  : {'teamzephyr'}
# ----------
# marstvdota2league2014
# team that match         : {'vicigaming', 'lgdgaming', 'invictusgaming', 'newbee', 'cisgame'}
# listteamprize not match : {'teamdk'}
# listteamcard not match  : {'dk'}
# ----------
# techlabscup2014season2
# team that match         : {'virtuspro', 'relax', 'powerrangers', 'dreamteam168'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# vgamestournament
# team that match         : {'vicigaming', 'lgdgaming', 'hypergloryteam', 'dtclub', 'tongfuwanzhou', 'speedgamingcn', 'invictusgaming', 'orenda', 'lgdcdec', 'newbee', 'cisgame', 'teamdk'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# cdecnewstarchallenge
# team that match         : {'vicigaming', 'wdlu5', 'lgdgaming', 'hypergloryteam', 'dtclub', 'speedgamingcn', 'happyboys', 'invictusgaming', 'lgdcdec', 'newbee', 'teamdk'}
# listteamprize not match : {'tongfuwanzhou'}
# listteamcard not match  : {'tongfu'}
# ----------
# thesummit1
# team that match         : {'vicigaming', 'natusvincere', 'fnatic', 'teamdk', 'evilgeniuses'}
# listteamprize not match : {'natusvincerenorthamerica'}
# listteamcard not match  : {'navinorthamerica'}
# ----------
# wvwnationalelectronicsportsclassicjune
# team that match         : {'vicigaming', 'hypergloryteam', 'lgdgaming', 'dtclub', 'invictusgaming', 'newbee', 'cisgame', 'teamdk'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# gestthechallengejune
# team that match         : {'vicigaming', 'lgdgaming', 'mineski', 'tongfu', 'titan', 'dtclub', 'pokerface', 'scythegaming', 'alapetstric', 'invictusgaming', 'arrowgaming', 'newbee', 'cisgame', 'orangeesports', 'teamdk'}
# listteamprize not match : {'mith'}
# listteamcard not match  : {'mithtrust'}
# ----------
# eslonefrankfurt2014
# team that match         : {'vicigaming', 'natusvincere', 'fnatic', 'cloud9', 'alliance', 'invictusgaming', 'mousesports', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# theinternational2014
# team that match         : {'vicigaming', 'lgdgaming', 'teamempire', 'natusvincere', 'fnatic', 'cloud9', 'titan', 'teamdk', 'teamliquid', 'alliance', 'invictusgaming', 'mousesports', 'arrowgaming', 'newbee', 'evilgeniuses'}
# listteamprize not match : {'natusvincerenorthamerica'}
# listteamcard not match  : {'virtuspro', 'mvpphoenix', 'navinorthamerica', 'cisgame'}
# ----------
# theinternational2014solotournament
# team that match         : set()
# listteamprize not match : {'s4', 'arteezy', 'fy', 'mushi', 'resolut1on', 'ferrari430', 'dendi', 'iceiceice'}
# listteamcard not match  : set()
# ----------
# koreadotaleagueseason3
# team that match         : {'mvpphoenix', 'rave', 'pokerface'}
# listteamprize not match : {'zephyr'}
# listteamcard not match  : {'teamzephyr', 'betboys', 'mvphot6ix', 'monkeyspanner', 'teammuhan', 'lotem', 'getouts'}
# ----------
# ileagueseason1
# team that match         : {'vicigaming', 'virtuspro', 'rave', 'powerrangers', 'oldboys', 'invictusgaming', 'lgdcdec', 'newbee'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# starladderstarseriesseason10
# team that match         : {'virtuspro', 'teamtinker', 'natusvincere', 'cloud9', 'alliance', 'execration', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# megafonbattlearena
# team that match         : {'virtuspro', 'teamempire', 'teamtinker', 'natusvincere'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# excellentmoscowcupseason2
# team that match         : {'hellraisers', 'teamempire', 'natusvincere'}
# listteamprize not match : {'asuspolar'}
# listteamcard not match  : {'virtuspropolar'}
# ----------
# dota2championsleagueseason4
# team that match         : {'teamempire', 'teamtinker', 'sneakynyxassassins'}
# listteamprize not match : {'natusvincere'}
# listteamcard not match  : set()
# ----------
# worldesportchampionships2014
# team that match         : {'vicigaming', 'lgdgaming', 'hypergloryteam', 'natusvincere', 'cloud9', 'lgdcdec', 'newbee', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# sinacupsupernovadota2openseason5
# team that match         : {'vicigaming', 'wdlu5', 'lgdgaming', 'hypergloryteam', 'dreamgaming', 'wingsgaming', 'tongfu', 'laigaming', 'speedgamingcn', 'invictusgaming', 'lgdcdec', 'lvgaming'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# gameshowleagueseason1
# team that match         : {'virtuspro', 'nvmi', 'teamempire', 'hellraisers', 'natusvincere', 'moscowfive'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# ecl2014autumn
# team that match         : {'vicigaming', 'lgdgaming', 'hypergloryteam', 'tongfu', 'laigaming', 'cdecgaming', 'speedgamingcn', 'invictusgaming', 'lvgaming', 'newbee'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# iesfasianchampionships
# team that match         : {'theprime', 'mvpphoenix', 'arcanys', 'msievogt'}
# listteamprize not match : set()
# listteamcard not match  : {'mithtrust', 'themongolz', 'orangeesports', 'mineski'}
# ----------
# nvidiagame24
# team that match         : {'alliance', 'cloud9', 'evilgeniuses', 'teamtinker'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# dotapitleagueseason2
# team that match         : {'virtuspro', 'teamempire', 'powerrangers', 'teamtinker', 'sneakynyxassassins', 'hellraisers', 'cloud9', 'myinsanity', 'denialesports', 'alliance', 'complexitygaming', 'moscowfive', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : {'asuspolar', '4anchors'}
# listteamcard not match  : {'virtuspropolar', '4anchorsseacaptain'}
# ----------
# synergyleagueseason1
# team that match         : set()
# listteamprize not match : {'tbd'}
# listteamcard not match  : {'vicigaming', 'teamempire', 'hellraisers', 'moscowfiveint', 'invasionesports', 'teammalaysia', 'denialesports', 'xgamekz'}
# ----------
# worldcyberarena2014
# team that match         : {'vicigaming', 'lgdgaming', 'natusvincere', 'cloud9', 'teammalaysia', 'alliance', 'invictusgaming', 'newbee'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# asusrogdreamleagueseason2
# team that match         : {'virtuspro', 'mvpphoenix', 'teamtinker', 'virtuspropolar', 'cloud9', 'alliance', 'evilgeniuses'}
# listteamprize not match : {'4asc'}
# listteamcard not match  : {'lgdgaming', 'teamempire', 'sneakynyxassassins', 'fnaticeu', 'complexitygaming', 'invictusgaming', '4anchorsseacaptain', 'xgamekz', 'rave'}
# ----------
# brasilgamecup2014
# team that match         : {'thehouseisdown', 'uniongaming', 'keydstars', 'paingaming', 'nottoday'}
# listteamprize not match : {'intz', 'isurus', 'cnb'}
# listteamcard not match  : {'isurusgaming', 'intzesports', 'cnbesportsclub'}
# ----------
# eslonenewyork2014
# team that match         : {'vicigaming', 'natusvincere', 'sneakynyxassassins', 'cloud9', 'alliance', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : {'natusvincerenorthamerica'}
# listteamcard not match  : {'navinorthamericalinknatusvincerenorthamerica'}
# ----------
# gleague2014
# team that match         : {'hypergloryteam', 'lgdgaming', 'laigaming', 'cdecgaming', 'speedgamingcn', 'invictusgaming', 'lvgaming', 'teamdk'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# koreadotaleagueseason4
# team that match         : {'mvpphoenix', 'mvphot6ix', 'rave', 'pokerface'}
# listteamprize not match : {'zephyr'}
# listteamcard not match  : {'teamzephyr', 'kdl', 'china', 'monkeyspanner', '10eye', 'pota2', 'lotem', 'bminor'}
# ----------
# nationalelectronicsportstournament2014
# team that match         : {'vicigaming', 'wingsgaming', 'lgdgaming', 'newbeeyoung', 'speedgamingcn', 'newbee', 'lvgaming', 'tongfuwanzhou'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# xmgcaptainsdraft20
# team that match         : {'virtuspro', 'powerrangers', 'teamtinker', 'natusvincere', 'alliance', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : {'4anchors'}
# listteamcard not match  : {'4anchorsseacaptain'}
# ----------
# msibeatit2014
# team that match         : {'virtuspro', 'wiredgaming', 'bravadoemotion', 'cdecgaming', 'teamimmunity', 'insidiousidol', 'rave'}
# listteamprize not match : {'natusvincerenorthamerica'}
# listteamcard not match  : {'navinorthamerica'}
# ----------
# battleofcentraleuropeseason3
# team that match         : {'virtuspro', 'powerrangers', 'hellraisers', 'lajons', 'vegasquadron', 'houseofgamers', 'basicallyunknown', 'balkanbears', 'denialesports', 'myinsanity', 'albumsheets', 'cck', 'moscowfive', 'komandaminus'}
# listteamprize not match : {'asuspolar', 'm5int'}
# listteamcard not match  : {'virtuspropolar', 'moscowfiveinternational'}
# ----------
# iesf2014worldchampionship
# team that match         : {'finland', 'mvpphoenix', 'mindsportssouthafrica', 'fiskestanga', 'raze', 'starperci', 'whatateam', 'teamegypt', 'clickstorm', 'wildpandaz', '4friendschrillee', 'newbee', 'romania'}
# listteamprize not match : {'themongolz'}
# listteamcard not match  : {'mongolz'}
# ----------
# starladderstarseriesseason11
# team that match         : {'mvpphoenix', 'ninjasinpyjamas', 'teamempire', 'powerrangers', 'hellraisers', 'virtuspropolar', 'natusvincere'}
# listteamprize not match : {'teamfire'}
# listteamcard not match  : {'fire'}
# ----------
# ileagueseason2
# team that match         : {'vicigaming', 'mvpphoenix', 'ninjasinpyjamas', 'hypergloryteam', 'lgdgaming', 'speedgamingcn', 'invictusgaming', 'biggod'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# esportaldota2league
# team that match         : {'virtuspro', 'teamempire', 'powerrangers', 'vegasquadron', 'hellraisers', 'myinsanity'}
# listteamprize not match : {'4clover', '4anchors'}
# listteamcard not match  : {'4cloverlepricon', '4anchorsseacaptain'}
# ----------
# thesummit2
# team that match         : {'vicigaming', 'teamtinker', 'cloud9', 'nottoday', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : {''}
# listteamcard not match  : set()
# ----------
# nationalelectronicsportsopen2014
# team that match         : {'hypergloryteam', 'lgdgaming', 'newbeeyoung', 'laigaming', 'cdecgaming', 'invictusgaming', 'newbee', 'tongfuwanzhou'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# esportaldota2leagueinvitationaltournament1
# team that match         : {'virtuspro', 'teamempire', 'powerrangers', 'myinsanity', 'balkanbears', 'alliance', '4friendschrillee'}
# listteamprize not match : {'asuspolar'}
# listteamcard not match  : {'virtuspropolar'}
# ----------
# okdota2cup
# team that match         : {'gguardesports', 'mineski', 'kingsurf', 'firstdeparture', 'rexregum', 'insidiousidol', 'acesgaming', 'cantsaywips'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# dota2leagueseason5
# team that match         : {'lvgaming', 'cdecgaming', 'evilgeniuses'}
# listteamprize not match : {'asuspolar'}
# listteamcard not match  : {'virtuspropolar'}
# ----------
# dotapitleagueseason3
# team that match         : {'virtuspro', 'ninjasinpyjamas', 'teamempire', 'powerrangers', 'hellraisers', 'vegasquadron', 'cloud9', 'myinsanity', 'alliance', 'mousesports', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# joindotamlgproleagueseason1
# team that match         : set()
# listteamprize not match : {'mvpphoenix', 'ninjasinpyjamas', 'teamempire', 'nottoday', 'evilgeniuses', 'balkanbears'}
# listteamcard not match  : set()
# ----------
# dota2asiachampionships2015
# team that match         : {'vicigaming', 'mvpphoenix', 'lgdgaming', 'hypergloryteam', 'biggod', 'wingsgaming', 'ehome', 'hellraisers', 'natusvincere', 'cloud9', 'powerrangers', 'cdecgaming', 'tongfuwanzhou', 'speedgamingcn', 'invictusgaming', 'energypacemaker', 'rave', 'newbee', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# dota2championsleagueseason5
# team that match         : {'vicigaming', 'burdenunited', 'ninjasinpyjamas', 'teamempire'}
# listteamprize not match : set()
# listteamcard not match  : {'lgdgaming', 'hypergloryteam', 'powerrangers', 'ehome', 'natusvincere', 'hellraisers', 'vicigamingpotential', 'cdecgaming', 'balkanbears', 'alliance', 'invictusgaming', 'newbee'}
# ----------
# starladderstarseriesseason12
# team that match         : {'vicigaming', 'teamtinker', 'cloud9', 'teammalaysia', 'alliance', 'invictusgaming', 'londonconspiracy', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# majorallstarsdota2tournament
# team that match         : {'ninjasinpyjamas', 'teamempire', 'natusvincere', 'invictusgaming', 'teamredemption', 'rave', 'cantsaywips'}
# listteamprize not match : {'invasion'}
# listteamcard not match  : {'invasionesports'}
# ----------
# asusrogdreamleagueseason3
# team that match         : set()
# listteamprize not match : {'virtuspro', 'ninjasinpyjamas', 'teamempire', 'natusvincere', 'vegasquadron', 'basicallyunknown', 'alliance', 'burdenunited'}
# listteamcard not match  : set()
# ----------
# ileagueseason3
# team that match         : {'vicigaming', 'lgdgaming', 'vicigamingpotential', 'teammalaysia', 'alliance', 'invictusgaming', 'energypacemaker', 'newbee'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# 2015redbullbattlegroundsdota2
# team that match         : set()
# listteamprize not match : set()
# listteamcard not match  : {'summersrift', 'invictusgaming', 'hellraisers', 'teammalaysia', 'teamsecret'}
# ----------
# vpgameproleagueseason1
# team that match         : {'vicigaming', 'lgdgaming', 'hypergloryteam', 'dreamgaming', 'newbee', 'ehome', 'tongfu', 'newbeeyoung', 'cdecgaming', 'energypacemaker', 'invictusgaming', 'terrorblade', 'newbeemiracle', 'braveheart', 'teamdk'}
# listteamprize not match : {'vicigamingpotential'}
# listteamcard not match  : {'vgpotential'}
# ----------
# ecl2015spring
# team that match         : {'vicigaming', 'lgdgaming', 'hypergloryteam', 'dreamgaming', 'ehome', 'tongfu', 'newbeeyoung', 'vicigamingpotential', 'cdecgaming', 'invictusgaming', 'energypacemaker', 'terrorblade', 'newbeemiracle', 'duobao', 'teamdk'}
# listteamprize not match : {'braveheart'}
# listteamcard not match  : {'teambraveheart'}
# ----------
# worldcyberarena2015chineseproqualifiers
# team that match         : {'vicigaming', 'hypergloryteam', 'lgdgaming', 'dreamgaming', 'ehome', 'tongfu', 'newbeeyoung', 'vicigamingpotential', 'cdecgaming', 'energypacemaker', 'invictusgaming', 'newbeemiracle', 'terrorblade', 'newbee', 'teamdk'}
# listteamprize not match : {'braveheart'}
# listteamcard not match  : {'teambraveheart'}
# ----------
# joindotamlgproleagueseason2
# team that match         : {'virtuspro', 'ninjasinpyjamas', 'fnatic', 'summersrift', 'alliance', 'mousesports', 'londonconspiracy', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# rogplayitcooldota2invitational
# team that match         : {'virtuspro', 'alliance', 'ninjasinpyjamas', 'lemondogs'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# worldcyberarena2015americanproqualifiers
# team that match         : {'voidboys', 'teamleviathan', 'nottoday', 'northamericanrejects', 'rootgaming', 'summersrift', 'teamehug', 'wheelwhreckwhilewhistling'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# marstvdota2league2015springchineseleague
# team that match         : {'hypergloryteam', 'ehome', 'tongfu', 'cdecgaming', 'immortalmagnetogaming', 'newbee', 'teamdk'}
# listteamprize not match : {'lgdgaming'}
# listteamcard not match  : {'lgd'}
# ----------
# mpglseason7sea
# team that match         : {'underminer', 'gguardesports', 'mineski', 'mvphot6ix', 'tncproteam', 'ice', 'signaturetrust', 'energypacemaker', '5eva', 'unitedwestand'}
# listteamprize not match : {'rexregum', 'ideal'}
# listteamcard not match  : {'idealesports', 'rexregumqeon'}
# ----------
# gleague2015
# team that match         : {'hypergloryteam', 'lgdgaming', 'tongfu', 'vicigamingpotential', 'cdecgaming', 'energypacemaker', 'immortalmagnetogaming', 'newbee'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# thesummit3
# team that match         : {'vicigaming', 'lgdgaming', 'cloud9', 'nottoday', 'invictusgaming', 'rave', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# marstvdota2league2015spring
# team that match         : {'vicigaming', 'lgdgaming', 'teamempire', 'ehome', 'natusvincere', 'cloud9', 'cdecgaming', 'invictusgaming', 'newbee', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# eslonefrankfurt2015
# team that match         : {'vicigaming', 'virtuspro', 'fnatic', 'cloud9', 'alliance', 'invictusgaming', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# User:Hoperz/VIP LAN CENTER
# theinternational2015
# team that match         : {'vicigaming', 'mvpphoenix', 'lgdgaming', 'teamempire', 'virtuspro', 'ehome', 'natusvincere', 'fnatic', 'cloud9', 'mvphot6ix', 'cdecgaming', 'invictusgaming', 'complexitygaming', 'newbee', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : {'teamarchon', 'vegasquadron'}
# ----------
# thedefenseseason5
# ...
# ----------
# mpglsoutheastasianchampionship
# team that match         : {'mvpphoenix', 'fnatic', 'warriorsgamingunity', 'tangerine', 'signaturetrust', 'whitefriesgaming', 'powergaming', 'ehomekeen', 'execration'}
# listteamprize not match : {'mineski'}
# listteamcard not match  : {'mineskiggnetwork'}
# ----------
# redbullheroicks
# team that match         : set()
# listteamprize not match : set()
# listteamcard not match  : {'', 'alliance', 'og'}
# ----------
# dota2professionalleagueseason2secondary
# team that match         : {'weareyoung', 'tongfu', 'newbeeyoung', 'avalonclub', 'ehomeluminous', 'ehomekeen', 'braveheart', 'duobao'}
# listteamprize not match : {'forthedream', 'vgjthunder'}
# listteamcard not match  : {'ftdcluba', 'teamvgj'}
# ----------
# shanghaidota2open2
# team that match         : {'vicigaming', 'weareyoung', 'longwan', 'newbee', 'ehome', 'tongfu', 'newbeeyoung', 'cdecgaming', 'ehomeluminous', 'invictusgaming', 'ehomex', 'maxx', 'ehomekeen', 'execration', 'igvitality', 'braveheart', 'duobao', 'lgdforeveryoung'}
# listteamprize not match : {'rock16', 'vgjthunder'}
# listteamcard not match  : {'rock', 'teamvgj'}
# ----------
# dota2professionalleagueseason2top
# team that match         : {'vicigaming', 'wingsgaming', 'lgdgaming', 'igvitality', 'ehome', 'cdecgaming', 'invictusgaming', 'ftdclubc', 'newbee', 'lgdforeveryoung'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# marsdota2league2016autumn
# team that match         : {'vicigaming', 'mvpphoenix', 'og', 'igvitality', 'newbee', 'lgdforeveryoung', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# worldcyberarena2016chinesequalifierss3
# team that match         : {'lgdgaming', 'ehome', 'tongfu', 'invictusgaming', 'ehomekeen', 'newbee', 'lgdforeveryoung'}
# listteamprize not match : {'vgjthunder'}
# listteamcard not match  : {'teamvgj'}
# ----------
# worldelectronicsportsgames2016europecisfinals
# team that match         : set()
# listteamprize not match : {'ukraine', 'woof', 'butterflyeffect', 'qlf', 'zerohootsgiven', 'fantasticfive', 'zeta', 'comanche', 'nerusь', 'wombatgaming', 'xenexgaming', 'alternateattax', 'denmark', 'lvlup', 'paragon', 'alliance', 'theimperial', 'necroraisers', 'horde', 'romania'}
# listteamcard not match  : set()
# ----------
# dreamleagueseason6leagueplay
# team that match         : {'virtuspro', 'adfinem', 'vegasquadron', 'teamnp', 'teamliquid', 'alliance', 'theimperial', 'escapegaming'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# nanyangdota2championshipscruisecup1
# team that match         : {'wingsgaming', 'newbee', 'invictusgaming', 'igvitality'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# dota2aceprovisional
# team that match         : {'wingsgaming', 'lgdgaming', 'newbeeyoung', 'maxy', 'duobao', 'vicigaming', 'avalonclub', 'ehomeluminous', 'igvitality', 'ftdclubc', 'cavalry', 'tongfu', 'vicigamingpotential', 'whitefriesgaming', 'ehomekeen', 'newbee', 'lgdforeveryoung', 'weareyoung', 'ehome', 'cdecgaming', 'invictusgaming', 'braveheart'}
# listteamprize not match : {'rg', 'rushb', 'vgjthunder', 'forthedream'}
# listteamcard not match  : {'rushb3349045', 'ftdcluba', 'teamvgj', 'rampagegaming'}
# ----------
# faceitinvitational
# team that match         : {'teamempire', 'og', 'adfinem', 'vegasquadron', 'teamliquid', 'alliance', 'escapegaming', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# worldelectronicsportsgames2016americasfinals
# team that match         : {'infamous', 'kingao4', 'tshow', 'learn2gank', 'rebirthesports', 'teamdilecom'}
# listteamprize not match : {'vultur', 'teamoneec'}
# listteamcard not match  : {'teamoneecuador', 'vulturgaming'}
# ----------
# rogmasters2016
# team that match         : {'themongolz', 'fnatic', 'aggressive5', 'natural9', 'mol', 'bigandblack', 'maxx', 'entityesports', 'execration', 'ehomex', 'teamsecret'}
# listteamprize not match : {'mineski'}
# listteamcard not match  : {'mineskiggnetwork'}
# ----------
# northernarenabeatinvitational
# team that match         : {'wingsgaming', 'ehome', 'adfinem', 'teamnp', 'alliance', 'complexitygaming', 'fdl', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# worldelectronicsportsgames2016asiapacificfinals
# team that match         : {'teamnation', 'mvpphoenix', 's1lykos', 'tobeornottobe', 'iclen', 'slayers', 'tncproteam', 'nextgeneration', 'dateletubbies', 'signaturetrust', 'nolifer5reborn', '90sgaming', 'powergaming', 'mvpaegis', 'maxy', 'detonator'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# worldcyberarena2016amqualifiers
# team that match         : {'uniongamingbo', 'vinceteipsum', 'pichau', 'nottoday', 'resnonverba', 'midasclubelite', 'apologaming', 'alphapro'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# thesummit6
# team that match         : {'wingsgaming', 'virtuspro', 'og', 'ehome', 'teamnp', 'digitalchaos', 'teamfaceless', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# asusrogdreamleagueseason6
# team that match         : {'alliance', 'theimperial', 'teamliquid', 'escapegaming'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# thebostonmajor2016
# team that match         : {'wingsgaming', 'lgdgaming', 'mvpphoenix', 'og', 'virtuspro', 'ehome', 'adfinem', 'igvitality', 'warriorsgamingunity', 'teamnp', 'digitalchaos', 'teamfaceless', 'complexitygaming', 'newbee', 'lgdforeveryoung', 'evilgeniuses'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# worldcyberarena2016
# team that match         : {'vicigaming', 'weareyoung', 'igvitality', 'vegasquadron', 'vinceteipsum', 'warriorsgamingunity', 'tncproteam', 'newbee', 'prodotagaming'}
# listteamprize not match : {'uniongamingbo'}
# listteamcard not match  : set()
# ----------
# chinatop2016
# team that match         : {'wingsgaming', 'newbee', 'evilgeniuses', 'digitalchaos'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# eslonegenting2017
# team that match         : {'wingsgaming', 'virtuspro', 'fnatic', 'warriorsgamingunity', 'teamnp', 'digitalchaos', 'execration', 'newbee'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# worldelectronicsportsgames2016
# team that match         : {'darkpassage', 'tshow', 'tobeornottobe', 'vultur', 'cloud9', 'mvprevolution', 'sgesports', 'tncproteam', 'alliance', 'signaturetrust', 'maxy', 'aboshamalah', 'horde'}
# listteamprize not match : {'infamous', 'ukraine', 'dby', 's1lykos', 'teamoneec', 'teamxbet', 'bravadogaming', 'fantasticfive', 'comanche', 'teamdilecom', 'romania'}
# listteamcard not match  : {'teamoneecuador'}
# ----------
# dotapitleagueseason5
# team that match         : {'virtuspro', 'og', 'digitalchaos', 'invictusgaming', 'teamfaceless', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : {'elementspro'}
# listteamcard not match  : {'elementsprogaming'}
# ----------
# eliminationmode30
# team that match         : {'teamfreedom', 'ninjasinpyjamas', 'og', 'teamonyx', 'wanted', 'adfinem', 'alliance', 'complexitygaming'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# starladderileaguestarseriesseason3
# team that match         : {'wingsgaming', 'og', 'teamliquid', 'tncproteam', 'digitalchaos', 'igvitality', 'teamsecret'}
# listteamprize not match : {'vgjthunder'}
# listteamcard not match  : {'teamvgj'}
# ----------
# dota2professionalleagueseason32017s1top
# team that match         : {'vicigaming', 'wingsgaming', 'lgdgaming', 'igvitality', 'vicigamingpotential', 'cdecgaming', 'invictusgaming', 'ftdclubc', 'ehomekeen', 'newbee', 'lgdforeveryoung'}
# listteamprize not match : {'vgjthunder'}
# listteamcard not match  : {'teamvgj'}
# ----------
# dota2asiachampionships2017
# team that match         : {'wingsgaming', 'teamempire', 'og', 'igvitality', 'teamnp', 'teamliquid', 'teamfaceless', 'invictusgaming', 'newbee', 'lgdforeveryoung', 'evilgeniuses'}
# listteamprize not match : {'vgjthunder'}
# listteamcard not match  : {'teamvgj'}
# ----------
# russianesportscup2017
# team that match         : {'hollow', 'topteam', 'dvk', 'teamspirit', 'piter', 'doteridva', 'friends', 'zeroone', 'sftesports', 'vegasquadron', 'zokengaming', 'maddogsteam', 'laflamme', 'yarosttopora', 'people', 'josskie', 'virtuspro', 'teamempire', 'animaapache', 'gearsofdestraction', 'lifebreake', 'withoutproblems', 'ignoreochir'}
# listteamprize not match : {'elementspro'}
# listteamcard not match  : {'elementsprogaming'}
# ----------
# thekievmajor2017
# team that match         : {'virtuspro', 'teamrandom', 'og', 'igvitality', 'teamliquid', 'tncproteam', 'digitalchaos', 'teamfaceless', 'invictusgaming', 'mousesports', 'newbee', 'sgesports', 'thunderbirds', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : {'vgjthunder'}
# listteamcard not match  : {'teamvgj'}
# ----------
# mrcatinvitationaleurope
# team that match         : {'virtuspro', 'ninjasinpyjamas', 'teamempire', 'vegasquadron', 'cloud9', 'effect', 'teamspirit', 'chip4', 'prodotagaming', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# dreamleagueseason7eudivision
# team that match         : {'virtuspro', 'teamempire', 'natusvincere', 'vegasquadron', 'teamliquid', 'mousesports', 'teamsecret'}
# listteamprize not match : {'elementspro'}
# listteamcard not match  : {'elementsprogaming'}
# ----------
# starladderileagueinvitationalseason2
# team that match         : {'vegasquadron', 'teamliquid', 'tncproteam', 'alliance', 'teamfaceless', 'invictusgaming', 'newbee'}
# listteamprize not match : {'vgjthunder'}
# listteamcard not match  : {'teamvgj'}
# ----------
# themanilamasters
# team that match         : {'og', 'teamnp', 'teamfaceless', 'invictusgaming', 'newbee', 'clutchgamers', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# dreamleagueseason7nadivision
# team that match         : {'teamfreedom', 'planetodd', 'complexitygaming', 'sgesports'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# zotaccupmasters
# team that match         : {'igvitality', 'fnatic', 'warriorsgamingunity', 'teamnp', 'digitalchaos', 'danishbears', 'newbee'}
# listteamprize not match : {'singularityesports'}
# listteamcard not match  : {'teamsingularity'}
# ----------
# epicenter2017
# team that match         : {'virtuspro', 'og', 'natusvincere', 'planetodd', 'teamliquid', 'invictusgaming', 'clutchgamers', 'lgdforeveryoung', 'evilgeniuses', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : {'fillerpick', 'kbu'}
# ----------
# dotasummit7
# team that match         : {'virtuspro', 'lgdgaming', 'teamempire', 'natusvincere', 'teamnp', 'digitalchaos', 'teamsecret'}
# listteamprize not match : {'vgjthunder'}
# listteamcard not match  : {'teamvgj'}
# ----------
# galaxybattles
# team that match         : {'vicigaming', 'infamous', 'igvitality', 'planetodd', 'happyfeet', 'tncproteam', 'mousesports', 'newbee'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# marsdota2league2017
# team that match         : {'lgdgaming', 'og', 'invictusgaming', 'evilgeniuses', 'newbee', 'clutchgamers', 'lgdforeveryoung'}
# listteamprize not match : {'vicigaming'}
# listteamcard not match  : set()
# ----------
# thefinalmatchseason1
# team that match         : {'infamous', 'mvprevolution', 'alliance', 'teamspirit', 'elitewolves', 'sgesports', 'thunderawaken'}
# listteamprize not match : {'midasce'}
# listteamcard not match  : {'teamvann', 'teambenjaz'}
# ----------
# dreamleagueseason7
# team that match         : {'planetodd', 'vegasquadron', 'teamliquid', 'teamsecret'}
# listteamprize not match : set()
# listteamcard not match  : set()
# ----------
# theinternational2017
# team that match         : set()
# listteamprize not match : set()
# listteamcard not match  : {'lgdgaming', 'hellraisers', 'fnatic', 'tncproteam', 'digitalchaos', 'execration', 'newbee', 'evilgeniuses', 'lgdforeveryoung', 'virtuspro', 'infamous', 'teamempire', 'og', 'cloud9', 'teamliquid', 'invictusgaming', 'igvitality', 'teamsecret'}
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# theinternational2017specialevents
# team that match         : set()
# listteamprize not match : {'teamradiant', 'teamdire'}
# listteamcard not match  : set()
# ----------
# Wall time: 7.5 s

# %%
re.sub(r'\W+|_', '', 'eg._K').lower()
# Out:
# 'egk'
