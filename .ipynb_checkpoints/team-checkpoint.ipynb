# %%
import requests
import datetime
import pandas as pd
import yaml
import re
from bs4 import BeautifulSoup

# %%
r = requests.get(url='http://liquipedia.net/dota2/api.php?action=ask&query=[[%3A%2B]][[Has+teamid%3A%3A>0]]|%3FHas+location|%3FHas+region|%3FHas+id|%3FHas+name|sort%3Dhas+id|limit%3D500&format=json')
json = r.json()

# %%
df = pd.DataFrame(columns=['link', 'region', 'location', 'teamlow', 'team'])

# %%
lq = []

# %%
for lname, ldata in json.get('query').get('results').items():
    po = ldata.get('printouts')
    tnlow = re.sub(r'\W+', '', ldata.get('fulltext')).lower()
    tn = ldata.get('fulltext')
    tl = ldata.get('fullurl')
    try:
        rg = po.get('Has region')[0]
    except IndexError:
        rg = 'Nan' 
    try:
        loc = po.get('Has location')[0]
    except IndexError:
        loc = 'Nan'        
    df = df.append({'link': tl, 'region': rg, 'location': loc, 'teamlow': tnlow, 'team': tn}, ignore_index=True)
    lq.append(tnlow)

# %%
dat = []

# %%
urldat = 'http://datdota.com/api/teams/performances?tier=1&tier=2&valve-event=does-not-matter&threshold=5&patch=7.09&patch=7.08&patch=7.07&patch=7.06&patch=7.05&patch=7.04&patch=7.03&patch=7.02&patch=7.01&patch=7.00&patch=6.88&patch=6.87&patch=6.86&patch=6.85&patch=6.84&patch=6.83&patch=6.82&patch=6.81&patch=6.80&patch=6.79&patch=6.78&patch=6.77&patch=6.76&patch=6.75&patch=6.74&winner=either&after=01%2F01%2F2011&before=20%2F02%2F2018&duration=0%3B200&duration-value-from=0&duration-value-to=200'
htmldat = requests.get(urldat)
htmldat.encoding = 'utf-8'
il = yaml.load(htmldat.text)
il = il['data']

# %%
da = pd.DataFrame(columns=['name'])

# %%
for l in il:
    name = re.sub(r'\W+', '', l['team']['name']).lower()
    da = da.append({'name': name}, ignore_index=True)
    dat.append(name)

# %%
dat
# Out:
# ['unknownradiantteam',
#  'unknowndireteam',
#  'zenith',
#  'complexitygaming',
#  'ehome',
#  'invictusgaming',
#  'steakgaming',
#  'absolutelegends',
#  'virtualthronegaming',
#  'dk',
#  'ahead',
#  'keitagaming',
#  'serejalijetanus',
#  'lilith7',
#  'aeonsports',
#  'aheadkz',
#  'sqreenssquadv20',
#  'teamchibiusa',
#  'lgdgaming',
#  'alternatetrasher',
#  'msievogtthenetcom',
#  'cisgame',
#  'tongfu',
#  'devedesetidevetposto',
#  'guess',
#  'znation',
#  'counterlogicgaming',
#  'signaturedota2',
#  'trust',
#  'mousesports',
#  'rocky',
#  'teamimpervious',
#  'teamquantic',
#  'mousehuntgaming',
#  'muhanfamily',
#  'mtw',
#  'darer',
#  'moscowfive',
#  'vgjstorm',
#  'duskbinesports',
#  'ice',
#  'natusvincere',
#  'mineskihyperx',
#  'fnaticraidcall',
#  'flipsid3tactics',
#  'evilgeniuses',
#  'geekfam',
#  'lumenia',
#  '4friendschrillee',
#  'xxxxx',
#  'neverflatempirez',
#  'orangeesports',
#  'biggooooood',
#  'nbl',
#  'teamempire',
#  'cisrejects',
#  'copenhagenwolves',
#  'wehazasian',
#  'uebelstgamyng',
#  'maxy',
#  'potmbottom',
#  'sirpwnalots',
#  'stormgamesclan',
#  'risper',
#  '_powerrangers',
#  'teamfreedomdota2',
#  'orangetaring',
#  'kaipi',
#  'acionarenadota2',
#  'unknownteam',
#  'scepter_5',
#  'dkscuderia',
#  'brodie',
#  'energypacemakergaming',
#  'teamfinland',
#  'immunitydota',
#  'curseoffallenangel',
#  'eclubmufc',
#  'paingaming',
#  'eyesonu',
#  'chuibiwangzhe',
#  'blowjobwhore',
#  'teamdilecom',
#  'signaturedota2',
#  'unknownteam',
#  'starsbobareborn',
#  'infused',
#  'fureurmultigaming',
#  'mineskihyperx',
#  'terrorblade',
#  'wolf',
#  'lowyatnetesports',
#  'warriorsgamingunity',
#  'ladottasstacks',
#  'extremistdota2',
#  'qlimaxcrew',
#  'silent',
#  'gguardesports',
#  'sigmafr',
#  'theawesomeredteam',
#  'dota2coordinators',
#  'pacificblue',
#  'pacificred',
#  'whiterabbitnewb',
#  'skaneselit',
#  'pota2',
#  'hmmmm',
#  'teamliquid',
#  'teamukraine',
#  'eclubmufc',
#  'teamarchon',
#  'basicallyunknown',
#  'theretry',
#  'leviathan',
#  'daifansgaming',
#  'teambadenglish',
#  'elementsprogaming',
#  'moscowfive',
#  'tobeornottobe',
#  'teamserenity',
#  'sacred',
#  'teamromania',
#  'echogaming',
#  'natural9',
#  'teamabal',
#  'invincibleflamezone',
#  'flashesports',
#  'kharkivteam',
#  'arenagaming',
#  'teamdignitas',
#  'life',
#  'relaxyouaredoingfine',
#  'fantasticgamingdotateam',
#  'darerfemale',
#  'lionsoul',
#  'teamdoggie',
#  'teamvgj',
#  'revivaldragons',
#  'msievogttric',
#  'meetyourmakers',
#  'iplayesports',
#  'medanwolves',
#  'pengyou',
#  'desire',
#  'thedagoneers',
#  'igvitality',
#  'vici_gamingreborn',
#  'thebalkanbears',
#  'meenixesports',
#  'oldsouth',
#  'urnrealtangoes',
#  'firstdeparture',
#  'borealesports',
#  'teamgillette',
#  'shazam',
#  'teamredemption',
#  'mvphot6',
#  'insidiousidol',
#  'arizonaicedoutboys',
#  'gusgamingcom',
#  'teamadfinem',
#  'teammalaysia',
#  'foucsman',
#  's1lykos',
#  'justnveu',
#  'anthrax',
#  'voidboys',
#  'evernova',
#  'planetdog',
#  'starkgg',
#  'wheninmood',
#  'silimei',
#  'hunkysfromzavod',
#  'mekattesport',
#  'sungaming',
#  'friends',
#  'ipod2',
#  'cryptex',
#  'swissqualitygaming',
#  'agv安博电竞',
#  'skatemasters',
#  '1crown',
#  'enso',
#  'titan',
#  'friendshipdedicationlove',
#  'rootgamingcom',
#  'zyphierandhispeople',
#  'teampangolier',
#  'falagga',
#  'ftdcluba',
#  'scrubgaming',
#  'levelup',
#  'gamerstarvip',
#  'tshowrising',
#  'myinsanitysensei',
#  'megaladaesports',
#  'donquixotefamily',
#  'fearlessstrong',
#  'manesnabbareihalvsnusarform',
#  'messaround',
#  'dark_undead',
#  'thelaknat',
#  'dreamyoursweetlove',
#  'monkeybusiness',
#  'komandaminus',
#  'teamsingularity',
#  'moscowfiverus',
#  'gohomeon',
#  'emperorslayer',
#  'thethundercats',
#  'hive',
#  'acesvn',
#  'balrogsesport',
#  'counterhelix',
#  'balkanbearscorleone',
#  'forthedreamwearethewinner',
#  'qpadredpandas',
#  'vgjstorm',
#  'maxx',
#  'og',
#  'centraloffear',
#  'insanebuster',
#  'gamdota',
#  'your_family',
#  'smultronglaentan',
#  'beyond_infinity',
#  'newbeginning',
#  'obscuredbyclouds',
#  'austriandotaassociation',
#  'purplecanadians',
#  'helsinkireds',
#  'panther',
#  'youth_fury',
#  'moogle',
#  'orangeesportsdota',
#  'thehouseisdown',
#  'smeagol',
#  '5turtles',
#  'teamalpha',
#  'doggyteam',
#  'totalaggression',
#  'havenoawnser',
#  'dreamweaversgaming',
#  '战神75',
#  'comanche',
#  'nerusь',
#  'superstrongdinosaurs',
#  'lvyexianzong',
#  'tongfuwanzhou',
#  'burdenunited',
#  'fxopenesports',
#  'skyville',
#  'wond5',
#  'witches',
#  'butterfly',
#  'zexbingo',
#  'polaritydota2',
#  'mineyemo',
#  'aftershockgamingint',
#  'natusvincereus',
#  'kingao4',
#  'eurynomos',
#  '2144gamingshield',
#  'cedenullis',
#  's1lykos',
#  'enterprisegaming',
#  'meetyourmakersdota2',
#  'eotgaminghammerteam',
#  'theone',
#  '4bunnies1turtle',
#  'flipsidetactics',
#  'yboat',
#  'poolsorcerysometangoes',
#  'ehomex',
#  'quintetgaming',
#  'doubledimension',
#  'smggirls',
#  'rave',
#  'drmzledionsteelseries',
#  'vegetablebee',
#  'marchofmasick',
#  'drinkingboys',
#  'denialesports',
#  '_komanda_5',
#  'gingertea',
#  'teamspirit',
#  'happyfeet',
#  'minion',
#  'skyville',
#  'redefiningmadness',
#  'sgesportsteam',
#  'kingbossing',
#  'gosuguys',
#  'vrfgc',
#  'revengespiritreborn',
#  'xgamekz',
#  'wearebug',
#  'friends',
#  'fivepersonalbeliefs',
#  'ultimateid',
#  'nolifer5',
#  'nottoday',
#  'inmemoryofakma',
#  'reasongaming',
#  'disastersnky',
#  'ninjasinpyjamas',
#  'kanon',
#  'inginging',
#  'weareyoungamazing',
#  'jakobtheblueberryboy',
#  'chuiniubi',
#  'fiskestanga',
#  'menofpauses',
#  'apetaco',
#  '_kitsune_',
#  'blacksheep',
#  'teamsynchronize',
#  'rockgaming',
#  'neolutionesports',
#  'radicalonlinextremists',
#  'clutchgamers',
#  'loem',
#  'elitewolves',
#  'teamvgj',
#  'godofwar',
#  'o1dboys',
#  'russiandotobestdoto',
#  'gizmogaming',
#  'vivofibrakeydstars',
#  'teamsubvert',
#  'fluffybears',
#  'shuttlegaming',
#  'c5gaming',
#  'starboyz',
#  'dtt',
#  'thejoikernaught',
#  'whitenoise',
#  'entityesports',
#  'themudakiebaniy',
#  'tanginamoboons',
#  'teamsingularity',
#  'gergsquad',
#  'teamever',
#  'neolutionesportsth',
#  'godsmercy',
#  'prizefightinggoats',
#  'danran',
#  'ehomemalaysia',
#  'repellian',
#  'exodus',
#  'itsprotimemineskicebu',
#  'goombagamingg',
#  'esportsdream',
#  'slayerofgods',
#  'animeproboksera',
#  'skadidoesntknow',
#  'icebergesports',
#  'orangeesports',
#  'wre',
#  'infamousna',
#  'execration1',
#  'typicalmistakes',
#  'beanboys',
#  'teamflash',
#  '1stvncyberpink',
#  'infamousyoung',
#  'topowergaming',
#  'escapegaming',
#  'suicideteam',
#  'sgrejects',
#  'sgesports',
#  'theunitedstates',
#  'invasionesports',
#  'spartakesports',
#  'tablesturned',
#  'dragonslayerzzz',
#  'theonepis',
#  'hothandshandwarmers',
#  'zweisternedeluxe',
#  'dongenergy',
#  'vanger',
#  'turtlemasters',
#  'mahameruid',
#  'teamtaivnaa',
#  'lucidlunatics',
#  'teamwaooo',
#  'kasperandco',
#  'birdgang',
#  'firedragoon',
#  'thedota',
#  'mindseyedota',
#  'crescendo',
#  'boomid',
#  'deathbysnusnu',
#  'robolisastyle',
#  'paingamingint',
#  'lq',
#  'fulltiltph',
#  'elementsone',
#  'immortals',
#  'justanothernoobs',
#  'tengengaming',
#  'recoveryposition',
#  'crew',
#  'gossipgirls',
#  'sarjanateknik',
#  'teamrussiadota2',
#  'tcmgaming',
#  'team_ehug',
#  'ancientwarriorsgaming',
#  'midasclubvictory',
#  'quanticgaming',
#  'okaythankyougoodbye',
#  'aggressive5',
#  'gabepls',
#  'cubassu',
#  'horde',
#  '82ndairborne',
#  'top1dvteam',
#  'youngelite',
#  'flipsid3tacticsna',
#  'imbaph',
#  'bgenetwork',
#  'taringmy',
#  'worldofdotas',
#  'lacresha',
#  'micareintenebris',
#  'darkpassageesports',
#  'noway',
#  'ilonkafan',
#  'teamuchihas',
#  'dustgaming',
#  'russiaknockoutru',
#  'tuho',
#  'poweroffriendship',
#  '3eancoraslosersofthehell',
#  'teamburster',
#  'saintw',
#  '',
#  'siberianvalenki',
#  'zephyrdota',
#  'teamteam',
#  'teambraveheart',
#  'ankirot',
#  'ssl',
#  '_nasnedogonyat',
#  'spdgamingint',
#  'shadow_knight',
#  'pacificesports',
#  'nextgenaorus',
#  'suxysquad',
#  'samuraichamplo0',
#  'nothreat',
#  'teamnp',
#  'teamvasavi',
#  'koroksgirth',
#  'tempo',
#  'londonconspiracydota2',
#  'goatishsoul',
#  'lovetara',
#  'vultur',
#  'keitagaming',
#  'isgg',
#  'lvgaming',
#  'kingssweetpain',
#  'ifinitegaming',
#  'orendaus',
#  'weeabooesports',
#  'scfe',
#  'kawaii',
#  'ulrica',
#  'attack_smile',
#  'turmoil',
#  'amgdfirstdeparture',
#  'teamsatuduatiga',
#  'nomoreheros',
#  'themongolz',
#  'thefinaltribe',
#  'teamerinomeeperino',
#  '5inqo',
#  'woof',
#  'radiantdota2',
#  'hsysport',
#  'alliance',
#  'unknown',
#  'bellum',
#  'prodotagaming',
#  '4protectfive',
#  'queennetbandung',
#  'narastacks',
#  'ravagee',
#  'teamkazakhstan',
#  'no8',
#  'revenge',
#  'madkings',
#  'teamdk',
#  'teamkinguin',
#  'teamimpreza2015',
#  'teamred',
#  'xenim',
#  'uebelst_gamyng',
#  'aot',
#  'adeksesports',
#  'arcanysgaming',
#  'vicigaming__',
#  'isurusgaminghyperx',
#  'ra4ku32',
#  'devilsamele',
#  'decertoozone',
#  'faceless',
#  'sfexpress',
#  'dreamgamin',
#  'dota2positiveenergy',
#  'rilimin',
#  'buhlorulit',
#  'sirkuss',
#  'mamasboys',
#  'opticgaming',
#  'thescourge',
#  'nextpleasegaming',
#  'bg',
#  'teamerinojancukimo',
#  'whiteflagbear',
#  'sneakynyxassassins',
#  'riptidedota2',
#  'tncproteam',
#  'warriorsgamingyouth',
#  'teamvduobao',
#  'ehomeluminous',
#  'wheelwhreckwhilewhistling',
#  'teamnemesis',
#  'idealgigabyte',
#  'thecykasquad',
#  'cybersportteambass',
#  '3dmax',
#  'cdecgaming',
#  'drunkbath',
#  '3dmaxfr',
#  'superebolacancer',
#  'dreamtime',
#  'newelement',
#  'vicigamingpotential',
#  'cnpz',
#  'ray',
#  'leviathan',
#  'getouts',
#  'intelligencequotientxd',
#  'abraxas',
#  'esportsmuxicn',
#  '',
#  'suibian123',
#  'energyesports',
#  'sc',
#  'bryanfriends',
#  'hwakingston',
#  'monkeyfreedomfighters',
#  'doubletrouble',
#  'thunderawaken',
#  'lw',
#  'svaha',
#  'kgluminous',
#  'rock',
#  'teamone',
#  'perkypepperonis',
#  'bornstofight',
#  'worldclass',
#  'team_ftd_a',
#  'teamrave',
#  'feverdota',
#  'elitewolves',
#  'zulunation',
#  'naixgondar',
#  'newteam123123',
#  'blametvozone',
#  'teamsouth',
#  'bluepikachu',
#  '1stvngigabyte',
#  'shadowfiendeatscake',
#  'fnaticnorthamerica',
#  'ronalds',
#  'southamericanrejects',
#  'geniusgang',
#  'annie',
#  'stayfree',
#  'starsesports',
#  'overpower',
#  'youngminds',
#  'pgbarracx',
#  'keengaming',
#  'rainbowheaven',
#  'infamous',
#  'ftdcluba',
#  'ashin',
#  'ghosts',
#  'komanda',
#  'ehomek',
#  'felmyst',
#  'forthedream',
#  'forlove',
#  'singstarsgaming',
#  'fox',
#  'midorfeed',
#  'ogurayui',
#  'nottoday',
#  'togetherwedidit',
#  'rattlesnakecngaming',
#  'orangeneolutionesports',
#  'teamallstars',
#  'laigaming',
#  'mineski亿鼎博',
#  'argentinianrejects',
#  'goombagaming',
#  'coolguysclub',
#  'wanted',
#  'davaydasvidaniaaa',
#  'chickenrice1',
#  'teamunderminer',
#  'malayallstar',
#  'nvidiaarrowgamingavf',
#  'entitygaming',
#  'deathbeforedefeat',
#  'warriorsgamingunity',
#  'rootgaming',
#  'neolutionesportinternational',
#  'shitbirds',
#  'outoftangos',
#  'joenetphenomenon',
#  'whitefriesgaming',
#  'afterlifex',
#  'shadowsofthepast',
#  'we3johnny',
#  'thewildwitchdoctors',
#  'genysis',
#  'norats',
#  'freedomoftheaction',
#  'johnnysrevenge',
#  'greenshootsgaming',
#  'snineg',
#  'bears',
#  'uniongamingbolivia',
#  'phoenix',
#  'luccinigaming',
#  'doubledimension',
#  'thechainsstack',
#  'wigglyshrews',
#  'netolicru',
#  'scaryfacezzz',
#  'killerhedgehogs',
#  'highcouncilofwizardspriests',
#  'admiral',
#  'vicigaming',
#  'danishbears',
#  'cdecyouth',
#  'htmlgaming',
#  'marceltheshellwithshoeson2',
#  'taskustitans',
#  'eternalenvysdisciples',
#  'speedgamingnantong',
#  'wonderwomen',
#  'cnbhyperx',
#  'teamsecret',
#  'savetheworld_cn',
#  'gnedreamz',
#  'duobaoint',
#  'swagenteiger',
#  'trackmatetric',
#  'hellraisers',
#  'doowop',
#  'bbubu4',
#  'druidzesport',
#  'gbangers',
#  'execration安博电竞',
#  'kompasgaming',
#  'apezone',
#  'powerplayesports',
#  'tryharddota',
#  'aesirdota',
#  'qqqdu',
#  'teamnv',
#  'goldenboys',
#  'fantasticfive',
#  '5jungz',
#  'natural9',
#  'scaryfacezzzzzzz',
#  'mvpaegis',
#  'teamtaka',
#  'teamleviathan',
#  'teamrandom',
#  'ilvincitore',
#  'nemiga',
#  'effect',
#  'newbeeyoung',
#  'talentcn',
#  'immortals',
#  'newstars',
#  'trg',
#  'ces',
#  'soulofstorm',
#  'gorillazpride',
#  'underrateds',
#  'ekeepo',
#  'sirkussfinlandia',
#  'digitalchaos',
#  'moosesports',
#  'avantisangles',
#  'm19',
#  'blackknights17',
#  'newbee',
#  'newbeginning',
#  'mvpphoenix',
#  'awaregaming',
#  'nelgoons',
#  'virtuspro',
#  'cdecyouth',
#  'teammax',
#  'kingdra',
#  'biggod',
#  'overdozer',
#  'bminorgamingstyle',
#  'againstallauthority',
#  'firedota',
#  'scythesg',
#  '_myducku_',
#  'evilcorporation',
#  'therereretry',
#  'teamcoast',
#  'spac_creators',
#  '__',
#  'angelofblood',
#  'grandmaster1',
#  'doubledimension',
#  'infinityvn',
#  '2',
#  'adversityrebirth',
#  'thejoikernaut',
#  'shishifriends',
#  'interactivephilippines',
#  'elitewolvesperu',
#  'tacolife',
#  'teampropertybb2',
#  'teamgo',
#  'skyville3',
#  'duskbinesports',
#  'ld_cpn',
#  'tshow',
#  'palawan',
#  'thetroublecrushers',
#  'theprimearvore',
#  'euforia',
#  'leftonetv',
#  'tryhard',
#  'vitualgamerz',
#  'thunderobotgaming',
#  'xantc',
#  'zajituan',
#  'vgjthunder',
#  'meronspektorsalchemy',
#  'tigerpower',
#  'cookiss',
#  'yuki',
#  'team_ftd_c',
#  'gambitesports',
#  'teamalternateattax',
#  'natashaishetparnya',
#  'cdecavenger',
#  'rizegaminginternational',
#  'technicalknockout',
#  'senseigamingmtrx',
#  'hawkgaming',
#  'romania',
#  'anima_',
#  'empress',
#  'couragegaming',
#  'assail',
#  'spiritgamingvn',
#  '',
#  'gamewareallstars',
#  'unknown',
#  'teamfreedom',
#  'moscowfiveinternational',
#  'ti9champion',
#  'landsholdet',
#  'bigandblack',
#  'priesg2acom',
#  'gstar',
#  'thebrestomans',
#  'ursastroithramm',
#  'teamleviathan',
#  'clanob',
#  'prieswheresmymoney',
#  'mvphotsix',
#  'quelafamille',
#  'mvprevolution',
#  'mutantteenageninjaturtles',
#  'hypergloryteam',
#  'avalon_club',
#  'ligadaslendas',
#  'dignotoss',
#  'sym4ny',
#  'terrafirmaesports',
#  'ehomeimmortal',
#  'vgsunrise',
#  'pulse',
#  'soul',
#  'bratvanur1ka',
#  'teamfinland',
#  'spintowin',
#  'mulangirls',
#  'vhoulassassins',
#  'coolbeans',
#  'vrn36rus',
#  'bornincomplete',
#  'zerorespect',
#  'blacksoul',
#  'lgdcm',
#  'victoryssecret',
#  'wingsred',
#  'lastominous',
#  'thefunkbunch',
#  'uncleblink',
#  'newbeem',
#  'ftdclubb',
#  'veyroninternational',
#  '4hate',
#  'infamous',
#  'gameware',
#  'lemondogsdota2',
#  'teamfifty9',
#  '',
#  'kuivahtaneetnakit',
#  'pentasports',
#  'ehshasbi',
#  'hakugyokurou',
#  'hwagaming',
#  'quepasano',
#  'enjoyrelaxh',
#  'mercilessmurderers',
#  'digitalcompany',
#  'cantsaywips',
#  'bravadoemotion',
#  'sagenetwork',
#  'brilliant',
#  'plantronicsnv',
#  'wombatgaming',
#  'oslikigaming',
#  'garudainfinity',
#  'happyboysintheworld',
#  '50gaming',
#  'namvezetmiigraem',
#  'luccinigam1ng',
#  'continuum',
#  'alphared',
#  'teamerinotinkerino',
#  'mineskimalaysia',
#  'vexxgaming',
#  'teambulgaria',
#  'asperaesports',
#  'teammenacefi',
#  'sunnysideup',
#  'teamonyx',
#  'honsquad',
#  'adngamer',
#  'evilcorporation',
#  '5anchorsnocaptain',
#  'areyouangry',
#  'corgiinateam',
#  'midasclub',
#  'teambadenglish',
#  'iceberg',
#  'danishbears',
#  'everlastbygamefilling',
#  'cqdufes',
#  'yourmum',
#  'teamromanianationscup',
#  'halaares',
#  'forthedream',
#  'd9',
#  'thebetterjusticeleague',
#  'vicigamingpotential',
#  'sectorv',
#  'teamhighground',
#  'noearthspirit',
#  'rexregumqeon',
#  'cavalry',
#  'thewingsgaming',
#  'legionares',
#  'maxx',
#  'bheartzombie',
#  'rebeldes',
#  'kingdomdota',
#  'clutchgamers',
#  'nonreturntozerolhh',
#  '458production',
#  '90soldrevenge',
#  'namelessdota',
#  'lovellkingsteam',
#  'teamserenity',
#  'uniongaming',
#  'archondota',
#  'anarchist',
#  'madkings',
#  'duobaoyoung',
#  'thethundercats',
#  'fuheavenago',
#  'infs',
#  'twitchtvnoblewingz',
#  'awake',
#  'teamevos',
#  'viciousfame',
#  'sftesports',
#  'teamfavi',
#  'qarqarnetworkers',
#  'pacificrevborn',
#  'noologicgaming',
#  'godofsun',
#  'joeeliteteam',
#  'tellmewhy',
#  'extremegamingphilippines',
#  'lgdforeveryoung',
#  'codexgigas',
#  'lgdgamingint',
#  'grandfathers',
#  'teamchaotix',
#  'w33haearthspirit',
#  'risingswes',
#  'd5dagonfive',
#  'xenim',
#  'geekfam',
#  'whut',
#  'genius',
#  'shichimiya',
#  'ragingweplay',
#  'sigmaint',
#  'invasionmufc',
#  'fishlordhowe',
#  'teamballoonicorn',
#  'lyt',
#  'cafelucrew',
#  'natus',
#  'lyggaming',
#  'teammoriarty',
#  'horgaming',
#  'artificialintelligence',
#  'littlerevival',
#  'russianfairytales',
#  'nolifer5reborn',
#  'vegasquadron',
#  'maruchan',
#  'newhope',
#  'thenetcomgaming',
#  'k1ckesports',
#  'greatteacheonidzuka45',
#  'youaremonster',
#  'cloud9',
#  'weareyoung',
#  'maxfloplay',
#  'dd',
#  'nolovegaming',
#  'newbeemiracle',
#  '5eva',
#  'joindotaslayer',
#  'salonaebalo',
#  'ravedota',
#  'zerolatitude',
#  'teammaven',
#  'idfc',
#  'seedteam',
#  'holdud',
#  'cyberpink',
#  'broodmothers',
#  'effect',
#  'teammuhan',
#  '',
#  'ninjasinpyjamas',
#  'northamericanrejects',
#  'neonesports',
#  'imbalancesbansaikia',
#  'faanother',
#  '3noobs2whiners',
#  'kingdom',
#  'ftda',
#  'yellowsubmarine',
#  'fnatic',
#  'monkeyspanner',
#  'aboshamaleh',
#  'nxlgigabyte',
#  'eclipse',
#  '90sgaming',
#  'teamfantuan',
#  'u5',
#  'wisemonkeys',
#  'nocreativity',
#  'burylove',
#  'battlezone',
#  'egamersx',
#  'prodotagaming',
#  'powergaming']

# %%
eql = {}
eqd = {}
for l in lq:
    for d in dat:
        if d == l:
            eql[l] = d
            eqd[d] = l
            l = ''
            d = ''
        if ((d in l) or (l in d)) and (abs(len(l) - len(d)) < 5) and ((d != '') and (l != '')):
            eql[l] = d
            eqd[d] = l

# %%
cp = pd.DataFrame.from_dict(list(eql.items()))

# %%
cp = cp.rename(columns={0:'lq', 1:'dat'})
cp.head()
# Out:
#                  lq               dat
# 0    monkeybusiness    monkeybusiness
# 1
# 2  4friendschrillee  4friendschrillee
# 3      4protectfive      4protectfive
# 4            5jungz            5jungz

# %%
df
# Out:
#                                                   link  \
# 0        http://liquipedia.net/dota2/(monkey)_Business
# 1                 http://liquipedia.net/dota2/.aSpera.
# 2                   http://liquipedia.net/dota2/1st.VN
# 3    http://liquipedia.net/dota2/4_Anchors_%2B_Sea_...
# 4    http://liquipedia.net/dota2/4_Clover_%26_Lepricon
# 5    http://liquipedia.net/dota2/4_Friends_%2B_Chri...
# 6       http://liquipedia.net/dota2/4_Vikings_%2B_Dane
# 7           http://liquipedia.net/dota2/4_protect_five
# 8                   http://liquipedia.net/dota2/5Jungz
# 9               http://liquipedia.net/dota2/90s_Gaming
# 10         http://liquipedia.net/dota2/ALTERNATE_aTTaX
# 11             http://liquipedia.net/dota2/Aces_Gaming
# 12             http://liquipedia.net/dota2/Acion_Arena
# 13                http://liquipedia.net/dota2/Ad_Finem
# 14                http://liquipedia.net/dota2/Alliance
# 15        http://liquipedia.net/dota2/Ancient_Warriors
# 16           http://liquipedia.net/dota2/Animal_Planet
# 17     http://liquipedia.net/dota2/Arcade.PowerRangers
# 18          http://liquipedia.net/dota2/Arcanys_Gaming
# 19             http://liquipedia.net/dota2/Avalon_Club
# 20                  http://liquipedia.net/dota2/B)ears
# 21                 http://liquipedia.net/dota2/BOOM_ID
# 22                 http://liquipedia.net/dota2/Balrogs
# 23       http://liquipedia.net/dota2/Basically_Unknown
# 24         http://liquipedia.net/dota2/Beyond_Infinity
# 25                 http://liquipedia.net/dota2/Big_God
# 26         http://liquipedia.net/dota2/Big_Red_Machine
# 27          http://liquipedia.net/dota2/Bravado_Gaming
# 28             http://liquipedia.net/dota2/Brave_Heart
# 29            http://liquipedia.net/dota2/BrooDMotherS
# ..                                                 ...
# 288            http://liquipedia.net/dota2/Unknown.xiu
# 289                http://liquipedia.net/dota2/VDuoBao
# 290              http://liquipedia.net/dota2/VGJ.Storm
# 291            http://liquipedia.net/dota2/VGJ.Thunder
# 292         http://liquipedia.net/dota2/VINCE_TE_IPSUM
# 293       http://liquipedia.net/dota2/Valkyrie_eSports
# 294          http://liquipedia.net/dota2/Vega_Squadron
# 295  http://liquipedia.net/dota2/Vegetables_Esports...
# 296            http://liquipedia.net/dota2/Vici_Gaming
# 297  http://liquipedia.net/dota2/Vici_Gaming_Potential
# 298     http://liquipedia.net/dota2/Vici_Gaming_Reborn
# 299             http://liquipedia.net/dota2/Virtus.pro
# 300              http://liquipedia.net/dota2/Void_Boys
# 301                 http://liquipedia.net/dota2/Vultur
# 302                 http://liquipedia.net/dota2/WanteD
# 303   http://liquipedia.net/dota2/WarriorsGaming.Unity
# 304   http://liquipedia.net/dota2/WarriorsGaming.Youth
# 305           http://liquipedia.net/dota2/We_Are_Young
# 306  http://liquipedia.net/dota2/Wheel_Whreck_While...
# 307     http://liquipedia.net/dota2/White_Fries_Gaming
# 308    http://liquipedia.net/dota2/White_Rabbit_Gaming
# 309                http://liquipedia.net/dota2/Who2Bet
# 310           http://liquipedia.net/dota2/Wings_Gaming
# 311              http://liquipedia.net/dota2/Wings.Red
# 312                  http://liquipedia.net/dota2/XDoto
# 313              http://liquipedia.net/dota2/XDoto_Red
# 314               http://liquipedia.net/dota2/XGame.kz
# 315       http://liquipedia.net/dota2/Yellow_Submarine
# 316                 http://liquipedia.net/dota2/Zephyr
# 317           http://liquipedia.net/dota2/Zero_Respect
#
#                                  region       location  \
# 0                                Europe         Europe
# 1    Commonwealth of Independent States         Russia
# 2                        Southeast Asia        Vietnam
# 3                                Europe        Finland
# 4                                Europe         Europe
# 5                                Europe         Sweden
# 6                                Europe         Sweden
# 7                                Europe         Sweden
# 8                                Europe         Europe
# 9                        Southeast Asia       Malaysia
# 10                               Europe        Germany
# 11                       Southeast Asia        Vietnam
# 12                       Southeast Asia    Philippines
# 13                               Europe         Greece
# 14                               Europe         Sweden
# 15                                  Nan         Sweden
# 16                        North America  North America
# 17   Commonwealth of Independent States        Belarus
# 18                       Southeast Asia    Philippines
# 19                                China          China
# 20                               Europe         Europe
# 21                       Southeast Asia      Indonesia
# 22                        South America           Peru
# 23                               Europe       Bulgaria
# 24                       Southeast Asia          India
# 25                                China          China
# 26   Commonwealth of Independent States         Russia
# 27                               Africa   South Africa
# 28                                China          China
# 29                               Europe         Greece
# ..                                  ...            ...
# 288                       South America           Peru
# 289                               China          China
# 290                       North America  United States
# 291                               China          China
# 292                       South America         Brazil
# 293                              Europe        Germany
# 294  Commonwealth of Independent States         Russia
# 295                                 Nan  United States
# 296                               China          China
# 297                               China          China
# 298                               China          China
# 299  Commonwealth of Independent States         Russia
# 300                       North America         Canada
# 301                       South America      Argentina
# 302                       North America  United States
# 303                      Southeast Asia       Malaysia
# 304                      Southeast Asia       Malaysia
# 305                               China          China
# 306                       North America  United States
# 307                               China          China
# 308                              Africa   South Africa
# 309                                 Nan       Malaysia
# 310                               China          China
# 311                               China          China
# 312                                 Nan           Peru
# 313                                 Nan           Peru
# 314  Commonwealth of Independent States     Kazakhstan
# 315  Commonwealth of Independent States         Russia
# 316                      Southeast Asia    South Korea
# 317                              Europe         France
#
#                        teamlow                          team
# 0               monkeybusiness             (monkey) Business
# 1                       aspera                      .aSpera.
# 2                        1stvn                        1st.VN
# 3           4anchorsseacaptain       4 Anchors + Sea Captain
# 4              4cloverlepricon           4 Clover & Lepricon
# 5             4friendschrillee          4 Friends + Chrillee
# 6                 4vikingsdane              4 Vikings + Dane
# 7                 4protectfive                4 protect five
# 8                       5jungz                        5Jungz
# 9                    90sgaming                    90s Gaming
# 10              alternateattax               ALTERNATE aTTaX
# 11                  acesgaming                   Aces Gaming
# 12                  acionarena                   Acion Arena
# 13                     adfinem                      Ad Finem
# 14                    alliance                      Alliance
# 15             ancientwarriors              Ancient Warriors
# 16                animalplanet                 Animal Planet
# 17          arcadepowerrangers           Arcade.PowerRangers
# 18               arcanysgaming                Arcanys Gaming
# 19                  avalonclub                   Avalon Club
# 20                       bears                        B)ears
# 21                      boomid                       BOOM ID
# 22                     balrogs                       Balrogs
# 23            basicallyunknown             Basically Unknown
# 24              beyondinfinity               Beyond Infinity
# 25                      biggod                       Big God
# 26               bigredmachine               Big Red Machine
# 27               bravadogaming                Bravado Gaming
# 28                  braveheart                   Brave Heart
# 29                broodmothers                  BrooDMotherS
# ..                         ...                           ...
# 288                 unknownxiu                   Unknown.xiu
# 289                    vduobao                       VDuoBao
# 290                   vgjstorm                     VGJ.Storm
# 291                 vgjthunder                   VGJ.Thunder
# 292               vinceteipsum                VINCE TE IPSUM
# 293            valkyrieesports              Valkyrie eSports
# 294               vegasquadron                 Vega Squadron
# 295      vegetablesesportsclub       Vegetables Esports Club
# 296                 vicigaming                   Vici Gaming
# 297        vicigamingpotential         Vici Gaming Potential
# 298           vicigamingreborn            Vici Gaming Reborn
# 299                  virtuspro                    Virtus.pro
# 300                   voidboys                     Void Boys
# 301                     vultur                        Vultur
# 302                     wanted                        WanteD
# 303        warriorsgamingunity          WarriorsGaming.Unity
# 304        warriorsgamingyouth          WarriorsGaming.Youth
# 305                 weareyoung                  We Are Young
# 306  wheelwhreckwhilewhistling  Wheel Whreck While Whistling
# 307           whitefriesgaming            White Fries Gaming
# 308          whiterabbitgaming           White Rabbit Gaming
# 309                    who2bet                       Who2Bet
# 310                wingsgaming                  Wings Gaming
# 311                   wingsred                     Wings.Red
# 312                      xdoto                         XDoto
# 313                   xdotored                     XDoto Red
# 314                    xgamekz                      XGame.kz
# 315            yellowsubmarine              Yellow Submarine
# 316                     zephyr                        Zephyr
# 317                zerorespect                  Zero Respect
#
# [318 rows x 5 columns]

# %%
df = df.merge(cp, left_on=['teamlow'], right_on=['lq'])

# %%
df.head()
# Out:
#                                                 link          region  \
# 0      http://liquipedia.net/dota2/(monkey)_Business          Europe
# 1  http://liquipedia.net/dota2/4_Friends_%2B_Chri...          Europe
# 2         http://liquipedia.net/dota2/4_protect_five          Europe
# 3                 http://liquipedia.net/dota2/5Jungz          Europe
# 4             http://liquipedia.net/dota2/90s_Gaming  Southeast Asia
#
#    location           teamlow                  team                lq  \
# 0    Europe    monkeybusiness     (monkey) Business    monkeybusiness
# 1    Sweden  4friendschrillee  4 Friends + Chrillee  4friendschrillee
# 2    Sweden      4protectfive        4 protect five      4protectfive
# 3    Europe            5jungz                5Jungz            5jungz
# 4  Malaysia         90sgaming            90s Gaming         90sgaming
#
#                 dat
# 0    monkeybusiness
# 1  4friendschrillee
# 2      4protectfive
# 3            5jungz
# 4         90sgaming
