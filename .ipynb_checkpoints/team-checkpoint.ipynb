# %%
import requests
import datetime
import pandas as pd
import yaml
import re
from bs4 import BeautifulSoup

# %%
r = requests.get(url='http://liquipedia.net/dota2/api.php?action=ask&query=[[%3A%2B]][[Has+teamid%3A%3A>0]]|%3FHas+location|%3FHas+region|%3FHas+id|%3FHas+name|sort%3Dhas+id|limit%3D500&format=json')
json = r.json()

# %%
df = pd.DataFrame(columns=['link', 'region', 'location', 'teamlow', 'team'])
lq = []

# %%
for lname, ldata in json.get('query').get('results').items():
    po = ldata.get('printouts')
    tnlow = re.sub(r'\W+', '', ldata.get('fulltext')).lower()
    tn = ldata.get('fulltext')
    tl = ldata.get('fullurl')
    try:
        rg = po.get('Has region')[0]
    except IndexError:
        rg = 'Nan' 
    try:
        loc = po.get('Has location')[0]
    except IndexError:
        loc = 'Nan'        
    df = df.append({'link': tl, 'region': rg, 'location': loc, 'teamlow': tnlow, 'team': tn}, ignore_index=True)
    lq.append(tnlow)

# %%
urldat = 'http://datdota.com/api/teams/performances?tier=1&tier=2&valve-event=does-not-matter&threshold=5&patch=7.09&patch=7.08&patch=7.07&patch=7.06&patch=7.05&patch=7.04&patch=7.03&patch=7.02&patch=7.01&patch=7.00&patch=6.88&patch=6.87&patch=6.86&patch=6.85&patch=6.84&patch=6.83&patch=6.82&patch=6.81&patch=6.80&patch=6.79&patch=6.78&patch=6.77&patch=6.76&patch=6.75&patch=6.74&winner=either&after=01%2F01%2F2011&before=20%2F02%2F2018&duration=0%3B200&duration-value-from=0&duration-value-to=200'
htmldat = requests.get(urldat)
htmldat.encoding = 'utf-8'
il = yaml.load(htmldat.text)
il = il['data']

# %%
da = pd.DataFrame(columns=['name'])
dat = []

# %%
for l in il:
    name = re.sub(r'\W+', '', l['team']['name']).lower()
    da = da.append({'name': name}, ignore_index=True)
    dat.append(name)

# %%
eql = {}
eqd = {}
for l in lq:
    for d in dat:
        if d == l:
            eql[l] = d
            eqd[d] = l
            l = ''
            d = ''
        if ((d in l) or (l in d)) and (abs(len(l) - len(d)) < 5) and ((d != '') and (l != '')):
            eql[l] = d
            eqd[d] = l

# %%
cp = pd.DataFrame.from_dict(list(eql.items()))

# %%
cp = cp.rename(columns={0:'lq', 1:'dat'})
cp.head()
# Out:
#                  lq               dat
# 0    monkeybusiness    monkeybusiness
# 1
# 2  4friendschrillee  4friendschrillee
# 3      4protectfive      4protectfive
# 4            5jungz            5jungz

# %%
df = df.merge(cp, left_on=['teamlow'], right_on=['lq'])

# %%
len(eql)
# Out:
# 211

# %%
eql
# Out:
# {'': '',
#  '4friendschrillee': '4friendschrillee',
#  '4protectfive': '4protectfive',
#  '5jungz': '5jungz',
#  '90sgaming': '90sgaming',
#  'adfinem': 'teamadfinem',
#  'alliance': 'alliance',
#  'alternateattax': 'teamalternateattax',
#  'arcanysgaming': 'arcanysgaming',
#  'basicallyunknown': 'basicallyunknown',
#  'bears': 'bears',
#  'biggod': 'biggod',
#  'boomid': 'boomid',
#  'braveheart': 'teambraveheart',
#  'broodmothers': 'broodmothers',
#  'burdenunited': 'burdenunited',
#  'cantsaywips': 'cantsaywips',
#  'cavalry': 'cavalry',
#  'cdecavenger': 'cdecavenger',
#  'cdecgaming': 'cdecgaming',
#  'cdecyouth': 'cdecyouth',
#  'cisrejects': 'cisrejects',
#  'cloud9': 'cloud9',
#  'clutchgamers': 'clutchgamers',
#  'comanche': 'comanche',
#  'complexitygaming': 'complexitygaming',
#  'cookiss': 'cookiss',
#  'crescendo': 'crescendo',
#  'danishbears': 'danishbears',
#  'darer': 'darer',
#  'dddota': 'dd',
#  'digitalchaos': 'digitalchaos',
#  'digitalchaossa': 'digitalchaos',
#  'doowop': 'doowop',
#  'doubledimension': 'doubledimension',
#  'dreamgaming': 'dreamgamin',
#  'drinkingboys': 'drinkingboys',
#  'echogaming': 'echogaming',
#  'eclipseteam': 'eclipse',
#  'effect': 'effect',
#  'ehome': 'ehome',
#  'ehomekeen': 'ehomek',
#  'ehomeluminous': 'ehomeluminous',
#  'ehomemalaysia': 'ehomemalaysia',
#  'ehomex': 'ehomex',
#  'elitewolves': 'elitewolves',
#  'enso': 'enso',
#  'entitygaming': 'entitygaming',
#  'escapegaming': 'escapegaming',
#  'evernova': 'evernova',
#  'evilgeniuses': 'evilgeniuses',
#  'execration': 'execration安博电竞',
#  'exodus': 'exodus',
#  'fantasticfive': 'fantasticfive',
#  'firedragoon': 'firedragoon',
#  'firstdeparture': 'firstdeparture',
#  'flipsid3tactics': 'flipsid3tactics',
#  'fnatic': 'fnatic',
#  'forthedream': 'forthedream',
#  'friends': 'friends',
#  'ftdclubb': 'ftdclubb',
#  'gambitesports': 'gambitesports',
#  'geekfam': 'geekfam',
#  'gguardesports': 'gguardesports',
#  'goldenboys': 'goldenboys',
#  'goombagaming': 'goombagaming',
#  'gusgaming': 'gusgamingcom',
#  'happyfeet': 'happyfeet',
#  'hellraisers': 'hellraisers',
#  'highcouncilofwizardspriests': 'highcouncilofwizardspriests',
#  'horde': 'horde',
#  'hypergloryteam': 'hypergloryteam',
#  'icebergesports': 'icebergesports',
#  'igvitality': 'igvitality',
#  'immortals': 'immortals',
#  'infamous': 'infamous',
#  'infinityvn': 'infinityvn',
#  'insidiousidol': 'insidiousidol',
#  'invasionesports': 'invasionesports',
#  'invictusgaming': 'invictusgaming',
#  'isgg': 'isgg',
#  'kaipi': 'kaipi',
#  'keengaming': 'keengaming',
#  'kingao4': 'kingao4',
#  'kingdom': 'kingdom',
#  'kingdomdota': 'kingdomdota',
#  'laigaming': 'laigaming',
#  'lgdforeveryoung': 'lgdforeveryoung',
#  'lgdgaming': 'lgdgaming',
#  'lq': 'lq',
#  'm19': 'm19',
#  'madkings': 'madkings',
#  'mamasboys': 'mamasboys',
#  'maxx': 'maxx',
#  'maxy': 'maxy',
#  'midasclub': 'midasclub',
#  'midasclubvictory': 'midasclubvictory',
#  'midorfeed': 'midorfeed',
#  'mineski': 'mineski亿鼎博',
#  'monkeybusiness': 'monkeybusiness',
#  'monkeyfreedomfighters': 'monkeyfreedomfighters',
#  'mousesports': 'mousesports',
#  'mvphot6ix': 'mvphot6',
#  'mvpphoenix': 'mvpphoenix',
#  'mvprevolution': 'mvprevolution',
#  'natural9': 'natural9',
#  'natusvincere': 'natusvincere',
#  'neolutionesport': 'neolutionesportsth',
#  'newbee': 'newbee',
#  'newbeeboss': 'newbee',
#  'newbeemiracle': 'newbeemiracle',
#  'newbeeyoung': 'newbeeyoung',
#  'newelement': 'newelement',
#  'newteam123123': 'newteam123123',
#  'ninjasinpyjamas': 'ninjasinpyjamas',
#  'nolifer5': 'nolifer5',
#  'nolifer5reborn': 'nolifer5reborn',
#  'nottoday': 'nottoday',
#  'og': 'og',
#  'opticgaming': 'opticgaming',
#  'orangeesports': 'orangeesports',
#  'paingaming': 'paingaming',
#  'pentasports': 'pentasports',
#  'planetdog': 'planetdog',
#  'potmbottom': 'potmbottom',
#  'powergaming': 'powergaming',
#  'poweroffriendship': 'poweroffriendship',
#  'powerrangers': '_powerrangers',
#  'prodotagaming': 'prodotagaming',
#  'qpadredpandas': 'qpadredpandas',
#  'rave': 'rave',
#  'rexregum': 'rexregumqeon',
#  'rootgaming': 'rootgaming',
#  's1lykos': 's1lykos',
#  'sacred': 'sacred',
#  'scaryfacez': 'scaryfacezzz',
#  'sectorv': 'sectorv',
#  'sftesports': 'sftesports',
#  'sgesports': 'sgesports',
#  'sgrejects': 'sgrejects',
#  'shazam': 'shazam',
#  'spartakesports': 'spartakesports',
#  'sqreenssquad': 'sqreenssquadv20',
#  'stark': 'starkgg',
#  'stars': 'newstars',
#  'steakgaming': 'steakgaming',
#  'stormgamesclan': 'stormgamesclan',
#  'sungaming': 'sungaming',
#  'superstrongdinosaurs': 'superstrongdinosaurs',
#  'tacolife': 'tacolife',
#  'taring': 'taringmy',
#  'teamarchon': 'teamarchon',
#  'teambadenglish': 'teambadenglish',
#  'teamdignitas': 'teamdignitas',
#  'teamdilecom': 'teamdilecom',
#  'teamempire': 'teamempire',
#  'teamfaceless': 'faceless',
#  'teamfantuan': 'teamfantuan',
#  'teamfreedom': 'teamfreedom',
#  'teamimpervious': 'teamimpervious',
#  'teamkinguin': 'teamkinguin',
#  'teamleviathan': 'teamleviathan',
#  'teamlife': 'life',
#  'teamliquid': 'teamliquid',
#  'teammalaysia': 'teammalaysia',
#  'teammax': 'teammax',
#  'teamnp': 'teamnp',
#  'teamonyx': 'teamonyx',
#  'teamrandom': 'teamrandom',
#  'teamred': 'teamred',
#  'teamsatuduatiga': 'teamsatuduatiga',
#  'teamsecret': 'teamsecret',
#  'teamsingularity': 'teamsingularity',
#  'teamspirit': 'teamspirit',
#  'themongolz': 'themongolz',
#  'thunderawaken': 'thunderawaken',
#  'thunderobotgaming': 'thunderobotgaming',
#  'titan': 'titan',
#  'tncproteam': 'tncproteam',
#  'tobeornottobe': 'tobeornottobe',
#  'tongfu': 'tongfu',
#  'tongfuna': 'tongfu',
#  'tongfuwanzhou': 'tongfuwanzhou',
#  'tshow': 'tshow',
#  'tuho': 'tuho',
#  'turtlemasters': 'turtlemasters',
#  'underminer': 'teamunderminer',
#  'uniongaming': 'uniongaming',
#  'uniongamingbo': 'uniongaming',
#  'unknownxiu': 'unknown',
#  'vduobao': 'teamvduobao',
#  'vegasquadron': 'vegasquadron',
#  'vgjstorm': 'vgjstorm',
#  'vgjthunder': 'vgjthunder',
#  'vicigaming': 'vicigaming',
#  'vicigamingpotential': 'vicigamingpotential',
#  'virtuspro': 'virtuspro',
#  'voidboys': 'voidboys',
#  'vultur': 'vultur',
#  'wanted': 'wanted',
#  'warriorsgamingunity': 'warriorsgamingunity',
#  'warriorsgamingyouth': 'warriorsgamingyouth',
#  'weareyoung': 'weareyoung',
#  'wheelwhreckwhilewhistling': 'wheelwhreckwhilewhistling',
#  'whitefriesgaming': 'whitefriesgaming',
#  'wingsgaming': 'thewingsgaming',
#  'wingsred': 'wingsred',
#  'xgamekz': 'xgamekz',
#  'yellowsubmarine': 'yellowsubmarine',
#  'zephyr': 'zephyrdota',
#  'zerorespect': 'zerorespect'}

# %%
lqm = []
for lq, da in eql.items():
    lqm.append(lq)

# %%
sorted(dat)
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '1crown',
#  '1stvncyberpink',
#  '1stvngigabyte',
#  '2',
#  '2144gamingshield',
#  '3dmax',
#  '3dmaxfr',
#  '3eancoraslosersofthehell',
#  '3noobs2whiners',
#  '458production',
#  '4bunnies1turtle',
#  '4friendschrillee',
#  '4hate',
#  '4protectfive',
#  '50gaming',
#  '5anchorsnocaptain',
#  '5eva',
#  '5inqo',
#  '5jungz',
#  '5turtles',
#  '82ndairborne',
#  '90sgaming',
#  '90soldrevenge',
#  '__',
#  '_kitsune_',
#  '_komanda_5',
#  '_myducku_',
#  '_nasnedogonyat',
#  '_powerrangers',
#  'aboshamaleh',
#  'abraxas',
#  'absolutelegends',
#  'acesvn',
#  'acionarenadota2',
#  'adeksesports',
#  'admiral',
#  'adngamer',
#  'adversityrebirth',
#  'aeonsports',
#  'aesirdota',
#  'afterlifex',
#  'aftershockgamingint',
#  'againstallauthority',
#  'aggressive5',
#  'agv安博电竞',
#  'ahead',
#  'aheadkz',
#  'alliance',
#  'alphared',
#  'alternatetrasher',
#  'amgdfirstdeparture',
#  'anarchist',
#  'ancientwarriorsgaming',
#  'angelofblood',
#  'anima_',
#  'animeproboksera',
#  'ankirot',
#  'annie',
#  'anthrax',
#  'aot',
#  'apetaco',
#  'apezone',
#  'arcanysgaming',
#  'archondota',
#  'arenagaming',
#  'areyouangry',
#  'argentinianrejects',
#  'arizonaicedoutboys',
#  'artificialintelligence',
#  'ashin',
#  'asperaesports',
#  'assail',
#  'attack_smile',
#  'austriandotaassociation',
#  'avalon_club',
#  'avantisangles',
#  'awake',
#  'awaregaming',
#  'balkanbearscorleone',
#  'balrogsesport',
#  'basicallyunknown',
#  'battlezone',
#  'bbubu4',
#  'beanboys',
#  'bears',
#  'bellum',
#  'beyond_infinity',
#  'bg',
#  'bgenetwork',
#  'bheartzombie',
#  'bigandblack',
#  'biggod',
#  'biggooooood',
#  'birdgang',
#  'blackknights17',
#  'blacksheep',
#  'blacksoul',
#  'blametvozone',
#  'blowjobwhore',
#  'bluepikachu',
#  'bminorgamingstyle',
#  'boomid',
#  'borealesports',
#  'bornincomplete',
#  'bornstofight',
#  'bratvanur1ka',
#  'bravadoemotion',
#  'brilliant',
#  'brodie',
#  'broodmothers',
#  'bryanfriends',
#  'buhlorulit',
#  'burdenunited',
#  'burylove',
#  'butterfly',
#  'c5gaming',
#  'cafelucrew',
#  'cantsaywips',
#  'cavalry',
#  'cdecavenger',
#  'cdecgaming',
#  'cdecyouth',
#  'cdecyouth',
#  'cedenullis',
#  'centraloffear',
#  'ces',
#  'chickenrice1',
#  'chuibiwangzhe',
#  'chuiniubi',
#  'cisgame',
#  'cisrejects',
#  'clanob',
#  'cloud9',
#  'clutchgamers',
#  'clutchgamers',
#  'cnbhyperx',
#  'cnpz',
#  'codexgigas',
#  'comanche',
#  'complexitygaming',
#  'continuum',
#  'cookiss',
#  'coolbeans',
#  'coolguysclub',
#  'copenhagenwolves',
#  'corgiinateam',
#  'counterhelix',
#  'counterlogicgaming',
#  'couragegaming',
#  'cqdufes',
#  'crescendo',
#  'crew',
#  'cryptex',
#  'cubassu',
#  'curseoffallenangel',
#  'cyberpink',
#  'cybersportteambass',
#  'd5dagonfive',
#  'd9',
#  'daifansgaming',
#  'danishbears',
#  'danishbears',
#  'danran',
#  'darer',
#  'darerfemale',
#  'dark_undead',
#  'darkpassageesports',
#  'davaydasvidaniaaa',
#  'dd',
#  'deathbeforedefeat',
#  'deathbysnusnu',
#  'decertoozone',
#  'denialesports',
#  'desire',
#  'devedesetidevetposto',
#  'devilsamele',
#  'digitalchaos',
#  'digitalcompany',
#  'dignotoss',
#  'disastersnky',
#  'dk',
#  'dkscuderia',
#  'doggyteam',
#  'dongenergy',
#  'donquixotefamily',
#  'doowop',
#  'dota2coordinators',
#  'dota2positiveenergy',
#  'doubledimension',
#  'doubledimension',
#  'doubledimension',
#  'doubletrouble',
#  'dragonslayerzzz',
#  'dreamgamin',
#  'dreamtime',
#  'dreamweaversgaming',
#  'dreamyoursweetlove',
#  'drinkingboys',
#  'drmzledionsteelseries',
#  'druidzesport',
#  'drunkbath',
#  'dtt',
#  'duobaoint',
#  'duobaoyoung',
#  'duskbinesports',
#  'duskbinesports',
#  'dustgaming',
#  'echogaming',
#  'eclipse',
#  'eclubmufc',
#  'eclubmufc',
#  'effect',
#  'effect',
#  'egamersx',
#  'ehome',
#  'ehomeimmortal',
#  'ehomek',
#  'ehomeluminous',
#  'ehomemalaysia',
#  'ehomex',
#  'ehshasbi',
#  'ekeepo',
#  'elementsone',
#  'elementsprogaming',
#  'elitewolves',
#  'elitewolves',
#  'elitewolvesperu',
#  'emperorslayer',
#  'empress',
#  'energyesports',
#  'energypacemakergaming',
#  'enjoyrelaxh',
#  'enso',
#  'enterprisegaming',
#  'entityesports',
#  'entitygaming',
#  'eotgaminghammerteam',
#  'escapegaming',
#  'esportsdream',
#  'esportsmuxicn',
#  'eternalenvysdisciples',
#  'euforia',
#  'eurynomos',
#  'everlastbygamefilling',
#  'evernova',
#  'evilcorporation',
#  'evilcorporation',
#  'evilgeniuses',
#  'execration1',
#  'execration安博电竞',
#  'exodus',
#  'extremegamingphilippines',
#  'extremistdota2',
#  'eyesonu',
#  'faanother',
#  'faceless',
#  'falagga',
#  'fantasticfive',
#  'fantasticgamingdotateam',
#  'fearlessstrong',
#  'felmyst',
#  'feverdota',
#  'firedota',
#  'firedragoon',
#  'firstdeparture',
#  'fishlordhowe',
#  'fiskestanga',
#  'fivepersonalbeliefs',
#  'flashesports',
#  'flipsid3tactics',
#  'flipsid3tacticsna',
#  'flipsidetactics',
#  'fluffybears',
#  'fnatic',
#  'fnaticnorthamerica',
#  'fnaticraidcall',
#  'forlove',
#  'forthedream',
#  'forthedream',
#  'forthedreamwearethewinner',
#  'foucsman',
#  'fox',
#  'freedomoftheaction',
#  'friends',
#  'friends',
#  'friendshipdedicationlove',
#  'ftda',
#  'ftdcluba',
#  'ftdcluba',
#  'ftdclubb',
#  'fuheavenago',
#  'fulltiltph',
#  'fureurmultigaming',
#  'fxopenesports',
#  'gabepls',
#  'gambitesports',
#  'gamdota',
#  'gamerstarvip',
#  'gameware',
#  'gamewareallstars',
#  'garudainfinity',
#  'gbangers',
#  'geekfam',
#  'geekfam',
#  'genius',
#  'geniusgang',
#  'genysis',
#  'gergsquad',
#  'getouts',
#  'gguardesports',
#  'ghosts',
#  'gingertea',
#  'gizmogaming',
#  'gnedreamz',
#  'goatishsoul',
#  'godofsun',
#  'godofwar',
#  'godsmercy',
#  'gohomeon',
#  'goldenboys',
#  'goombagaming',
#  'goombagamingg',
#  'gorillazpride',
#  'gossipgirls',
#  'gosuguys',
#  'grandfathers',
#  'grandmaster1',
#  'greatteacheonidzuka45',
#  'greenshootsgaming',
#  'gstar',
#  'guess',
#  'gusgamingcom',
#  'hakugyokurou',
#  'halaares',
#  'happyboysintheworld',
#  'happyfeet',
#  'havenoawnser',
#  'hawkgaming',
#  'hellraisers',
#  'helsinkireds',
#  'highcouncilofwizardspriests',
#  'hive',
#  'hmmmm',
#  'holdud',
#  'honsquad',
#  'horde',
#  'horgaming',
#  'hothandshandwarmers',
#  'hsysport',
#  'htmlgaming',
#  'hunkysfromzavod',
#  'hwagaming',
#  'hwakingston',
#  'hypergloryteam',
#  'ice',
#  'iceberg',
#  'icebergesports',
#  'idealgigabyte',
#  'idfc',
#  'ifinitegaming',
#  'igvitality',
#  'ilonkafan',
#  'ilvincitore',
#  'imbalancesbansaikia',
#  'imbaph',
#  'immortals',
#  'immortals',
#  'immunitydota',
#  'infamous',
#  'infamous',
#  'infamousna',
#  'infamousyoung',
#  'infinityvn',
#  'infs',
#  'infused',
#  'inginging',
#  'inmemoryofakma',
#  'insanebuster',
#  'insidiousidol',
#  'intelligencequotientxd',
#  'interactivephilippines',
#  'invasionesports',
#  'invasionmufc',
#  'invictusgaming',
#  'invincibleflamezone',
#  'iplayesports',
#  'ipod2',
#  'isgg',
#  'isurusgaminghyperx',
#  'itsprotimemineskicebu',
#  'jakobtheblueberryboy',
#  'joeeliteteam',
#  'joenetphenomenon',
#  'johnnysrevenge',
#  'joindotaslayer',
#  'justanothernoobs',
#  'justnveu',
#  'k1ckesports',
#  'kaipi',
#  'kanon',
#  'kasperandco',
#  'kawaii',
#  'keengaming',
#  'keitagaming',
#  'keitagaming',
#  'kgluminous',
#  'kharkivteam',
#  'killerhedgehogs',
#  'kingao4',
#  'kingbossing',
#  'kingdom',
#  'kingdomdota',
#  'kingdra',
#  'kingssweetpain',
#  'komanda',
#  'komandaminus',
#  'kompasgaming',
#  'koroksgirth',
#  'kuivahtaneetnakit',
#  'lacresha',
#  'ladottasstacks',
#  'laigaming',
#  'landsholdet',
#  'lastominous',
#  'ld_cpn',
#  'leftonetv',
#  'legionares',
#  'lemondogsdota2',
#  'levelup',
#  'leviathan',
#  'leviathan',
#  'lgdcm',
#  'lgdforeveryoung',
#  'lgdgaming',
#  'lgdgamingint',
#  'life',
#  'ligadaslendas',
#  'lilith7',
#  'lionsoul',
#  'littlerevival',
#  'loem',
#  'londonconspiracydota2',
#  'lovellkingsteam',
#  'lovetara',
#  'lowyatnetesports',
#  'lq',
#  'luccinigam1ng',
#  'luccinigaming',
#  'lucidlunatics',
#  'lumenia',
#  'lvgaming',
#  'lvyexianzong',
#  'lw',
#  'lyggaming',
#  'lyt',
#  'm19',
#  'madkings',
#  'madkings',
#  'mahameruid',
#  'malayallstar',
#  'mamasboys',
#  'manesnabbareihalvsnusarform',
#  'marceltheshellwithshoeson2',
#  'marchofmasick',
#  'maruchan',
#  'maxfloplay',
#  'maxx',
#  'maxx',
#  'maxy',
#  'medanwolves',
#  'meenixesports',
#  'meetyourmakers',
#  'meetyourmakersdota2',
#  'megaladaesports',
#  'mekattesport',
#  'menofpauses',
#  'mercilessmurderers',
#  'meronspektorsalchemy',
#  'messaround',
#  'micareintenebris',
#  'midasclub',
#  'midasclubvictory',
#  'midorfeed',
#  'mindseyedota',
#  'mineskihyperx',
#  'mineskihyperx',
#  'mineskimalaysia',
#  'mineski亿鼎博',
#  'mineyemo',
#  'minion',
#  'monkeybusiness',
#  'monkeyfreedomfighters',
#  'monkeyspanner',
#  'moogle',
#  'moosesports',
#  'moscowfive',
#  'moscowfive',
#  'moscowfiveinternational',
#  'moscowfiverus',
#  'mousehuntgaming',
#  'mousesports',
#  'msievogtthenetcom',
#  'msievogttric',
#  'mtw',
#  'muhanfamily',
#  'mulangirls',
#  'mutantteenageninjaturtles',
#  'mvpaegis',
#  'mvphot6',
#  'mvphotsix',
#  'mvpphoenix',
#  'mvprevolution',
#  'myinsanitysensei',
#  'naixgondar',
#  'namelessdota',
#  'namvezetmiigraem',
#  'narastacks',
#  'natashaishetparnya',
#  'natural9',
#  'natural9',
#  'natus',
#  'natusvincere',
#  'natusvincereus',
#  'nbl',
#  'nelgoons',
#  'nemiga',
#  'neolutionesportinternational',
#  'neolutionesports',
#  'neolutionesportsth',
#  'neonesports',
#  'nerusь',
#  'netolicru',
#  'neverflatempirez',
#  'newbee',
#  'newbeem',
#  'newbeemiracle',
#  'newbeeyoung',
#  'newbeginning',
#  'newbeginning',
#  'newelement',
#  'newhope',
#  'newstars',
#  'newteam123123',
#  'nextgenaorus',
#  'nextpleasegaming',
#  'ninjasinpyjamas',
#  'ninjasinpyjamas',
#  'no8',
#  'nocreativity',
#  'noearthspirit',
#  'nolifer5',
#  'nolifer5reborn',
#  'nolovegaming',
#  'nomoreheros',
#  'nonreturntozerolhh',
#  'noologicgaming',
#  'norats',
#  'northamericanrejects',
#  'nothreat',
#  'nottoday',
#  'nottoday',
#  'noway',
#  'nvidiaarrowgamingavf',
#  'nxlgigabyte',
#  'o1dboys',
#  'obscuredbyclouds',
#  'og',
#  'ogurayui',
#  'okaythankyougoodbye',
#  'oldsouth',
#  'opticgaming',
#  'orangeesports',
#  'orangeesports',
#  'orangeesportsdota',
#  'orangeneolutionesports',
#  'orangetaring',
#  'orendaus',
#  'oslikigaming',
#  'outoftangos',
#  'overdozer',
#  'overpower',
#  'pacificblue',
#  'pacificesports',
#  'pacificred',
#  'pacificrevborn',
#  'paingaming',
#  'paingamingint',
#  'palawan',
#  'panther',
#  'pengyou',
#  'pentasports',
#  'perkypepperonis',
#  'pgbarracx',
#  'phoenix',
#  'planetdog',
#  'plantronicsnv',
#  'polaritydota2',
#  'poolsorcerysometangoes',
#  'pota2',
#  'potmbottom',
#  'powergaming',
#  'poweroffriendship',
#  'powerplayesports',
#  'priesg2acom',
#  'prieswheresmymoney',
#  'prizefightinggoats',
#  'prodotagaming',
#  'prodotagaming',
#  'pulse',
#  'purplecanadians',
#  'qarqarnetworkers',
#  'qlimaxcrew',
#  'qpadredpandas',
#  'qqqdu',
#  'quanticgaming',
#  'queennetbandung',
#  'quelafamille',
#  'quepasano',
#  'quintetgaming',
#  'ra4ku32',
#  'radiantdota2',
#  'radicalonlinextremists',
#  'ragingweplay',
#  'rainbowheaven',
#  'rattlesnakecngaming',
#  'ravagee',
#  'rave',
#  'ravedota',
#  'ray',
#  'reasongaming',
#  'rebeldes',
#  'recoveryposition',
#  'redefiningmadness',
#  'relaxyouaredoingfine',
#  'repellian',
#  'revenge',
#  'revengespiritreborn',
#  'revivaldragons',
#  'rexregumqeon',
#  'rilimin',
#  'riptidedota2',
#  'risingswes',
#  'risper',
#  'rizegaminginternational',
#  'robolisastyle',
#  'rock',
#  'rockgaming',
#  'rocky',
#  'romania',
#  'ronalds',
#  'rootgaming',
#  'rootgamingcom',
#  'russiaknockoutru',
#  'russiandotobestdoto',
#  'russianfairytales',
#  's1lykos',
#  's1lykos',
#  'sacred',
#  'sagenetwork',
#  'saintw',
#  'salonaebalo',
#  'samuraichamplo0',
#  'sarjanateknik',
#  'savetheworld_cn',
#  'sc',
#  'scaryfacezzz',
#  'scaryfacezzzzzzz',
#  'scepter_5',
#  'scfe',
#  'scrubgaming',
#  'scythesg',
#  'sectorv',
#  'seedteam',
#  'senseigamingmtrx',
#  'serejalijetanus',
#  'sfexpress',
#  'sftesports',
#  'sgesports',
#  'sgesportsteam',
#  'sgrejects',
#  'shadow_knight',
#  'shadowfiendeatscake',
#  'shadowsofthepast',
#  'shazam',
#  'shichimiya',
#  'shishifriends',
#  'shitbirds',
#  'shuttlegaming',
#  'siberianvalenki',
#  'sigmafr',
#  'sigmaint',
#  'signaturedota2',
#  'signaturedota2',
#  'silent',
#  'silimei',
#  'singstarsgaming',
#  'sirkuss',
#  'sirkussfinlandia',
#  'sirpwnalots',
#  'skadidoesntknow',
#  'skaneselit',
#  'skatemasters',
#  'skyville',
#  'skyville',
#  'skyville3',
#  'slayerofgods',
#  'smeagol',
#  'smggirls',
#  'smultronglaentan',
#  'sneakynyxassassins',
#  'snineg',
#  'soul',
#  'soulofstorm',
#  'southamericanrejects',
#  'spac_creators',
#  'spartakesports',
#  'spdgamingint',
#  'speedgamingnantong',
#  'spintowin',
#  'spiritgamingvn',
#  'sqreenssquadv20',
#  'ssl',
#  'starboyz',
#  'starkgg',
#  'starsbobareborn',
#  'starsesports',
#  'stayfree',
#  'steakgaming',
#  'stormgamesclan',
#  'suibian123',
#  'suicideteam',
#  'sungaming',
#  'sunnysideup',
#  'superebolacancer',
#  'superstrongdinosaurs',
#  'suxysquad',
#  'svaha',
#  'swagenteiger',
#  'swissqualitygaming',
#  'sym4ny',
#  'tablesturned',
#  'tacolife',
#  'talentcn',
#  'tanginamoboons',
#  'taringmy',
#  'taskustitans',
#  'tcmgaming',
#  'team_ehug',
#  'team_ftd_a',
#  'team_ftd_c',
#  'teamabal',
#  'teamadfinem',
#  'teamallstars',
#  'teamalpha',
#  'teamalternateattax',
#  'teamarchon',
#  'teambadenglish',
#  'teambadenglish',
#  'teamballoonicorn',
#  'teambraveheart',
#  'teambulgaria',
#  'teamburster',
#  'teamchaotix',
#  'teamchibiusa',
#  'teamcoast',
#  'teamdignitas',
#  'teamdilecom',
#  'teamdk',
#  'teamdoggie',
#  'teamempire',
#  'teamerinojancukimo',
#  'teamerinomeeperino',
#  'teamerinotinkerino',
#  'teamever',
#  'teamevos',
#  'teamfantuan',
#  'teamfavi',
#  'teamfifty9',
#  'teamfinland',
#  'teamfinland',
#  'teamflash',
#  'teamfreedom',
#  'teamfreedomdota2',
#  'teamgillette',
#  'teamgo',
#  'teamhighground',
#  'teamimpervious',
#  'teamimpreza2015',
#  'teamkazakhstan',
#  'teamkinguin',
#  'teamleviathan',
#  'teamleviathan',
#  'teamliquid',
#  'teammalaysia',
#  'teammaven',
#  'teammax',
#  'teammenacefi',
#  'teammoriarty',
#  'teammuhan',
#  'teamnemesis',
#  'teamnp',
#  'teamnv',
#  'teamone',
#  'teamonyx',
#  'teampangolier',
#  'teampropertybb2',
#  'teamquantic',
#  'teamrandom',
#  'teamrave',
#  'teamred',
#  'teamredemption',
#  'teamromania',
#  'teamromanianationscup',
#  'teamrussiadota2',
#  'teamsatuduatiga',
#  'teamsecret',
#  'teamserenity',
#  'teamserenity',
#  'teamsingularity',
#  'teamsingularity',
#  'teamsouth',
#  'teamspirit',
#  'teamsubvert',
#  'teamsynchronize',
#  'teamtaivnaa',
#  'teamtaka',
#  'teamteam',
#  'teamuchihas',
#  'teamukraine',
#  'teamunderminer',
#  'teamvasavi',
#  'teamvduobao',
#  'teamvgj',
#  'teamvgj',
#  'teamwaooo',
#  'technicalknockout',
#  'tellmewhy',
#  'tempo',
#  'tengengaming',
#  'terrafirmaesports',
#  'terrorblade',
#  'theawesomeredteam',
#  'thebalkanbears',
#  'thebetterjusticeleague',
#  'thebrestomans',
#  'thechainsstack',
#  'thecykasquad',
#  'thedagoneers',
#  'thedota',
#  'thefinaltribe',
#  'thefunkbunch',
#  'thehouseisdown',
#  'thejoikernaught',
#  'thejoikernaut',
#  'thelaknat',
#  'themongolz',
#  'themudakiebaniy',
#  'thenetcomgaming',
#  'theone',
#  'theonepis',
#  'theprimearvore',
#  'therereretry',
#  'theretry',
#  'thescourge',
#  'thethundercats',
#  'thethundercats',
#  'thetroublecrushers',
#  'theunitedstates',
#  'thewildwitchdoctors',
#  'thewingsgaming',
#  'thunderawaken',
#  'thunderobotgaming',
#  'ti9champion',
#  'tigerpower',
#  'titan',
#  'tncproteam',
#  'tobeornottobe',
#  'togetherwedidit',
#  'tongfu',
#  'tongfuwanzhou',
#  'top1dvteam',
#  'topowergaming',
#  'totalaggression',
#  'trackmatetric',
#  'trg',
#  'trust',
#  'tryhard',
#  'tryharddota',
#  'tshow',
#  'tshowrising',
#  'tuho',
#  'turmoil',
#  'turtlemasters',
#  'twitchtvnoblewingz',
#  'typicalmistakes',
#  'u5',
#  'uebelst_gamyng',
#  'uebelstgamyng',
#  'ulrica',
#  'ultimateid',
#  'uncleblink',
#  'underrateds',
#  'uniongaming',
#  'uniongamingbolivia',
#  'unknown',
#  'unknown',
#  'unknowndireteam',
#  'unknownradiantteam',
#  'unknownteam',
#  'unknownteam',
#  'urnrealtangoes',
#  'ursastroithramm',
#  'vanger',
#  'vegasquadron',
#  'vegetablebee',
#  'vexxgaming',
#  'veyroninternational',
#  'vgjstorm',
#  'vgjstorm',
#  'vgjthunder',
#  'vgsunrise',
#  'vhoulassassins',
#  'vici_gamingreborn',
#  'vicigaming',
#  'vicigaming__',
#  'vicigamingpotential',
#  'vicigamingpotential',
#  'viciousfame',
#  'victoryssecret',
#  'virtualthronegaming',
#  'virtuspro',
#  'vitualgamerz',
#  'vivofibrakeydstars',
#  'voidboys',
#  'vrfgc',
#  'vrn36rus',
#  'vultur',
#  'w33haearthspirit',
#  'wanted',
#  'warriorsgamingunity',
#  'warriorsgamingunity',
#  'warriorsgamingyouth',
#  'we3johnny',
#  'wearebug',
#  'weareyoung',
#  'weareyoungamazing',
#  'weeabooesports',
#  'wehazasian',
#  'wheelwhreckwhilewhistling',
#  'wheninmood',
#  'whiteflagbear',
#  'whitefriesgaming',
#  'whitenoise',
#  'whiterabbitnewb',
#  'whut',
#  'wigglyshrews',
#  'wingsred',
#  'wisemonkeys',
#  'witches',
#  'wolf',
#  'wombatgaming',
#  'wond5',
#  'wonderwomen',
#  'woof',
#  'worldclass',
#  'worldofdotas',
#  'wre',
#  'xantc',
#  'xenim',
#  'xenim',
#  'xgamekz',
#  'xxxxx',
#  'yboat',
#  'yellowsubmarine',
#  'youaremonster',
#  'youngelite',
#  'youngminds',
#  'your_family',
#  'yourmum',
#  'youth_fury',
#  'yuki',
#  'zajituan',
#  'zenith',
#  'zephyrdota',
#  'zerolatitude',
#  'zerorespect',
#  'zexbingo',
#  'znation',
#  'zulunation',
#  'zweisternedeluxe',
#  'zyphierandhispeople',
#  '战神75']
