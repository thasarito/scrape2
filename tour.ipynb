# %%
import requests
import datetime
import pandas as pd

# %%
r = requests.get(url='http://liquipedia.net/dota2/api.php?action=ask&query=[[%3A%2B]]+[[Has+liquipedia+tier%3A%3AMajor]]+[[Has+date%3A%3A>2011-01-01]]+OR+[[%3A%2B]]+[[Has+liquipedia+tier%3A%3APremier]]+[[Has+date%3A%3A>2011-01-01]]+OR+[[Has+date%3A%3A>2011-01-01]]+[[Has+liquipedia+tier%3A%3A%2B]]+[[Is+valve+premier%3A%3Atrue]]|%3FHas+prizepool+in+usd|%3FHas+date|%3FHas+end+date|%3FHas+leagueid|sort%3Dhas+date|limit%3D500&format=json')
json = r.json()

# %%
df = pd.DataFrame(columns=['link', 'tour', 'start', 'end', 'prize'])

# %%
json.get('query').get('results')
# Out:
# {'2013 WPC ACE Dota 2 League': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': '2013 WPC ACE Dota 2 League',
#   'fullurl': 'http://liquipedia.net/dota2/2013_WPC_ACE_Dota_2_League',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/9/22',
#      'timestamp': '1379808000'}],
#    'Has end date': [{'raw': '1/2014/1/1', 'timestamp': '1388534400'}],
#    'Has leagueid': ['81'],
#    'Has prizepool in usd': [247920]}},
#  '2015 Red Bull Battle Grounds: Dota 2': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': '2015 Red Bull Battle Grounds: Dota 2',
#   'fullurl': 'http://liquipedia.net/dota2/2015_Red_Bull_Battle_Grounds:_Dota_2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/4/6', 'timestamp': '1428278400'}],
#    'Has end date': [{'raw': '1/2015/5/10', 'timestamp': '1431216000'}],
#    'Has leagueid': ['2877'],
#    'Has prizepool in usd': [88290]}},
#  'AMD Premier League/Season 1': {'displaytitle': 'AMD Premier League Season 1',
#   'exists': '1',
#   'fulltext': 'AMD Premier League/Season 1',
#   'fullurl': 'http://liquipedia.net/dota2/AMD_Premier_League/Season_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/5/6', 'timestamp': '1367798400'}],
#    'Has end date': [{'raw': '1/2013/5/15', 'timestamp': '1368576000'}],
#    'Has leagueid': ['40'],
#    'Has prizepool in usd': [5000]}},
#  'AMD Premier League/Season 2': {'displaytitle': 'AMD Premier League Season 2',
#   'exists': '1',
#   'fulltext': 'AMD Premier League/Season 2',
#   'fullurl': 'http://liquipedia.net/dota2/AMD_Premier_League/Season_2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/7/17',
#      'timestamp': '1374019200'}],
#    'Has end date': [{'raw': '1/2013/7/23', 'timestamp': '1374537600'}],
#    'Has leagueid': ['58'],
#    'Has prizepool in usd': [5000]}},
#  'ASUS Open 2012': {'displaytitle': 'ASUS Open 2012 Finals',
#   'exists': '1',
#   'fulltext': 'ASUS Open 2012',
#   'fullurl': 'http://liquipedia.net/dota2/ASUS_Open_2012',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2012/12/13',
#      'timestamp': '1355356800'}],
#    'Has end date': [{'raw': '1/2012/12/16', 'timestamp': '1355616000'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [15000]}},
#  'Adrenaline Cyber League/2017': {'displaytitle': 'Adrenaline Cyber League',
#   'exists': '1',
#   'fulltext': 'Adrenaline Cyber League/2017',
#   'fullurl': 'http://liquipedia.net/dota2/Adrenaline_Cyber_League/2017',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/11/21',
#      'timestamp': '1511222400'}],
#    'Has end date': [{'raw': '1/2017/11/22', 'timestamp': '1511308800'}],
#    'Has leagueid': ['4820'],
#    'Has prizepool in usd': [100000]}},
#  'Alienware 2012 Battlegrounds': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Alienware 2012 Battlegrounds',
#   'fullurl': 'http://liquipedia.net/dota2/Alienware_2012_Battlegrounds',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2012/8/1', 'timestamp': '1343779200'}],
#    'Has end date': [{'raw': '1/2012/9/25', 'timestamp': '1348531200'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [3000]}},
#  'Alienware Cup': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Alienware Cup',
#   'fullurl': 'http://liquipedia.net/dota2/Alienware_Cup',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/6/16',
#      'timestamp': '1371340800'}],
#    'Has end date': [{'raw': '1/2013/7/9', 'timestamp': '1373328000'}],
#    'Has leagueid': ['54'],
#    'Has prizepool in usd': [60000]}},
#  'American Dota League/Season 1': {'displaytitle': 'American Dota League Season 1',
#   'exists': '1',
#   'fulltext': 'American Dota League/Season 1',
#   'fullurl': 'http://liquipedia.net/dota2/American_Dota_League/Season_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/5/28',
#      'timestamp': '1369699200'}],
#    'Has end date': [{'raw': '1/2013/7/10', 'timestamp': '1373414400'}],
#    'Has leagueid': ['50'],
#    'Has prizepool in usd': [10000]}},
#  'American Dota League/Season 2': {'displaytitle': 'American Dota League Season 2',
#   'exists': '1',
#   'fulltext': 'American Dota League/Season 2',
#   'fullurl': 'http://liquipedia.net/dota2/American_Dota_League/Season_2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/4/8', 'timestamp': '1396915200'}],
#    'Has end date': [{'raw': '1/2014/6/3', 'timestamp': '1401753600'}],
#    'Has leagueid': ['1100'],
#    'Has prizepool in usd': [10000]}},
#  'Armaggeddon Dota 2 Grand Slam Asia 2013': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Armaggeddon Dota 2 Grand Slam Asia 2013',
#   'fullurl': 'http://liquipedia.net/dota2/Armaggeddon_Dota_2_Grand_Slam_Asia_2013',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/3/7', 'timestamp': '1362614400'}],
#    'Has end date': [{'raw': '1/2013/3/10', 'timestamp': '1362873600'}],
#    'Has leagueid': ['31'],
#    'Has prizepool in usd': [22500]}},
#  'Asian Cyber Games 2013': {'displaytitle': 'Asian Cyber Games',
#   'exists': '1',
#   'fulltext': 'Asian Cyber Games 2013',
#   'fullurl': 'http://liquipedia.net/dota2/Asian_Cyber_Games_2013',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/12/27',
#      'timestamp': '1388102400'}],
#    'Has end date': [{'raw': '1/2013/12/29', 'timestamp': '1388275200'}],
#    'Has leagueid': ['146'],
#    'Has prizepool in usd': [30000]}},
#  'Battle of Central Europe/Season 3': {'displaytitle': 'Battle of Central Europe Season 3',
#   'exists': '1',
#   'fulltext': 'Battle of Central Europe/Season 3',
#   'fullurl': 'http://liquipedia.net/dota2/Battle_of_Central_Europe/Season_3',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/11/9',
#      'timestamp': '1415491200'}],
#    'Has end date': [{'raw': '1/2014/12/19', 'timestamp': '1418947200'}],
#    'Has leagueid': ['2125'],
#    'Has prizepool in usd': [30000]}},
#  'Boston Major/2016': {'displaytitle': 'The Boston Major 2016',
#   'exists': '1',
#   'fulltext': 'Boston Major/2016',
#   'fullurl': 'http://liquipedia.net/dota2/Boston_Major/2016',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/12/3',
#      'timestamp': '1480723200'}],
#    'Has end date': [{'raw': '1/2016/12/10', 'timestamp': '1481328000'}],
#    'Has leagueid': ['4874'],
#    'Has prizepool in usd': [3000000]}},
#  'Brasil Game Cup/2014': {'displaytitle': 'Brasil Game Cup 2014',
#   'exists': '1',
#   'fulltext': 'Brasil Game Cup/2014',
#   'fullurl': 'http://liquipedia.net/dota2/Brasil_Game_Cup/2014',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/10/9',
#      'timestamp': '1412812800'}],
#    'Has end date': [{'raw': '1/2014/10/12', 'timestamp': '1413072000'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [24800]}},
#  'CDEC New Star Challenge': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'CDEC New Star Challenge',
#   'fullurl': 'http://liquipedia.net/dota2/CDEC_New_Star_Challenge',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/6/4', 'timestamp': '1401840000'}],
#    'Has end date': [{'raw': '1/2014/6/22', 'timestamp': '1403395200'}],
#    'Has leagueid': ['1284'],
#    'Has prizepool in usd': [16000]}},
#  'Captains Draft/1': {'displaytitle': 'XMG Captains Draft Invitational',
#   'exists': '1',
#   'fulltext': 'Captains Draft/1',
#   'fullurl': 'http://liquipedia.net/dota2/Captains_Draft/1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/2/18',
#      'timestamp': '1392681600'}],
#    'Has end date': [{'raw': '1/2014/4/1', 'timestamp': '1396310400'}],
#    'Has leagueid': ['203'],
#    'Has prizepool in usd': [40170]}},
#  'Captains Draft/2': {'displaytitle': 'XMG Captains Draft 2.0',
#   'exists': '1',
#   'fulltext': 'Captains Draft/2',
#   'fullurl': 'http://liquipedia.net/dota2/Captains_Draft/2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/10/31',
#      'timestamp': '1414713600'}],
#    'Has end date': [{'raw': '1/2014/12/21', 'timestamp': '1419120000'}],
#    'Has leagueid': ['2140'],
#    'Has prizepool in usd': [276742]}},
#  'Captains Draft/3': {'displaytitle': 'Captains Draft 3.0',
#   'exists': '1',
#   'fulltext': 'Captains Draft/3',
#   'fullurl': 'http://liquipedia.net/dota2/Captains_Draft/3',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/1/19',
#      'timestamp': '1453161600'}],
#    'Has end date': [{'raw': '1/2016/2/17', 'timestamp': '1455667200'}],
#    'Has leagueid': ['4289'],
#    'Has prizepool in usd': [124154]}},
#  'Captains Draft/4': {'displaytitle': 'Captains Draft 4.0',
#   'exists': '1',
#   'fulltext': 'Captains Draft/4',
#   'fullurl': 'http://liquipedia.net/dota2/Captains_Draft/4',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2018/1/4', 'timestamp': '1515024000'}],
#    'Has end date': [{'raw': '1/2018/1/7', 'timestamp': '1515283200'}],
#    'Has leagueid': ['5688'],
#    'Has prizepool in usd': [300000]}},
#  'China Top/2016': {'displaytitle': 'China Top 2016',
#   'exists': '1',
#   'fulltext': 'China Top/2016',
#   'fullurl': 'http://liquipedia.net/dota2/China_Top/2016',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/12/17',
#      'timestamp': '1481932800'}],
#    'Has end date': [{'raw': '1/2016/12/18', 'timestamp': '1482019200'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [229904]}},
#  'China Top/2017': {'displaytitle': 'China Top 2017',
#   'exists': '1',
#   'fulltext': 'China Top/2017',
#   'fullurl': 'http://liquipedia.net/dota2/China_Top/2017',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/11/19',
#      'timestamp': '1511049600'}],
#    'Has end date': [{'raw': '1/2017/11/23', 'timestamp': '1511395200'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': []}},
#  'Corsair Gaming Summer Dota 2 Tournament 2013': {'displaytitle': 'Corsair Gaming Summer Tournament 2013',
#   'exists': '1',
#   'fulltext': 'Corsair Gaming Summer Dota 2 Tournament 2013',
#   'fullurl': 'http://liquipedia.net/dota2/Corsair_Gaming_Summer_Dota_2_Tournament_2013',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/6/28',
#      'timestamp': '1372377600'}],
#    'Has end date': [{'raw': '1/2013/7/26', 'timestamp': '1374796800'}],
#    'Has leagueid': ['57'],
#    'Has prizepool in usd': [10000]}},
#  'Curse Dota 2 Invitational': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Curse Dota 2 Invitational',
#   'fullurl': 'http://liquipedia.net/dota2/Curse_Dota_2_Invitational',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/5/4', 'timestamp': '1367625600'}],
#    'Has end date': [{'raw': '1/2013/5/19', 'timestamp': '1368921600'}],
#    'Has leagueid': ['41'],
#    'Has prizepool in usd': [10000]}},
#  'Dota 2 Asia Championships/2015': {'displaytitle': 'Dota 2 Asia Championships 2015',
#   'exists': '1',
#   'fulltext': 'Dota 2 Asia Championships/2015',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Asia_Championships/2015',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/1/29',
#      'timestamp': '1422489600'}],
#    'Has end date': [{'raw': '1/2015/2/9', 'timestamp': '1423440000'}],
#    'Has leagueid': ['2339'],
#    'Has prizepool in usd': [3057519]}},
#  'Dota 2 Asia Championships/2017': {'displaytitle': 'Dota 2 Asia Championships 2017',
#   'exists': '1',
#   'fulltext': 'Dota 2 Asia Championships/2017',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Asia_Championships/2017',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/3/27',
#      'timestamp': '1490572800'}],
#    'Has end date': [{'raw': '1/2017/4/4', 'timestamp': '1491264000'}],
#    'Has leagueid': ['5197'],
#    'Has prizepool in usd': [611997]}},
#  'Dota 2 Asia Championships/2018': {'displaytitle': 'Dota 2 Asia Championships 2018',
#   'exists': '1',
#   'fulltext': 'Dota 2 Asia Championships/2018',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Asia_Championships/2018',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2018/3/30',
#      'timestamp': '1522368000'}],
#    'Has end date': [{'raw': '1/2018/4/7', 'timestamp': '1523059200'}],
#    'Has leagueid': ['9643'],
#    'Has prizepool in usd': [1000000]}},
#  'Dota 2 Canada Cup/Season 6': {'displaytitle': 'Dota 2 Canada Cup Season 6',
#   'exists': '1',
#   'fulltext': 'Dota 2 Canada Cup/Season 6',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Canada_Cup/Season_6',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/11/28',
#      'timestamp': '1448668800'}],
#    'Has end date': [{'raw': '1/2016/2/8', 'timestamp': '1454889600'}],
#    'Has leagueid': ['2747'],
#    'Has prizepool in usd': [40763]}},
#  'Dota 2 Champions League/Christmas Charity Magic': {'displaytitle': 'Dota 2 Champions League Christmas Charity Magic',
#   'exists': '1',
#   'fulltext': 'Dota 2 Champions League/Christmas Charity Magic',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Champions_League/Christmas_Charity_Magic',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/12/2',
#      'timestamp': '1449014400'}],
#    'Has end date': [{'raw': '1/2015/12/23', 'timestamp': '1450828800'}],
#    'Has leagueid': ['4119'],
#    'Has prizepool in usd': [40180]}},
#  'Dota 2 Champions League/Season 1': {'displaytitle': 'Dota 2 Champions League Season 1',
#   'exists': '1',
#   'fulltext': 'Dota 2 Champions League/Season 1',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Champions_League/Season_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/10/17',
#      'timestamp': '1381968000'}],
#    'Has end date': [{'raw': '1/2014/1/15', 'timestamp': '1389744000'}],
#    'Has leagueid': ['103'],
#    'Has prizepool in usd': [50000]}},
#  'Dota 2 Champions League/Season 2': {'displaytitle': 'Dota 2 Champions League Season 2',
#   'exists': '1',
#   'fulltext': 'Dota 2 Champions League/Season 2',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Champions_League/Season_2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/2/9', 'timestamp': '1391904000'}],
#    'Has end date': [{'raw': '1/2014/4/15', 'timestamp': '1397520000'}],
#    'Has leagueid': ['196'],
#    'Has prizepool in usd': [124165]}},
#  'Dota 2 Champions League/Season 3': {'displaytitle': 'Dota 2 Champions League Season 3',
#   'exists': '1',
#   'fulltext': 'Dota 2 Champions League/Season 3',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Champions_League/Season_3',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/4/25',
#      'timestamp': '1398384000'}],
#    'Has end date': [{'raw': '1/2014/6/25', 'timestamp': '1403654400'}],
#    'Has leagueid': ['1068'],
#    'Has prizepool in usd': [67835]}},
#  'Dota 2 Champions League/Season 4': {'displaytitle': 'Dota 2 Champions League Season 4',
#   'exists': '1',
#   'fulltext': 'Dota 2 Champions League/Season 4',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Champions_League/Season_4',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/9/1', 'timestamp': '1409529600'}],
#    'Has end date': [{'raw': '1/2014/11/2', 'timestamp': '1414886400'}],
#    'Has leagueid': ['1712'],
#    'Has prizepool in usd': [76235]}},
#  'Dota 2 Champions League/Season 5': {'displaytitle': 'Dota 2 Champions League Season 5',
#   'exists': '1',
#   'fulltext': 'Dota 2 Champions League/Season 5',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Champions_League/Season_5',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/2/23',
#      'timestamp': '1424649600'}],
#    'Has end date': [{'raw': '1/2015/5/10', 'timestamp': '1431216000'}],
#    'Has leagueid': ['2358'],
#    'Has prizepool in usd': [79504]}},
#  'Dota 2 Champions League/Season 6': {'displaytitle': 'Dota 2 Champions League Season 6',
#   'exists': '1',
#   'fulltext': 'Dota 2 Champions League/Season 6',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Champions_League/Season_6',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/9/20',
#      'timestamp': '1442707200'}],
#    'Has end date': [{'raw': '1/2015/11/12', 'timestamp': '1447286400'}],
#    'Has leagueid': ['3726'],
#    'Has prizepool in usd': [50000]}},
#  'Dota 2 League/Season 4': {'displaytitle': 'Dota 2 League Season 4',
#   'exists': '1',
#   'fulltext': 'Dota 2 League/Season 4',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_League/Season_4',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/1/7', 'timestamp': '1389052800'}],
#    'Has end date': [{'raw': '1/2014/1/8', 'timestamp': '1389139200'}],
#    'Has leagueid': ['104'],
#    'Has prizepool in usd': [50000]}},
#  'Dota 2 League/Season 5': {'displaytitle': 'Dota 2 League Season 5',
#   'exists': '1',
#   'fulltext': 'Dota 2 League/Season 5',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_League/Season_5',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/1/5', 'timestamp': '1420416000'}],
#    'Has end date': [{'raw': '1/2015/1/6', 'timestamp': '1420502400'}],
#    'Has leagueid': ['2096'],
#    'Has prizepool in usd': [58397]}},
#  'Dota 2 League/Western Challenge': {'displaytitle': 'HyperX D2L Western Challenge',
#   'exists': '1',
#   'fulltext': 'Dota 2 League/Western Challenge',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_League/Western_Challenge',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/4/1', 'timestamp': '1396310400'}],
#    'Has end date': [{'raw': '1/2014/6/24', 'timestamp': '1403568000'}],
#    'Has leagueid': ['1135'],
#    'Has prizepool in usd': [68517]}},
#  'Dota 2 Radiant & Dire Cup/2015': {'displaytitle': 'Dota 2 Radiant & Dire Cup 2015',
#   'exists': '1',
#   'fulltext': 'Dota 2 Radiant & Dire Cup/2015',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Radiant_%26_Dire_Cup/2015',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/12/25',
#      'timestamp': '1451001600'}],
#    'Has end date': [{'raw': '1/2015/12/27', 'timestamp': '1451174400'}],
#    'Has leagueid': ['3877'],
#    'Has prizepool in usd': [154823]}},
#  'Dota 2 Super League': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Dota 2 Super League',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_2_Super_League',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/5/10',
#      'timestamp': '1368144000'}],
#    'Has end date': [{'raw': '1/2013/7/6', 'timestamp': '1373068800'}],
#    'Has leagueid': ['42'],
#    'Has prizepool in usd': [163050]}},
#  'Dota Pit League/Season 2': {'displaytitle': 'Dota Pit League Season 2',
#   'exists': '1',
#   'fulltext': 'Dota Pit League/Season 2',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_Pit_League/Season_2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/9/25',
#      'timestamp': '1411603200'}],
#    'Has end date': [{'raw': '1/2014/12/23', 'timestamp': '1419292800'}],
#    'Has leagueid': ['1942'],
#    'Has prizepool in usd': [80589]}},
#  'Dota Pit League/Season 3': {'displaytitle': 'Dota Pit League Season 3',
#   'exists': '1',
#   'fulltext': 'Dota Pit League/Season 3',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_Pit_League/Season_3',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/1/21',
#      'timestamp': '1421798400'}],
#    'Has end date': [{'raw': '1/2015/7/12', 'timestamp': '1436659200'}],
#    'Has leagueid': ['2129'],
#    'Has prizepool in usd': [265378]}},
#  'Dota Pit League/Season 4': {'displaytitle': 'Dota Pit League Season 4',
#   'exists': '1',
#   'fulltext': 'Dota Pit League/Season 4',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_Pit_League/Season_4',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/3/19',
#      'timestamp': '1458345600'}],
#    'Has end date': [{'raw': '1/2016/3/20', 'timestamp': '1458432000'}],
#    'Has leagueid': ['4210'],
#    'Has prizepool in usd': [195274]}},
#  'Dota Pit League/Season 5': {'displaytitle': 'Dota Pit League Season 5',
#   'exists': '1',
#   'fulltext': 'Dota Pit League/Season 5',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_Pit_League/Season_5',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/1/20',
#      'timestamp': '1484870400'}],
#    'Has end date': [{'raw': '1/2017/1/22', 'timestamp': '1485043200'}],
#    'Has leagueid': ['4979'],
#    'Has prizepool in usd': [139860]}},
#  'Dota Pit League/Season 6': {'displaytitle': 'AMD SAPPHIRE Dota PIT League',
#   'exists': '1',
#   'fulltext': 'Dota Pit League/Season 6',
#   'fullurl': 'http://liquipedia.net/dota2/Dota_Pit_League/Season_6',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/11/2',
#      'timestamp': '1509580800'}],
#    'Has end date': [{'raw': '1/2017/11/5', 'timestamp': '1509840000'}],
#    'Has leagueid': ['5690'],
#    'Has prizepool in usd': [300000]}},
#  'Dota2 ACE/Provisional': {'displaytitle': 'Dota2 ACE - Provisional',
#   'exists': '1',
#   'fulltext': 'Dota2 ACE/Provisional',
#   'fullurl': 'http://liquipedia.net/dota2/Dota2_ACE/Provisional',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/10/16',
#      'timestamp': '1476576000'}],
#    'Has end date': [{'raw': '1/2016/12/26', 'timestamp': '1482710400'}],
#    'Has leagueid': ['5006'],
#    'Has prizepool in usd': [60975.6]}},
#  'Dota2 Battle Arena': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Dota2 Battle Arena',
#   'fullurl': 'http://liquipedia.net/dota2/Dota2_Battle_Arena',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/11/11',
#      'timestamp': '1447200000'}],
#    'Has end date': [{'raw': '1/2015/11/15', 'timestamp': '1447545600'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [100000]}},
#  'Dota2 Professional League/Season 1': {'displaytitle': 'Dota2 Professional League Season 1',
#   'exists': '1',
#   'fulltext': 'Dota2 Professional League/Season 1',
#   'fullurl': 'http://liquipedia.net/dota2/Dota2_Professional_League/Season_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/5/18',
#      'timestamp': '1463529600'}],
#    'Has end date': [{'raw': '1/2016/7/17', 'timestamp': '1468713600'}],
#    'Has leagueid': ['4693'],
#    'Has prizepool in usd': [200000]}},
#  'Dota2 Professional League/Season 2/Secondary': {'displaytitle': 'Dota2 Professional League Season 2 - Secondary',
#   'exists': '1',
#   'fulltext': 'Dota2 Professional League/Season 2/Secondary',
#   'fullurl': 'http://liquipedia.net/dota2/Dota2_Professional_League/Season_2/Secondary',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/9/19',
#      'timestamp': '1474243200'}],
#    'Has end date': [{'raw': '1/2016/12/13', 'timestamp': '1481587200'}],
#    'Has leagueid': ['4920'],
#    'Has prizepool in usd': [100000]}},
#  'Dota2 Professional League/Season 2/Top': {'displaytitle': 'Dota2 Professional League Season 2 - Top',
#   'exists': '1',
#   'fulltext': 'Dota2 Professional League/Season 2/Top',
#   'fullurl': 'http://liquipedia.net/dota2/Dota2_Professional_League/Season_2/Top',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/9/23',
#      'timestamp': '1474588800'}],
#    'Has end date': [{'raw': '1/2016/12/31', 'timestamp': '1483142400'}],
#    'Has leagueid': ['4920'],
#    'Has prizepool in usd': [700000]}},
#  'Dota2 Professional League/Season 3/Top': {'displaytitle': 'Dota2 Professional League Season 3 (2017 S1) - Top',
#   'exists': '1',
#   'fulltext': 'Dota2 Professional League/Season 3/Top',
#   'fullurl': 'http://liquipedia.net/dota2/Dota2_Professional_League/Season_3/Top',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/3/15',
#      'timestamp': '1489536000'}],
#    'Has end date': [{'raw': '1/2017/4/16', 'timestamp': '1492300800'}],
#    'Has leagueid': ['4920'],
#    'Has prizepool in usd': [72595]}},
#  'Dota2 Professional League/Season 4/Top': {'displaytitle': 'Dota2 Professional League Season 4 (2017 S2)- Top',
#   'exists': '1',
#   'fulltext': 'Dota2 Professional League/Season 4/Top',
#   'fullurl': 'http://liquipedia.net/dota2/Dota2_Professional_League/Season_4/Top',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/9/30',
#      'timestamp': '1506729600'}],
#    'Has end date': [{'raw': '1/2017/11/12', 'timestamp': '1510444800'}],
#    'Has leagueid': ['4920'],
#    'Has prizepool in usd': [143070]}},
#  'Dota2 Star Championship': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Dota2 Star Championship',
#   'fullurl': 'http://liquipedia.net/dota2/Dota2_Star_Championship',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2011/12/8',
#      'timestamp': '1323302400'}],
#    'Has end date': [{'raw': '1/2011/12/11', 'timestamp': '1323561600'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [20000]}},
#  'Dota2Replays Brawl': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Dota2Replays Brawl',
#   'fullurl': 'http://liquipedia.net/dota2/Dota2Replays_Brawl',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2012/1/14',
#      'timestamp': '1326499200'}],
#    'Has end date': [{'raw': '1/2012/3/12', 'timestamp': '1331510400'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [6000]}},
#  'DreamHack/2011/Winter': {'displaytitle': 'DreamHack Winter 2011',
#   'exists': '1',
#   'fulltext': 'DreamHack/2011/Winter',
#   'fullurl': 'http://liquipedia.net/dota2/DreamHack/2011/Winter',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2011/11/24',
#      'timestamp': '1322092800'}],
#    'Has end date': [{'raw': '1/2011/11/26', 'timestamp': '1322265600'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [14500]}},
#  'DreamHack/2012/Summer': {'displaytitle': 'DreamHack Summer 2012',
#   'exists': '1',
#   'fulltext': 'DreamHack/2012/Summer',
#   'fullurl': 'http://liquipedia.net/dota2/DreamHack/2012/Summer',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2012/6/16',
#      'timestamp': '1339804800'}],
#    'Has end date': [{'raw': '1/2012/6/18', 'timestamp': '1339977600'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [28772]}},
#  'DreamHack/2012/Winter': {'displaytitle': 'DreamHack Winter 2012',
#   'exists': '1',
#   'fulltext': 'DreamHack/2012/Winter',
#   'fullurl': 'http://liquipedia.net/dota2/DreamHack/2012/Winter',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2012/11/22',
#      'timestamp': '1353542400'}],
#    'Has end date': [{'raw': '1/2012/11/25', 'timestamp': '1353801600'}],
#    'Has leagueid': ['65002'],
#    'Has prizepool in usd': [30198]}},
#  'DreamHack/2013/Invitational': {'displaytitle': 'DreamHack Dota 2 Invitational',
#   'exists': '1',
#   'fulltext': 'DreamHack/2013/Invitational',
#   'fullurl': 'http://liquipedia.net/dota2/DreamHack/2013/Invitational',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/3/14',
#      'timestamp': '1363219200'}],
#    'Has end date': [{'raw': '1/2013/4/18', 'timestamp': '1366243200'}],
#    'Has leagueid': ['33'],
#    'Has prizepool in usd': [6000]}},
#  'DreamHack/2013/Summer': {'displaytitle': 'DreamHack Summer 2013',
#   'exists': '1',
#   'fulltext': 'DreamHack/2013/Summer',
#   'fullurl': 'http://liquipedia.net/dota2/DreamHack/2013/Summer',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/6/15',
#      'timestamp': '1371254400'}],
#    'Has end date': [{'raw': '1/2013/6/17', 'timestamp': '1371427200'}],
#    'Has leagueid': ['53'],
#    'Has prizepool in usd': [46422]}},
#  'DreamHack/2014/Bucharest': {'displaytitle': 'DreamHack Bucharest Invitational',
#   'exists': '1',
#   'fulltext': 'DreamHack/2014/Bucharest',
#   'fullurl': 'http://liquipedia.net/dota2/DreamHack/2014/Bucharest',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/4/26',
#      'timestamp': '1398470400'}],
#    'Has end date': [{'raw': '1/2014/4/27', 'timestamp': '1398556800'}],
#    'Has leagueid': ['1123'],
#    'Has prizepool in usd': [25000]}},
#  'DreamLeague/Kick-Off Season': {'displaytitle': 'ASUS ROG DreamLeague Kick-Off Season',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Kick-Off Season',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Kick-Off_Season',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/11/4',
#      'timestamp': '1383523200'}],
#    'Has end date': [{'raw': '1/2013/11/30', 'timestamp': '1385769600'}],
#    'Has leagueid': ['112'],
#    'Has prizepool in usd': [50000]}},
#  'DreamLeague/Season 1': {'displaytitle': 'ASUS ROG DreamLeague Season 1',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 1',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/3/3', 'timestamp': '1393804800'}],
#    'Has end date': [{'raw': '1/2014/6/16', 'timestamp': '1402876800'}],
#    'Has leagueid': ['223'],
#    'Has prizepool in usd': [265257]}},
#  'DreamLeague/Season 2': {'displaytitle': 'ASUS ROG DreamLeague Season 2',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 2',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/10/6',
#      'timestamp': '1412553600'}],
#    'Has end date': [{'raw': '1/2014/11/29', 'timestamp': '1417219200'}],
#    'Has leagueid': ['2190'],
#    'Has prizepool in usd': [115560]}},
#  'DreamLeague/Season 3': {'displaytitle': 'ASUS ROG DreamLeague Season 3',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 3',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_3',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/3/28',
#      'timestamp': '1427500800'}],
#    'Has end date': [{'raw': '1/2015/6/15', 'timestamp': '1434326400'}],
#    'Has leagueid': ['2790'],
#    'Has prizepool in usd': [149582]}},
#  'DreamLeague/Season 4': {'displaytitle': 'ASUS ROG DreamLeague Season 4',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 4',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_4',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/9/29',
#      'timestamp': '1443484800'}],
#    'Has end date': [{'raw': '1/2015/11/28', 'timestamp': '1448668800'}],
#    'Has leagueid': ['3865'],
#    'Has prizepool in usd': [150000]}},
#  'DreamLeague/Season 5': {'displaytitle': 'DreamLeague Season 5',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 5',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_5',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/5/21',
#      'timestamp': '1463788800'}],
#    'Has end date': [{'raw': '1/2016/5/22', 'timestamp': '1463875200'}],
#    'Has leagueid': ['4507'],
#    'Has prizepool in usd': [100000]}},
#  'DreamLeague/Season 6': {'displaytitle': 'ASUS ROG DreamLeague Season 6',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 6',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_6',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/11/25',
#      'timestamp': '1480032000'}],
#    'Has end date': [{'raw': '1/2016/11/26', 'timestamp': '1480118400'}],
#    'Has leagueid': ['4951'],
#    'Has prizepool in usd': [185000]}},
#  'DreamLeague/Season 6/League Play': {'displaytitle': 'DreamLeague Season 6 League Play',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 6/League Play',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_6/League_Play',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/10/11',
#      'timestamp': '1476144000'}],
#    'Has end date': [{'raw': '1/2016/11/8', 'timestamp': '1478563200'}],
#    'Has leagueid': ['4951'],
#    'Has prizepool in usd': [56000]}},
#  'DreamLeague/Season 7': {'displaytitle': 'DreamLeague Season 7',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 7',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_7',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/7/21',
#      'timestamp': '1500595200'}],
#    'Has end date': [{'raw': '1/2017/7/22', 'timestamp': '1500681600'}],
#    'Has leagueid': ['5336'],
#    'Has prizepool in usd': [175000]}},
#  'DreamLeague/Season 7/EU Division': {'displaytitle': 'DreamLeague Season 7 EU Division',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 7/EU Division',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_7/EU_Division',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/5/4', 'timestamp': '1493856000'}],
#    'Has end date': [{'raw': '1/2017/5/21', 'timestamp': '1495324800'}],
#    'Has leagueid': ['5336'],
#    'Has prizepool in usd': [56000]}},
#  'DreamLeague/Season 7/NA Division': {'displaytitle': 'DreamLeague Season 7 NA Division',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 7/NA Division',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_7/NA_Division',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/5/30',
#      'timestamp': '1496102400'}],
#    'Has end date': [{'raw': '1/2017/5/31', 'timestamp': '1496188800'}],
#    'Has leagueid': ['5336'],
#    'Has prizepool in usd': [12000]}},
#  'DreamLeague/Season 8': {'displaytitle': 'DreamLeague Season 8',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 8',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_8',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/12/1',
#      'timestamp': '1512086400'}],
#    'Has end date': [{'raw': '1/2017/12/3', 'timestamp': '1512259200'}],
#    'Has leagueid': ['5627'],
#    'Has prizepool in usd': [1000000]}},
#  'DreamLeague/Season 9': {'displaytitle': 'DreamLeague Season 9',
#   'exists': '1',
#   'fulltext': 'DreamLeague/Season 9',
#   'fullurl': 'http://liquipedia.net/dota2/DreamLeague/Season_9',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2018/3/21',
#      'timestamp': '1521590400'}],
#    'Has end date': [{'raw': '1/2018/3/25', 'timestamp': '1521936000'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [300000]}},
#  'E2MAX L33t Championship': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'E2MAX L33t Championship',
#   'fullurl': 'http://liquipedia.net/dota2/E2MAX_L33t_Championship',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/7/7', 'timestamp': '1373155200'}],
#    'Has end date': [{'raw': '1/2013/7/7', 'timestamp': '1373155200'}],
#    'Has leagueid': ['38'],
#    'Has prizepool in usd': [10400]}},
#  'ECL 2013/Finals': {'displaytitle': 'Red Bull ECL 2013 Grand Finals',
#   'exists': '1',
#   'fulltext': 'ECL 2013/Finals',
#   'fullurl': 'http://liquipedia.net/dota2/ECL_2013/Finals',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/1/3', 'timestamp': '1388707200'}],
#    'Has end date': [{'raw': '1/2014/1/7', 'timestamp': '1389052800'}],
#    'Has leagueid': ['52'],
#    'Has prizepool in usd': [21476]}},
#  'ECL 2013/Season': {'displaytitle': 'Red Bull ECL 2013 Dota 2 Season',
#   'exists': '1',
#   'fulltext': 'ECL 2013/Season',
#   'fullurl': 'http://liquipedia.net/dota2/ECL_2013/Season',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/7/10',
#      'timestamp': '1373414400'}],
#    'Has end date': [{'raw': '1/2013/7/14', 'timestamp': '1373760000'}],
#    'Has leagueid': ['52'],
#    'Has prizepool in usd': [21165.3]}},
#  'ECL 2014/Autumn': {'displaytitle': 'ECL 2014 Autumn',
#   'exists': '1',
#   'fulltext': 'ECL 2014/Autumn',
#   'fullurl': 'http://liquipedia.net/dota2/ECL_2014/Autumn',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/9/12',
#      'timestamp': '1410480000'}],
#    'Has end date': [{'raw': '1/2014/12/30', 'timestamp': '1419897600'}],
#    'Has leagueid': ['1116'],
#    'Has prizepool in usd': [20930]}},
#  'ECL 2014/Season 1': {'displaytitle': 'ECL 2014 Spring',
#   'exists': '1',
#   'fulltext': 'ECL 2014/Season 1',
#   'fullurl': 'http://liquipedia.net/dota2/ECL_2014/Season_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/3/26',
#      'timestamp': '1395792000'}],
#    'Has end date': [{'raw': '1/2014/6/15', 'timestamp': '1402790400'}],
#    'Has leagueid': ['1116'],
#    'Has prizepool in usd': [20935.2]}},
#  'ECL/2015/Autumn': {'displaytitle': 'ECL 2015 Autumn',
#   'exists': '1',
#   'fulltext': 'ECL/2015/Autumn',
#   'fullurl': 'http://liquipedia.net/dota2/ECL/2015/Autumn',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/10/16',
#      'timestamp': '1444953600'}],
#    'Has end date': [{'raw': '1/2015/12/30', 'timestamp': '1451433600'}],
#    'Has leagueid': ['3904'],
#    'Has prizepool in usd': [30816]}},
#  'ECL/2015/Spring': {'displaytitle': 'ECL 2015 Spring',
#   'exists': '1',
#   'fulltext': 'ECL/2015/Spring',
#   'fullurl': 'http://liquipedia.net/dota2/ECL/2015/Spring',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/4/11',
#      'timestamp': '1428710400'}],
#    'Has end date': [{'raw': '1/2015/6/14', 'timestamp': '1434240000'}],
#    'Has leagueid': ['2985'],
#    'Has prizepool in usd': [32090]}},
#  'EPICENTER/2016': {'displaytitle': 'EPICENTER 2016',
#   'exists': '1',
#   'fulltext': 'EPICENTER/2016',
#   'fullurl': 'http://liquipedia.net/dota2/EPICENTER/2016',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/5/9', 'timestamp': '1462752000'}],
#    'Has end date': [{'raw': '1/2016/5/15', 'timestamp': '1463270400'}],
#    'Has leagueid': ['4461'],
#    'Has prizepool in usd': [500000]}},
#  'EPICENTER/2017': {'displaytitle': 'EPICENTER 2017',
#   'exists': '1',
#   'fulltext': 'EPICENTER/2017',
#   'fullurl': 'http://liquipedia.net/dota2/EPICENTER/2017',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/6/4', 'timestamp': '1496534400'}],
#    'Has end date': [{'raw': '1/2017/6/11', 'timestamp': '1497139200'}],
#    'Has leagueid': ['5353'],
#    'Has prizepool in usd': [500000]}},
#  'EPICENTER/2018': {'displaytitle': 'EPICENTER XL',
#   'exists': '1',
#   'fulltext': 'EPICENTER/2018',
#   'fullurl': 'http://liquipedia.net/dota2/EPICENTER/2018',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2018/4/27',
#      'timestamp': '1524787200'}],
#    'Has end date': [{'raw': '1/2018/5/6', 'timestamp': '1525564800'}],
#    'Has leagueid': ['9601'],
#    'Has prizepool in usd': [1000000]}},
#  'ESL Major Series One/Fall/Main Event': {'displaytitle': 'RaidCall EMS One Fall Season',
#   'exists': '1',
#   'fulltext': 'ESL Major Series One/Fall/Main Event',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_Major_Series_One/Fall/Main_Event',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/9/2', 'timestamp': '1378080000'}],
#    'Has end date': [{'raw': '1/2013/12/8', 'timestamp': '1386460800'}],
#    'Has leagueid': ['70'],
#    'Has prizepool in usd': [39000]}},
#  'ESL Major Series One/Spring/Main Event': {'displaytitle': 'RaidCall EMS One Spring Season',
#   'exists': '1',
#   'fulltext': 'ESL Major Series One/Spring/Main Event',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_Major_Series_One/Spring/Main_Event',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/3/18',
#      'timestamp': '1363564800'}],
#    'Has end date': [{'raw': '1/2013/4/21', 'timestamp': '1366502400'}],
#    'Has leagueid': ['28'],
#    'Has prizepool in usd': [35000]}},
#  'ESL Major Series One/Summer/Main Event': {'displaytitle': 'RaidCall EMS One Summer Season',
#   'exists': '1',
#   'fulltext': 'ESL Major Series One/Summer/Main Event',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_Major_Series_One/Summer/Main_Event',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/6/19',
#      'timestamp': '1371600000'}],
#    'Has end date': [{'raw': '1/2013/7/14', 'timestamp': '1373760000'}],
#    'Has leagueid': ['47'],
#    'Has prizepool in usd': [35000]}},
#  'ESL One/Frankfurt/2014': {'displaytitle': 'ESL One Frankfurt 2014',
#   'exists': '1',
#   'fulltext': 'ESL One/Frankfurt/2014',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/Frankfurt/2014',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/6/28',
#      'timestamp': '1403913600'}],
#    'Has end date': [{'raw': '1/2014/6/29', 'timestamp': '1404000000'}],
#    'Has leagueid': ['1248'],
#    'Has prizepool in usd': [210900]}},
#  'ESL One/Frankfurt/2015': {'displaytitle': 'ESL One Frankfurt 2015',
#   'exists': '1',
#   'fulltext': 'ESL One/Frankfurt/2015',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/Frankfurt/2015',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/6/20',
#      'timestamp': '1434758400'}],
#    'Has end date': [{'raw': '1/2015/6/21', 'timestamp': '1434844800'}],
#    'Has leagueid': ['2686'],
#    'Has prizepool in usd': [286622]}},
#  'ESL One/Frankfurt/2016': {'displaytitle': 'ESL One Frankfurt 2016',
#   'exists': '1',
#   'fulltext': 'ESL One/Frankfurt/2016',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/Frankfurt/2016',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/6/17',
#      'timestamp': '1466121600'}],
#    'Has end date': [{'raw': '1/2016/6/19', 'timestamp': '1466294400'}],
#    'Has leagueid': ['4554'],
#    'Has prizepool in usd': [314545]}},
#  'ESL One/Genting/2017': {'displaytitle': 'ESL One Genting 2017',
#   'exists': '1',
#   'fulltext': 'ESL One/Genting/2017',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/Genting/2017',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/1/6', 'timestamp': '1483660800'}],
#    'Has end date': [{'raw': '1/2017/1/8', 'timestamp': '1483833600'}],
#    'Has leagueid': ['5018'],
#    'Has prizepool in usd': [250000]}},
#  'ESL One/Genting/2018': {'displaytitle': 'ESL One Genting 2018',
#   'exists': '1',
#   'fulltext': 'ESL One/Genting/2018',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/Genting/2018',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2018/1/23',
#      'timestamp': '1516665600'}],
#    'Has end date': [{'raw': '1/2018/1/28', 'timestamp': '1517097600'}],
#    'Has leagueid': ['8093'],
#    'Has prizepool in usd': [400000]}},
#  'ESL One/Hamburg/2017': {'displaytitle': 'ESL One Hamburg 2017',
#   'exists': '1',
#   'fulltext': 'ESL One/Hamburg/2017',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/Hamburg/2017',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/10/26',
#      'timestamp': '1508976000'}],
#    'Has end date': [{'raw': '1/2017/10/29', 'timestamp': '1509235200'}],
#    'Has leagueid': ['5609'],
#    'Has prizepool in usd': [1000000]}},
#  'ESL One/Katowice/2018': {'displaytitle': 'ESL One Katowice 2018',
#   'exists': '1',
#   'fulltext': 'ESL One/Katowice/2018',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/Katowice/2018',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2018/2/20',
#      'timestamp': '1519084800'}],
#    'Has end date': [{'raw': '1/2018/2/25', 'timestamp': '1519516800'}],
#    'Has leagueid': ['9633'],
#    'Has prizepool in usd': [1000000]}},
#  'ESL One/Manila/2016': {'displaytitle': 'ESL One Manila 2016',
#   'exists': '1',
#   'fulltext': 'ESL One/Manila/2016',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/Manila/2016',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/4/22',
#      'timestamp': '1461283200'}],
#    'Has end date': [{'raw': '1/2016/4/24', 'timestamp': '1461456000'}],
#    'Has leagueid': ['4357'],
#    'Has prizepool in usd': [250000]}},
#  'ESL One/New York/2014': {'displaytitle': 'ESL One New York 2014',
#   'exists': '1',
#   'fulltext': 'ESL One/New York/2014',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/New_York/2014',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/10/9',
#      'timestamp': '1412812800'}],
#    'Has end date': [{'raw': '1/2014/10/10', 'timestamp': '1412899200'}],
#    'Has leagueid': ['1886'],
#    'Has prizepool in usd': [141010]}},
#  'ESL One/New York/2015': {'displaytitle': 'ESL One New York 2015',
#   'exists': '1',
#   'fulltext': 'ESL One/New York/2015',
#   'fullurl': 'http://liquipedia.net/dota2/ESL_One/New_York/2015',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/10/3',
#      'timestamp': '1443830400'}],
#    'Has end date': [{'raw': '1/2015/10/4', 'timestamp': '1443916800'}],
#    'Has leagueid': ['3798'],
#    'Has prizepool in usd': [286622]}},
#  'Electronic Sports Prime/Shock Therapy Cup': {'displaytitle': 'Electronic Sports Prime Shock Therapy Cup',
#   'exists': '1',
#   'fulltext': 'Electronic Sports Prime/Shock Therapy Cup',
#   'fullurl': 'http://liquipedia.net/dota2/Electronic_Sports_Prime/Shock_Therapy_Cup',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/1/31',
#      'timestamp': '1391126400'}],
#    'Has end date': [{'raw': '1/2014/2/8', 'timestamp': '1391817600'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [10000]}},
#  'Electronic Sports World Cup 2011': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Electronic Sports World Cup 2011',
#   'fullurl': 'http://liquipedia.net/dota2/Electronic_Sports_World_Cup_2011',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2011/10/21',
#      'timestamp': '1319155200'}],
#    'Has end date': [{'raw': '1/2011/10/25', 'timestamp': '1319500800'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [22000]}},
#  'Electronic Sports World Cup 2012': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Electronic Sports World Cup 2012',
#   'fullurl': 'http://liquipedia.net/dota2/Electronic_Sports_World_Cup_2012',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2012/11/2',
#      'timestamp': '1351814400'}],
#    'Has end date': [{'raw': '1/2012/11/4', 'timestamp': '1351987200'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [25000]}},
#  'Electronic Sports World Cup 2013': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Electronic Sports World Cup 2013',
#   'fullurl': 'http://liquipedia.net/dota2/Electronic_Sports_World_Cup_2013',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/10/31',
#      'timestamp': '1383177600'}],
#    'Has end date': [{'raw': '1/2013/11/3', 'timestamp': '1383436800'}],
#    'Has leagueid': ['61'],
#    'Has prizepool in usd': [25000]}},
#  'Elimination Mode/3': {'displaytitle': 'Elimination Mode 3.0',
#   'exists': '1',
#   'fulltext': 'Elimination Mode/3',
#   'fullurl': 'http://liquipedia.net/dota2/Elimination_Mode/3',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/2/11',
#      'timestamp': '1486771200'}],
#    'Has end date': [{'raw': '1/2017/2/17', 'timestamp': '1487289600'}],
#    'Has leagueid': ['4289'],
#    'Has prizepool in usd': [25000]}},
#  'Esportal Dota 2 League': {'displaytitle': 'Esportal Dota 2 League',
#   'exists': '1',
#   'fulltext': 'Esportal Dota 2 League',
#   'fullurl': 'http://liquipedia.net/dota2/Esportal_Dota_2_League',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/11/28',
#      'timestamp': '1417132800'}],
#    'Has end date': [{'raw': '1/2015/7/5', 'timestamp': '1436054400'}],
#    'Has leagueid': ['2172'],
#    'Has prizepool in usd': [64000]}},
#  'Esportal Dota 2 League/Invitational Tournament 1': {'displaytitle': 'Esportal Dota 2 League Invitational Tournament 1',
#   'exists': '1',
#   'fulltext': 'Esportal Dota 2 League/Invitational Tournament 1',
#   'fullurl': 'http://liquipedia.net/dota2/Esportal_Dota_2_League/Invitational_Tournament_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/12/10',
#      'timestamp': '1418169600'}],
#    'Has end date': [{'raw': '1/2014/12/14', 'timestamp': '1418515200'}],
#    'Has leagueid': ['2172'],
#    'Has prizepool in usd': [18691.472328]}},
#  'Excellent Moscow Cup/Season 1': {'displaytitle': 'Excellent Moscow Cup Season 1',
#   'exists': '1',
#   'fulltext': 'Excellent Moscow Cup/Season 1',
#   'fullurl': 'http://liquipedia.net/dota2/Excellent_Moscow_Cup/Season_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/3/28',
#      'timestamp': '1395964800'}],
#    'Has end date': [{'raw': '1/2014/5/18', 'timestamp': '1400371200'}],
#    'Has leagueid': ['1003'],
#    'Has prizepool in usd': [20125]}},
#  'Excellent Moscow Cup/Season 2': {'displaytitle': 'Excellent Moscow Cup Season 2',
#   'exists': '1',
#   'fulltext': 'Excellent Moscow Cup/Season 2',
#   'fullurl': 'http://liquipedia.net/dota2/Excellent_Moscow_Cup/Season_2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/8/26',
#      'timestamp': '1409011200'}],
#    'Has end date': [{'raw': '1/2014/10/29', 'timestamp': '1414540800'}],
#    'Has leagueid': ['1761'],
#    'Has prizepool in usd': [75575]}},
#  'FACEIT/Invitational/1': {'displaytitle': 'FACEIT Invitational',
#   'exists': '1',
#   'fulltext': 'FACEIT/Invitational/1',
#   'fullurl': 'http://liquipedia.net/dota2/FACEIT/Invitational/1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/10/17',
#      'timestamp': '1476662400'}],
#    'Has end date': [{'raw': '1/2016/10/19', 'timestamp': '1476835200'}],
#    'Has leagueid': ['4122'],
#    'Has prizepool in usd': [25000]}},
#  'Fengyun Dota 2 Tournament': {'displaytitle': 'Fengyun Dota 2 Tournament',
#   'exists': '1',
#   'fulltext': 'Fengyun Dota 2 Tournament',
#   'fullurl': 'http://liquipedia.net/dota2/Fengyun_Dota_2_Tournament',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/12/23',
#      'timestamp': '1387756800'}],
#    'Has end date': [{'raw': '1/2013/12/28', 'timestamp': '1388188800'}],
#    'Has leagueid': ['91'],
#    'Has prizepool in usd': [13191]}},
#  'Fragbite Masters 2013': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Fragbite Masters 2013',
#   'fullurl': 'http://liquipedia.net/dota2/Fragbite_Masters_2013',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/10/21',
#      'timestamp': '1382313600'}],
# ...
#   'fullurl': 'http://liquipedia.net/dota2/The_Summit/8',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/12/13',
#      'timestamp': '1513123200'}],
#    'Has end date': [{'raw': '1/2017/12/17', 'timestamp': '1513468800'}],
#    'Has leagueid': ['5850'],
#    'Has prizepool in usd': [300000]}},
#  'Thor Open 2012': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'Thor Open 2012',
#   'fullurl': 'http://liquipedia.net/dota2/Thor_Open_2012',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2012/12/8',
#      'timestamp': '1354924800'}],
#    'Has end date': [{'raw': '1/2012/12/9', 'timestamp': '1355011200'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [19459.62]}},
#  'User:Hoperz/VIP LAN CENTER': {'displaytitle': 'VIP LAN CENTER',
#   'exists': '1',
#   'fulltext': 'User:Hoperz/VIP LAN CENTER',
#   'fullurl': 'http://liquipedia.net/dota2/User:Hoperz/VIP_LAN_CENTER',
#   'namespace': 2,
#   'printouts': {'Has date': [{'raw': '1/2015/7/27',
#      'timestamp': '1437955200'}],
#    'Has end date': [{'raw': '1/2015/8/8', 'timestamp': '1438992000'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': []}},
#  'V Games Tournament': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'V Games Tournament',
#   'fullurl': 'http://liquipedia.net/dota2/V_Games_Tournament',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/6/2', 'timestamp': '1401667200'}],
#    'Has end date': [{'raw': '1/2014/6/25', 'timestamp': '1403654400'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [16042]}},
#  'VPGame Pro League/Season 1': {'displaytitle': 'VPGame Pro League Season 1',
#   'exists': '1',
#   'fulltext': 'VPGame Pro League/Season 1',
#   'fullurl': 'http://liquipedia.net/dota2/VPGame_Pro_League/Season_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/4/6', 'timestamp': '1428278400'}],
#    'Has end date': [{'raw': '1/2015/4/19', 'timestamp': '1429401600'}],
#    'Has leagueid': ['2912'],
#    'Has prizepool in usd': [24186]}},
#  'VPGame Pro League/Season 2': {'displaytitle': 'VPGame Pro League Season 2',
#   'exists': '1',
#   'fulltext': 'VPGame Pro League/Season 2',
#   'fullurl': 'http://liquipedia.net/dota2/VPGame_Pro_League/Season_2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/7/20',
#      'timestamp': '1468972800'}],
#    'Has end date': [{'raw': '1/2016/7/31', 'timestamp': '1469923200'}],
#    'Has leagueid': ['4777'],
#    'Has prizepool in usd': [45198]}},
#  'WCG Asia 2012': {'displaytitle': 'WCG Asian Championship 2012',
#   'exists': '1',
#   'fulltext': 'WCG Asia 2012',
#   'fullurl': 'http://liquipedia.net/dota2/WCG_Asia_2012',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2012/9/8', 'timestamp': '1347062400'}],
#    'Has end date': [{'raw': '1/2012/9/9', 'timestamp': '1347148800'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [6000]}},
#  'WPC 2014': {'displaytitle': 'WPC 2014',
#   'exists': '1',
#   'fulltext': 'WPC 2014',
#   'fullurl': 'http://liquipedia.net/dota2/WPC_2014',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/3/29',
#      'timestamp': '1396051200'}],
#    'Has end date': [{'raw': '1/2014/6/2', 'timestamp': '1401667200'}],
#    'Has leagueid': ['1014'],
#    'Has prizepool in usd': [244885]}},
#  'WVW National Electronic Sports Classic/April': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'WVW National Electronic Sports Classic/April',
#   'fullurl': 'http://liquipedia.net/dota2/WVW_National_Electronic_Sports_Classic/April',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/4/9', 'timestamp': '1397001600'}],
#    'Has end date': [{'raw': '1/2014/5/1', 'timestamp': '1398902400'}],
#    'Has leagueid': ['1097'],
#    'Has prizepool in usd': [9586]}},
#  'WVW National Electronic Sports Classic/June': {'displaytitle': 'WVW National Electronic Sports Classic June',
#   'exists': '1',
#   'fulltext': 'WVW National Electronic Sports Classic/June',
#   'fullurl': 'http://liquipedia.net/dota2/WVW_National_Electronic_Sports_Classic/June',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/6/16',
#      'timestamp': '1402876800'}],
#    'Has end date': [{'raw': '1/2014/6/24', 'timestamp': '1403568000'}],
#    'Has leagueid': ['1097'],
#    'Has prizepool in usd': [8240]}},
#  'WePlay Dota2 League/Season 1': {'displaytitle': 'WePlay Dota2 League Season 1',
#   'exists': '1',
#   'fulltext': 'WePlay Dota2 League/Season 1',
#   'fullurl': 'http://liquipedia.net/dota2/WePlay_Dota2_League/Season_1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/3/9', 'timestamp': '1362787200'}],
#    'Has end date': [{'raw': '1/2013/5/13', 'timestamp': '1368403200'}],
#    'Has leagueid': ['32'],
#    'Has prizepool in usd': [8700]}},
#  'WePlay Dota2 League/Season 2': {'displaytitle': 'WePlay Dota2 League Season 2',
#   'exists': '1',
#   'fulltext': 'WePlay Dota2 League/Season 2',
#   'fullurl': 'http://liquipedia.net/dota2/WePlay_Dota2_League/Season_2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2013/9/11',
#      'timestamp': '1378857600'}],
#    'Has end date': [{'raw': '1/2013/11/10', 'timestamp': '1384041600'}],
#    'Has leagueid': ['78'],
#    'Has prizepool in usd': [25000]}},
#  'WePlay Dota2 League/Season 3': {'displaytitle': 'WePlay Dota2 League Season 3',
#   'exists': '1',
#   'fulltext': 'WePlay Dota2 League/Season 3',
#   'fullurl': 'http://liquipedia.net/dota2/WePlay_Dota2_League/Season_3',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/4/28',
#      'timestamp': '1461801600'}],
#    'Has end date': [{'raw': '1/2016/5/1', 'timestamp': '1462060800'}],
#    'Has leagueid': ['3454'],
#    'Has prizepool in usd': [208239]}},
#  'World Cyber Arena/2014': {'displaytitle': 'World Cyber Arena 2014',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2014',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2014',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/10/2',
#      'timestamp': '1412208000'}],
#    'Has end date': [{'raw': '1/2014/10/5', 'timestamp': '1412467200'}],
#    'Has leagueid': ['2045'],
#    'Has prizepool in usd': [468176]}},
#  'World Cyber Arena/2015': {'displaytitle': 'World Cyber Arena 2015',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2015',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2015',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/12/17',
#      'timestamp': '1450310400'}],
#    'Has end date': [{'raw': '1/2015/12/20', 'timestamp': '1450569600'}],
#    'Has leagueid': ['4088'],
#    'Has prizepool in usd': [663275]}},
#  'World Cyber Arena/2015/American Qualifiers': {'displaytitle': 'World Cyber Arena 2015 - American Pro Qualifiers',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2015/American Qualifiers',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2015/American_Qualifiers',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/5/3', 'timestamp': '1430611200'}],
#    'Has end date': [{'raw': '1/2015/6/2', 'timestamp': '1433203200'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [90000]}},
#  'World Cyber Arena/2015/Chinese Qualifiers': {'displaytitle': 'World Cyber Arena 2015 - Chinese Pro Qualifiers',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2015/Chinese Qualifiers',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2015/Chinese_Qualifiers',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/4/14',
#      'timestamp': '1428969600'}],
#    'Has end date': [{'raw': '1/2015/7/5', 'timestamp': '1436054400'}],
#    'Has leagueid': ['2922'],
#    'Has prizepool in usd': [129316.5]}},
#  'World Cyber Arena/2015/European Qualifiers': {'displaytitle': 'World Cyber Arena 2015 - European Pro Qualifiers',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2015/European Qualifiers',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2015/European_Qualifiers',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/9/21',
#      'timestamp': '1442793600'}],
#    'Has end date': [{'raw': '1/2015/9/24', 'timestamp': '1443052800'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [97500]}},
#  'World Cyber Arena/2015/SEA Qualifiers': {'displaytitle': 'World Cyber Arena 2015 - SEA Pro Qualifiers',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2015/SEA Qualifiers',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2015/SEA_Qualifiers',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2015/10/7',
#      'timestamp': '1444176000'}],
#    'Has end date': [{'raw': '1/2015/10/14', 'timestamp': '1444780800'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [102440]}},
#  'World Cyber Arena/2016': {'displaytitle': 'World Cyber Arena 2016',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2016',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2016',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/12/14',
#      'timestamp': '1481673600'}],
#    'Has end date': [{'raw': '1/2016/12/16', 'timestamp': '1481846400'}],
#    'Has leagueid': ['5115'],
#    'Has prizepool in usd': [589252]}},
#  'World Cyber Arena/2016/America Qualifier': {'displaytitle': 'World Cyber Arena 2016 AM Qualifiers',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2016/America Qualifier',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2016/America_Qualifier',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/11/11',
#      'timestamp': '1478822400'}],
#    'Has end date': [{'raw': '1/2016/11/13', 'timestamp': '1478995200'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [55000]}},
#  'World Cyber Arena/2016/Chinese Qualifiers/S1': {'displaytitle': 'World Cyber Arena 2016 Chinese Qualifiers S1',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2016/Chinese Qualifiers/S1',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2016/Chinese_Qualifiers/S1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/3/19',
#      'timestamp': '1458345600'}],
#    'Has end date': [{'raw': '1/2016/5/19', 'timestamp': '1463616000'}],
#    'Has leagueid': ['4405'],
#    'Has prizepool in usd': [61100]}},
#  'World Cyber Arena/2016/Chinese Qualifiers/S2': {'displaytitle': 'World Cyber Arena 2016 Chinese Qualifiers S2',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2016/Chinese Qualifiers/S2',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2016/Chinese_Qualifiers/S2',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/6/13',
#      'timestamp': '1465776000'}],
#    'Has end date': [{'raw': '1/2016/9/25', 'timestamp': '1474761600'}],
#    'Has leagueid': ['4525'],
#    'Has prizepool in usd': [59956]}},
#  'World Cyber Arena/2016/Chinese Qualifiers/S3': {'displaytitle': 'World Cyber Arena 2016 Chinese Qualifiers S3',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2016/Chinese Qualifiers/S3',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2016/Chinese_Qualifiers/S3',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/10/5',
#      'timestamp': '1475625600'}],
#    'Has end date': [{'raw': '1/2016/11/12', 'timestamp': '1478908800'}],
#    'Has leagueid': ['4837'],
#    'Has prizepool in usd': [59683]}},
#  'World Cyber Arena/2016/Europe Main Qualifier': {'displaytitle': 'World Cyber Arena 2016 EU Main Qualifier',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2016/Europe Main Qualifier',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2016/Europe_Main_Qualifier',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/8/23',
#      'timestamp': '1471910400'}],
#    'Has end date': [{'raw': '1/2016/9/1', 'timestamp': '1472688000'}],
#    'Has leagueid': ['4525'],
#    'Has prizepool in usd': [54500]}},
#  'World Cyber Arena/2016/SEA Qualifiers/S1': {'displaytitle': 'World Cyber Arena 2016 SEA Qualifiers',
#   'exists': '1',
#   'fulltext': 'World Cyber Arena/2016/SEA Qualifiers/S1',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Arena/2016/SEA_Qualifiers/S1',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/4/29',
#      'timestamp': '1461888000'}],
#    'Has end date': [{'raw': '1/2016/5/21', 'timestamp': '1463788800'}],
#    'Has leagueid': ['4405'],
#    'Has prizepool in usd': [61108]}},
#  'World Cyber Games 2012': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'World Cyber Games 2012',
#   'fullurl': 'http://liquipedia.net/dota2/World_Cyber_Games_2012',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2012/11/29',
#      'timestamp': '1354147200'}],
#    'Has end date': [{'raw': '1/2012/12/2', 'timestamp': '1354406400'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [33000]}},
#  'World E-sport Championships 2014': {'displaytitle': '',
#   'exists': '1',
#   'fulltext': 'World E-sport Championships 2014',
#   'fullurl': 'http://liquipedia.net/dota2/World_E-sport_Championships_2014',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2014/9/5', 'timestamp': '1409875200'}],
#    'Has end date': [{'raw': '1/2014/9/7', 'timestamp': '1410048000'}],
#    'Has leagueid': ['1663'],
#    'Has prizepool in usd': [166942.4]}},
#  'World Electronic Sports Games/2016': {'displaytitle': 'World Electronic Sports Games 2016',
#   'exists': '1',
#   'fulltext': 'World Electronic Sports Games/2016',
#   'fullurl': 'http://liquipedia.net/dota2/World_Electronic_Sports_Games/2016',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/1/12',
#      'timestamp': '1484179200'}],
#    'Has end date': [{'raw': '1/2017/1/15', 'timestamp': '1484438400'}],
#    'Has leagueid': ['4916'],
#    'Has prizepool in usd': [1500000]}},
#  'World Electronic Sports Games/2016/Americas': {'displaytitle': 'World Electronic Sports Games 2016 Americas Finals',
#   'exists': '1',
#   'fulltext': 'World Electronic Sports Games/2016/Americas',
#   'fullurl': 'http://liquipedia.net/dota2/World_Electronic_Sports_Games/2016/Americas',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/10/21',
#      'timestamp': '1477008000'}],
#    'Has end date': [{'raw': '1/2016/10/23', 'timestamp': '1477180800'}],
#    'Has leagueid': ['4972'],
#    'Has prizepool in usd': [73918.5713]}},
#  'World Electronic Sports Games/2016/Asia Pacific': {'displaytitle': 'World Electronic Sports Games 2016 Asia Pacific Finals',
#   'exists': '1',
#   'fulltext': 'World Electronic Sports Games/2016/Asia Pacific',
#   'fullurl': 'http://liquipedia.net/dota2/World_Electronic_Sports_Games/2016/Asia_Pacific',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/11/10',
#      'timestamp': '1478736000'}],
#    'Has end date': [{'raw': '1/2016/11/13', 'timestamp': '1478995200'}],
#    'Has leagueid': ['4972'],
#    'Has prizepool in usd': [73350]}},
#  'World Electronic Sports Games/2016/Europe CIS': {'displaytitle': 'World Electronic Sports Games 2016 Europe & CIS Finals',
#   'exists': '1',
#   'fulltext': 'World Electronic Sports Games/2016/Europe CIS',
#   'fullurl': 'http://liquipedia.net/dota2/World_Electronic_Sports_Games/2016/Europe_CIS',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/10/6',
#      'timestamp': '1475712000'}],
#    'Has end date': [{'raw': '1/2016/10/9', 'timestamp': '1475971200'}],
#    'Has leagueid': ['4972'],
#    'Has prizepool in usd': [74926]}},
#  'World Electronic Sports Games/2016/Middle East and Africa': {'displaytitle': 'World Electronic Sports Games 2016 Middle East & Africa Finals',
#   'exists': '1',
#   'fulltext': 'World Electronic Sports Games/2016/Middle East and Africa',
#   'fullurl': 'http://liquipedia.net/dota2/World_Electronic_Sports_Games/2016/Middle_East_and_Africa',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2016/8/26',
#      'timestamp': '1472169600'}],
#    'Has end date': [{'raw': '1/2016/8/28', 'timestamp': '1472342400'}],
#    'Has leagueid': [],
#    'Has prizepool in usd': [74910]}},
#  'ZOTAC Cup/Masters': {'displaytitle': 'ZOTAC Cup Masters',
#   'exists': '1',
#   'fulltext': 'ZOTAC Cup/Masters',
#   'fullurl': 'http://liquipedia.net/dota2/ZOTAC_Cup/Masters',
#   'namespace': 0,
#   'printouts': {'Has date': [{'raw': '1/2017/5/30',
#      'timestamp': '1496102400'}],
#    'Has end date': [{'raw': '1/2017/6/3', 'timestamp': '1496448000'}],
#    'Has leagueid': ['5396'],
#    'Has prizepool in usd': [100000]}}}

# %%
json.get('query').get('results')['ProDOTA2 League/Season 1/Pro'].get('displaytitle')
# Out:
# 'Prodota 2 Worldwide League'

# %%
for lname, ldata in json.get('query').get('results').items():
    po = ldata.get('printouts')
    outer = po.get('Has leagueid')
    name = ldata.get('displaytitle')
    if outer:
        link = ldata.get('fullurl')
        try:
            pzus = po.get('Has prizepool in usd')[0]
        except IndexError:
            pzus = 'Nan'
        start = datetime.datetime.fromtimestamp(int(po.get('Has date')[0].get('timestamp'))).strftime('%d/%m/%Y')
        end = datetime.datetime.fromtimestamp(int(po.get('Has end date')[0].get('timestamp'))).strftime('%d/%m/%Y')
        df = df.append({'link': link, 'tour': name if name != '' else lname, 'start': pd.to_datetime(start), 'end': pd.to_datetime(end), 'prize': pzus}, ignore_index=True)

# %%
df
# Out:
#                                                   link  \
# 0    http://liquipedia.net/dota2/ProDOTA2_League/Se...
# 1    http://liquipedia.net/dota2/StarLadder/StarSer...
# 2     http://liquipedia.net/dota2/The_Defense/Season_2
# 3    http://liquipedia.net/dota2/The_International/...
# 4    http://liquipedia.net/dota2/RaidCall_Dota_2_Le...
# 5    http://liquipedia.net/dota2/StarLadder/StarSer...
# 6    http://liquipedia.net/dota2/GosuLeague/4/Divis...
# 7    http://liquipedia.net/dota2/The_Premier_League...
# 8    http://liquipedia.net/dota2/G-1_Champions_Leag...
# 9    http://liquipedia.net/dota2/GosuLeague/5/Divis...
# 10   http://liquipedia.net/dota2/StarLadder/StarSer...
# 11   http://liquipedia.net/dota2/DreamHack/2012/Winter
# 12    http://liquipedia.net/dota2/The_Defense/Season_3
# 13   http://liquipedia.net/dota2/RaidCall_Dota_2_Le...
# 14           http://liquipedia.net/dota2/The_Asia_2012
# 15   http://liquipedia.net/dota2/G-League_2012_Seas...
# 16   http://liquipedia.net/dota2/The_Premier_League...
# 17   http://liquipedia.net/dota2/StarLadder/StarSer...
# 18   http://liquipedia.net/dota2/Armaggeddon_Dota_2...
# 19   http://liquipedia.net/dota2/WePlay_Dota2_Leagu...
# 20   http://liquipedia.net/dota2/DreamHack/2013/Inv...
# 21   http://liquipedia.net/dota2/G-1_Champions_Leag...
# 22   http://liquipedia.net/dota2/ESL_Major_Series_O...
# 23   http://liquipedia.net/dota2/Curse_Dota_2_Invit...
# 24   http://liquipedia.net/dota2/AMD_Premier_League...
# 25     http://liquipedia.net/dota2/Dota_2_Super_League
# 26   http://liquipedia.net/dota2/Rapture_Gaming_Net...
# 27   http://liquipedia.net/dota2/StarLadder/StarSer...
# 28   http://liquipedia.net/dota2/The_Premier_League...
# 29   http://liquipedia.net/dota2/RaidCall_Dota_2_Le...
# ..                                                 ...
# 211  http://liquipedia.net/dota2/The_Masters/2017/M...
# 212  http://liquipedia.net/dota2/DreamLeague/Season...
# 213      http://liquipedia.net/dota2/ZOTAC_Cup/Masters
# 214         http://liquipedia.net/dota2/EPICENTER/2017
# 215           http://liquipedia.net/dota2/The_Summit/7
# 216       http://liquipedia.net/dota2/Galaxy_Battles/1
# 217  http://liquipedia.net/dota2/Mars_Dota_2_League...
# 218  http://liquipedia.net/dota2/The_Final_Match/Se...
# 219   http://liquipedia.net/dota2/DreamLeague/Season_7
# 220  http://liquipedia.net/dota2/The_International/...
# 221  http://liquipedia.net/dota2/Dota2_Professional...
# 222  http://liquipedia.net/dota2/StarLadder/i-Leagu...
# 223  http://liquipedia.net/dota2/PGL_Open/Bucharest...
# 224   http://liquipedia.net/dota2/ESL_One/Hamburg/2017
# 225  http://liquipedia.net/dota2/Dota_Pit_League/Se...
# 226  http://liquipedia.net/dota2/Perfect_World_Mast...
# 227  http://liquipedia.net/dota2/Adrenaline_Cyber_L...
# 228   http://liquipedia.net/dota2/DreamLeague/Season_8
# 229       http://liquipedia.net/dota2/ROG_MASTERS/2017
# 230  http://liquipedia.net/dota2/Mars_Dota_2_League...
# 231           http://liquipedia.net/dota2/The_Summit/8
# 232       http://liquipedia.net/dota2/Captains_Draft/4
# 233       http://liquipedia.net/dota2/Galaxy_Battles/2
# 234   http://liquipedia.net/dota2/ESL_One/Genting/2018
# 235  http://liquipedia.net/dota2/StarLadder/i-Leagu...
# 236  http://liquipedia.net/dota2/ESL_One/Katowice/2018
# 237  http://liquipedia.net/dota2/PGL/Bucharest_Majo...
# 238  http://liquipedia.net/dota2/GESC/Indonesia_Min...
# 239  http://liquipedia.net/dota2/Dota_2_Asia_Champi...
# 240         http://liquipedia.net/dota2/EPICENTER/2018
#
#                                                   tour      start        end  \
# 0                           Prodota 2 Worldwide League 2012-04-13 2012-05-08
# 1                       StarLadder StarSeries Season 2 2012-05-16 2012-07-15
# 2                                 The Defense Season 2 2012-06-21 2012-12-08
# 3                               The International 2012 2012-08-26 2012-02-09
# 4                      RaidCall Dota 2 League Season 1 2012-10-09 2012-11-18
# 5                       StarLadder StarSeries Season 3 2012-09-17 2012-10-21
# 6                       GosuLeague Season 4 Division 1 2012-02-10 2012-10-28
# 7                          The Premier League Season 3 2012-03-10 2013-01-13
# 8                        G-1 Champions League Season 4 2012-10-22 2012-11-18
# 9                       GosuLeague Season 5 Division 1 2012-08-11 2012-12-22
# 10                      StarLadder StarSeries Season 4 2012-11-13 2012-12-23
# 11                               DreamHack Winter 2012 2012-11-22 2012-11-25
# 12                                The Defense Season 3 2012-11-26 2013-03-30
# 13                     RaidCall Dota 2 League Season 2 2012-12-12 2013-10-04
# 14                                       The Asia 2012 2012-12-22 2012-12-23
# 15                              G-League 2012 Season 2 2012-12-24 2013-09-03
# 16                         The Premier League Season 4 2013-10-02 2013-04-28
# 17                      StarLadder StarSeries Season 5 2013-11-02 2013-07-04
# 18             Armaggeddon Dota 2 Grand Slam Asia 2013 2013-07-03 2013-10-03
# 19                        WePlay Dota2 League Season 1 2013-09-03 2013-05-13
# 20                       DreamHack Dota 2 Invitational 2013-03-14 2013-04-18
# 21                       G-1 Champions League Season 5 2013-03-16 2013-05-26
# 22                      RaidCall EMS One Spring Season 2013-03-18 2013-04-21
# 23                           Curse Dota 2 Invitational 2013-04-05 2013-05-19
# 24                         AMD Premier League Season 1 2013-06-05 2013-05-15
# 25                                 Dota 2 Super League 2013-10-05 2013-06-07
# 26             Rapture Gaming Network League 2013/2014 2013-05-18 2013-08-12
# 27                      StarLadder StarSeries Season 6 2013-05-19 2013-07-07
# 28                         The Premier League Season 5 2013-05-20 2013-07-21
# 29                     RaidCall Dota 2 League Season 3 2013-05-20 2013-07-17
# ..                                                 ...        ...        ...
# 211                                 The Manila Masters 2017-05-25 2017-05-28
# 212                   DreamLeague Season 7 NA Division 2017-05-30 2017-05-31
# 213                                  ZOTAC Cup Masters 2017-05-30 2017-03-06
# 214                                     EPICENTER 2017 2017-04-06 2017-11-06
# 215                                      DOTA Summit 7 2017-06-14 2017-06-18
# 216                                     Galaxy Battles 2017-06-15 2017-06-18
# 217                            Mars Dota 2 League 2017 2017-05-07 2017-09-07
# 218                           The Final Match Season 1 2017-07-07 2017-09-07
# 219                               DreamLeague Season 7 2017-07-21 2017-07-22
# 220                             The International 2017 2017-02-08 2017-12-08
# 221  Dota2 Professional League Season 4 (2017 S2)- Top 2017-09-30 2017-12-11
# 222          StarLadder i-League Invitational Season 3 2017-12-10 2017-10-15
# 223                                 PGL Open Bucharest 2017-10-19 2017-10-22
# 224                               ESL One Hamburg 2017 2017-10-26 2017-10-29
# 225                       AMD SAPPHIRE Dota PIT League 2017-02-11 2017-05-11
# 226                              Perfect World Masters 2017-11-19 2017-11-26
# 227                            Adrenaline Cyber League 2017-11-21 2017-11-22
# 228                               DreamLeague Season 8 2017-01-12 2017-03-12
# 229                                   ROG MASTERS 2017 2017-07-12 2017-10-12
# 230                                          MDL Macau 2017-08-12 2017-10-12
# 231                                      DOTA Summit 8 2017-12-13 2017-12-17
# 232                                 Captains Draft 4.0 2018-04-01 2018-07-01
# 233                 Galaxy Battles II: Emerging Worlds 2018-01-19 2018-01-21
# 234                               ESL One Genting 2018 2018-01-23 2018-01-28
# 235          StarLadder i-League Invitational Season 4 2018-01-02 2018-04-02
# 236                              ESL One Katowice 2018 2018-02-20 2018-02-25
# 237                                The Bucharest Major 2018-04-03 2018-11-03
# 238                        GESC: Indonesia Dota2 Minor 2018-03-15 2018-03-18
# 239                     Dota 2 Asia Championships 2018 2018-03-30 2018-07-04
# 240                                       EPICENTER XL 2018-04-27 2018-06-05
#
#         prize
# 0       20000
# 1       15000
# 2       12291
# 3     1600000
# 4       10000
# 5       15000
# 6        5000
# 7        6000
# 8     52879.2
# 9        5000
# 10      15000
# 11      30198
# 12      20000
# 13      10000
# 14      30000
# 15      41834
# 16      10000
# 17      15000
# 18      22500
# 19       8700
# 20       6000
# 21      65156
# 22      35000
# 23      10000
# 24       5000
# 25     163050
# 26      15200
# 27      22500
# 28      15500
# 29      10000
# ..        ...
# 211    250000
# 212     12000
# 213    100000
# 214    500000
# 215    100000
# 216    150000
# 217    250000
# 218     50000
# 219    175000
# 220  24787916
# 221    143070
# 222    300000
# 223    300000
# 224   1000000
# 225    300000
# 226    300000
# 227    100000
# 228   1000000
# 229    235000
# 230    300000
# 231    300000
# 232    300000
# 233    500000
# 234    400000
# 235    300000
# 236   1000000
# 237   1000000
# 238    300000
# 239   1000000
# 240   1000000
#
# [241 rows x 5 columns]
