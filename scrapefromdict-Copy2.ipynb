# %%
from datetime import datetime
import requests
import numpy as np
import pandas as pd
import yaml
import re
from bs4 import BeautifulSoup
import wikitextparser as wtp
from ratelimit import rate_limited
from operator import *

def save_obj(obj, name ):
    import pickle
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
        
def load_obj(name ):
    import pickle
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
def parseSquad(tourdict):
    '''
    input: title of tournament
    output: dictionary of participants of that tournament
    '''
    json = tourdict['wikitext']
    wiki = json.get('parse').get('wikitext').get('*')
    wiki = re.sub('\n', '', wiki)
    parsed = wtp.parse(wiki)
    templates = parsed.templates
    squad = {}
    prize = {} 
    for t in templates:
        if str(t)[:12].lower() == '{{prize pool':
            for ar in t.arguments:
                if (str(ar)[:6] == '|place'):
                    place = ar.value
                if (str(ar)[:9] == '|usdprize'):
                    usdprize = ar.value 
            for ar in t.arguments:
                if str(ar)[1:] == ar.value:
                    teamshort = re.sub(r' ', '', ar.value)
                    try:
                        teamSim = teamEasy[teamshort]
                    except KeyError:
                        teamSim = teamshort
                    teamSim = re.sub(r'\W+|_', '', teamSim).lower()
                    prize[teamSim] = {}
                    prize[teamSim]['usdprize'] = usdprize
                    prize[teamSim]['place'] = place
        if str(t)[:11] == '{{TeamCard|':
            for ar in t.arguments:
                if (str(ar)[:5] == '|team'):
                    teamname = re.sub(r'\W+', '', ar.value).lower()
                    squad[teamname] = {}
                for i in range(1, 6):
                    if (str(ar)[:4] == '|p' + str(i) + '='): 
                        pid = re.sub(r'\W+', '', ar.value).lower()
                        try:
                            pid = AlternateIdDict[re.sub(r'\W+', '', ar.value).lower()]
                        except KeyError:
                            pid = re.sub(r'\W+', '', ar.value).lower()
                        squad[teamname]['pos' + str(i)] = re.sub(r'\W+', '', pid).lower()
                    if (str(ar)[:7] == '|p' + str(i) + 'link'):
                        squad[teamname]['pos' + str(i)] = squad[teamname]['pos' + str(i)] + ' haslink'
    return squad, prize

# %%
alltour = load_obj('/dict/touranddate')
comparedict = load_obj('/dict/lqtodat')
AlternateIdDict = load_obj('/dict/AlternateIdDict')
teamEasy = load_obj('/dict/teamEasy2')

# %%
tourdict = load_obj('forglicko/' + re.sub(r'\W+', '', 'Dota2 Professional League Season 2 - Secondary').lower() )
json = tourdict['wikitext']
wiki = json.get('parse').get('wikitext').get('*')
wiki = re.sub('\n', '', wiki)
parsed = wtp.parse(wiki)
templates = parsed.templates
squad, prize = parseSquad(tourdict)

# %%
teamEasy['forthedream'] = 'ftdcluba'

# %%
def getEloDict(tourdict):
    return (tourdict['startelodict'], tourdict['endelodict'])

# %%
re.sub(r'team', '', 'teamvgj') in 'vgjthunder'
# Out:
# True

# %%
def noTeam(text):
    return re.sub(r'team', '', text)

# %%
def compareAndPut(df, squad, prize, ifd, startelodict, endelodict):
    for lqn, pdc in squad.items():
        try:
            teamName = comparedict[lqn]
        except KeyError:
            teamName = lqn
        j = 0
        try:
            place = prize[teamName]['place']
            usdprize = prize[teamName]['usdprize']
        except KeyError:
            place = '0.00'
            usdprize = '0.00'
            for pk in prize.keys():
                if (pk in teamName) or (teamName in pk) or (noTeam(pk) in noTeam(teamName)) or (noTeam(teamName) in noTeam(pk)):
                    place = prize[pk]['place']
                    usdprize = prize[pk]['usdprize']
        for srt in startelodict:
            for ert in endelodict:
                if (teamName == re.sub(r'\W+', '', srt['teamName']).lower()) & (teamName == re.sub(r'\W+', '', ert['teamName']).lower()):
                    j += 1
                    for pos, id in pdc.items():
                        df = df.append({
                            'team': teamName,
                            'pos': pos,
                            'id': id,
                            'tour': ifd['title'],
                            'prizepool': ifd['prize'],
                            'place': place,
                            'prizeusd': usdprize,
                            'start': ifd['start'],
                            'end': ifd['end'],
                            'startelo': srt['elo64']['current'],
                            'startglicko2mu': srt['glicko2']['mu'],
                            'startglicko2phi': srt['glicko2']['phi'],
                            'startglicko2rating': srt['glicko2']['rating'],
                            'endelo': ert['elo64']['current'],
                            'endglicko2mu': ert['glicko2']['mu'],
                            'endglicko2phi': ert['glicko2']['phi'],
                            'endglicko2rating': ert['glicko2']['rating']
                        }, ignore_index=True)
        if j == 0:
            for pos, id in pdc.items():
                if id == '':
                    continue
                else:
                    df = df.append({
                        'team': teamName,
                        'pos': pos,
                        'id': id,
                        'tour': ifd['title'],
                        'prizepool': ifd['prize'],
                        'place': place,
                        'prizeusd': usdprize,
                        'start': ifd['start'],
                        'end': ifd['end'],
                        'startelo': np.nan,
                        'startglicko2mu': np.nan,
                        'startglicko2phi': np.nan,
                        'startglicko2rating': np.nan,
                        'endelo': np.nan,
                        'endglicko2mu': np.nan,
                        'endglicko2phi': np.nan,
                        'endglicko2rating': np.nan
                    }, ignore_index=True)
        
    return df

# %%
alltour = load_obj('/dict/touranddate')
comparedict = load_obj('/dict/lqtodat')
AlternateIdDict = load_obj('/dict/AlternateIdDict')
teamEasy = load_obj('/dict/teamEasy2')

# %%
endti2 = '2012-09-02'
endti7 = '2017-08-12'

# %%
# %%time
errortitle = []
df = pd.DataFrame(columns=['team', 'pos', 'id', 'tour', 'prizepool', 'place', 'prizeusd', 'start', 'end',
                           'startelo', 'startglicko2mu', 'startglicko2phi', 'startglicko2rating', 'endelo', 'endglicko2mu', 'endglicko2phi', 'endglicko2rating'])
for turl, ifd in alltour.items():
    try:
        if (pd.to_datetime(ifd['start'], format='%d/%m/%Y') > pd.to_datetime(endti2)) & (pd.to_datetime(ifd['end'], format='%d/%m/%Y') <= pd.to_datetime(endti7)):
            try:
                tourdict = load_obj('forglicko/' + re.sub(r'\W+', '', ifd['title']).lower() )
            except:
                continue
            ptc, prz = parseSquad(tourdict)
            startelodict, endelodict = getEloDict(tourdict)
            df = compareAndPut(df, ptc, prz, ifd, startelodict, endelodict)
    except:
        print(turl)
        errortitle = errortitle.append(turl)
# Out:
# Wall time: 1min 36s

# %%
teamEasy
# Out:
# {'.aspera.': 'aspera',
#  '1stvn': '1stvn',
#  '3dclan': '3dclan',
#  '3dmax': '3dmax',
#  '4 friends + chrillee': '4friendschrillee',
#  '4anchorsseacaptain': '4anchorsseacaptain',
#  '4cloverlepricon': '4cloverlepricon',
#  '4fc': '4friendschrillee',
#  '4p5': '4protectfive',
#  '4vikingsdane': '4vikingsdane',
#  '5eva.': '5eva',
#  '5inq': '5inqo',
#  '5jungz': '5jungz',
#  '90s': '90sgaming',
#  '???': 'redefiningmadness',
#  'ASUS.polar': 'asuspolar',
#  'Fiskestanga': 'fiskestanga',
#  'Flip.sid3 Tactics': 'flipsid3tactics',
#  'MUFC': 'mufc',
#  'ROOT Gaming': 'rootgaming',
#  'Team Finland': 'finland',
#  'aaa': 'teamaaa',
#  'abc': 'applebananacucumber',
#  'absolutelegends': 'absolutelegends',
#  'aces': 'acesgaming',
#  'acionarena': 'acionarena',
#  'adfinem': 'adfinem',
#  'affection': 'affection',
#  'aftershock': 'aftershockgaming',
#  'ahead': 'aheadgaming',
#  'ahead.kz': 'aheadgaming',
#  'al': 'absolutelegends',
#  'alternate': 'alternateattax',
#  'ancientwarriors': 'ancientwarriors',
#  'animal kingdom': 'kingdomdota',
#  'anji': 'cyberanji',
#  'anzhi': 'cyberanji',
#  'apezone': 'apezone',
#  'arcade': 'arcadepowerrangers',
#  'arcade esports': 'arcadepowerrangers',
#  'arcade.power rangers': 'arcadepowerrangers',
#  'arcade.pr': 'arcadepowerrangers',
#  'arcanysgaming': 'arcanysgaming',
#  'archon': 'teamarchon',
#  'arrow': 'arrowgaming',
#  'artyk': 'artykgaming',
#  'as1': 'as1',
#  'ashock': 'aftershockgaming',
#  'astralauthority': 'astralauthority',
#  'asus': 'asuspolar',
#  'asus.polar': 'asuspolar',
#  'asuspolar': 'asuspolar',
#  'atn': 'alternateattax',
#  'avalon': 'avalonclub',
#  'avengers': 'avengers',
#  'awake': 'awake',
#  'aware': 'awaregaming',
#  'awesomegaming': 'awesomegaming',
#  'b)': 'bears',
#  'bad english': 'teambadenglish',
#  'baguette': 'baguette',
#  'balkanbears': 'balkanbears',
#  'balrogs': 'balrogs',
#  'banaaaanas': 'banaaaanas',
#  'bathroombuddies': 'bathroombuddies',
#  'battlezone': 'battlezone',
#  'bazaar': 'teambazaar',
#  'bazaar.youth': 'teambazaaryouth',
#  'bbc': 'balkanbears',
#  'bears': 'bears',
#  'betboys': 'betboys',
#  'bg': 'biggod',
#  'bheart': 'braveheart',
#  'bi': 'beyondinfinity',
#  'bminor': 'bminor',
#  'boom': 'boomid',
#  'boreal': 'borealesports',
#  'bravadogaming': 'bravadogaming',
#  'brm': 'bigredmachine',
#  'broodmothers': 'broodmothers',
#  'bulgaria': 'bulgaria',
#  'burden': 'burdenunited',
#  'bvm': 'bvm',
#  'c9': 'cloud9',
#  'cascade': 'cascade',
#  'cavalry': 'cavalry',
#  'cdec': 'cdecgaming',
#  'cdec avengers': 'cdecavenger',
#  'cdec gaming/cdec gaming': 'cdecgaming',
#  'cdec gaming/cdec.a': 'cdecavenger',
#  'cdec gaming/cdec.y': 'cdecyouth',
#  'cdec.a': 'cdecavenger',
#  'cdec.douyutv': 'cdecgaming',
#  'cdec.y': 'cdecyouth',
#  'cdec.youth': 'cdecyouth',
#  'cdec2': 'cdecgaming',
#  'cdecy': 'cdecyouth',
#  'cedenullis': 'cedenullis',
#  'cg': 'clutchgamers',
#  'chainsstack': 'chainsstack',
#  "champions of summer's rift": 'summersrift',
#  'chui niu bi': 'cnbcn',
#  'cis': 'cisgame',
#  'cisrejects': 'cisrejects',
#  'cleavegaming': 'cleavegaming',
#  'clg': 'counterlogicgaming',
#  'clgaming': 'counterlogicgaming',
#  'click': 'clicknsearch',
#  'cloud 9': 'cloud9',
#  'clutch': 'clutchgamers',
#  'cnbcn': 'cnbcn',
#  'cnbesportsclub': 'cnbesportsclub',
#  'coast': 'teamcoast',
#  'col': 'complexitygaming',
#  'comanche': 'comanche',
#  'complexity': 'complexitygaming',
#  'complexitygaming': 'complexitygaming',
#  'cookiss': 'cookiss',
#  'courage': 'couragegaming',
#  'crescendo': 'crescendo',
#  'cst': 'teamcoast',
#  'csw': 'cantsaywips',
#  'd5': 'dagonfive',
#  'darer': 'darer',
#  'darkhorse': 'darkhorse',
#  'db': 'danishbears',
#  'dc': 'digitalchaos',
#  'dc.sa': 'digitalchaossa',
#  'dddota': 'dddota',
#  'ddim': 'doubledimension',
#  'defiance': 'teamdefiance',
#  'denial': 'denialesports',
#  'denmark': 'denmark',
#  'detonator': 'detonator',
#  'dg': 'dreamgaming',
#  'digital chaos/digital chaos': 'digitalchaos',
#  'digital chaos/digital chaos.sa': 'digitalchaossa',
#  'digitalchaos': 'digitalchaos',
#  'dignitas': 'teamdignitas',
#  'dilecom': 'teamdilecom',
#  'dk': 'teamdk',
#  'dog': 'teamdog',
#  'doge': 'teamdoge',
#  'doowop': 'doowop',
#  'dotaallstars': 'dotaallstars',
#  'dragneel': 'dragneel',
#  'drak': 'drakdräpare',
#  'dream': 'dreamdestroyers',
#  'dreamtime': 'dtclub',
#  'drinking boys': 'drinkingboys',
#  'druidz': 'druidz',
#  'dt': 'dtclub',
#  'dt club': 'dtclub',
#  'dt168': 'dreamteam168',
#  'dts': 'dtsgaming',
#  'dts2010': 'dts2010',
#  'duza': 'duzagaming',
#  'dwaynethejohnrockson': 'dwaynethejohnrockson',
#  'e. wolves': 'elitewolves',
#  'echo': 'echogaming',
#  'echo international team': 'echointernational',
#  'echo.int': 'echointernational',
#  'eclipse': 'eclipseteam',
#  'eclypsia': 'eclypsia',
#  'eeriness': 'eeriness',
#  'effect': 'effect',
#  'eg': 'evilgeniuses',
#  'egamersx': 'egamersx',
#  'eh.kn': 'ehomekeen',
#  'eh.lm': 'ehomeluminous',
#  'ehome.cn': 'ehome',
#  'ehome.i': 'ehomeimmortal',
#  'ehome.k': 'ehomekeen',
#  'ehome.kn': 'ehomekeen',
#  'ehome.l': 'ehomeluminous',
#  'ehome.my': 'ehomemalaysia',
#  'ehome/ehome.cn': 'ehome',
#  'ehome/ehome.k': 'ehomekeen',
#  'ehome/ehome.keen': 'ehomekeen',
#  'ehome/ehome.l': 'ehomeluminous',
#  'ehome/ehome.luminous': 'ehomeluminous',
#  'ehome/ehome.my': 'ehomemalaysia',
#  'ehome/ehome.x': 'ehomex',
#  'ehomeorganization': 'ehomeorganization',
#  'ehug': 'teamehug',
#  'elab': 'elab',
#  'elements': 'elementspro',
#  'elements pro gaming': 'elementspro',
#  'elements pro gaming/elements one': 'elementsone',
#  'elements pro gaming/elements pro': 'elementspro',
#  'elementsprogaming': 'elementsprogaming',
#  'elementsprogamingelementsone': 'elementsprogamingelementsone',
#  'elementsprogamingelementspro': 'elementsprogamingelementspro',
#  'eleone': 'elementsone',
#  'elpride': 'lionspride',
#  'elysium': 'elysiumgaming',
#  'empire': 'teamempire',
#  'encoreesports': 'encoreesports',
#  'end': 'endteam',
#  'energy pacemaker gaming': 'energypacemaker',
#  'enso cybersport club': 'enso',
#  'entitygaming': 'entitygaming',
#  'eot': 'eyesoftiger',
#  'ep': 'energypacemaker',
#  'epg': 'elementspro',
#  'epidemic': 'epidemic',
#  'escape': 'escapegaming',
#  'estar': 'estar',
#  'eternitygaming': 'eternitygaming',
#  'everlast': 'everlastgamefilling',
#  'evernova/evernova': 'evernova',
#  'evernova/evernovas': 'evernovas',
#  'evernovaevernova': 'evernovaevernova',
#  'evernovaevernovas': 'evernovaevernovas',
#  'evilgeniuses': 'evilgeniuses',
#  'evos orig': 'evosesports',
#  'ewolves': 'elitewolves',
#  'execration/teamb esports': 'teambesports',
#  'exodus': 'exodus',
#  'experiencegaming': 'experiencegaming',
#  'f.3': 'flipsid3tactics',
#  'f3': 'flipsid3tactics',
#  'f5': 'fantasticfive',
#  'faceless': 'teamfaceless',
#  'fantastic five 2015': 'fantasticfive',
#  'fantuan': 'teamfantuan',
#  'fc anji': 'cyberanji',
#  'fc anzhi': 'cyberanji',
#  'fdl': 'fdl',
#  'ff2015': 'fantasticfive',
#  'fire': 'teamfire',
#  'firedragoon': 'firedragoon',
#  'firstdeparture': 'firstdeparture',
#  'fl': 'teamfaceless',
#  'flip.sid3 tactics': 'flipsid3tactics',
#  'flipsid3': 'flipsid3tactics',
#  'flipside': 'flipsid3tactics',
#  'flipside tactics': 'flipsid3tactics',
#  'flowgaming': 'flowgaming',
#  'fnatic.rs': 'fnatic',
#  'fnatic/fnatic': 'fnatic',
#  'fnatic/fnatic.na': 'fnaticna',
#  'fnatic/fnatic.rs': 'fnatic',
#  'fnc': 'fnatic',
#  'forlove': 'forlove',
#  'forthedream': 'ftdcluba',
#  'fou': 'forourutopia',
#  'france': 'france',
#  'freedom': 'teamfreedom',
#  'friends': 'friends',
#  'ftd': 'forthedream',
#  'ftd b': 'ftdclubb',
#  'ftd c': 'ftdclubc',
#  'ftd club a': 'forthedream',
#  'ftd club/for the dream': 'forthedream',
#  'ftd club/ftd club a': 'forthedream',
#  'ftd club/ftd club b': 'ftdclubb',
#  'ftd club/ftd club c': 'ftdclubc',
#  'ftd.a': 'forthedream',
#  'ftd.b': 'ftdclubb',
#  'ftd.c': 'ftdclubc',
#  'fureur': 'fureur',
#  'fxopen': 'fxopenesports',
#  'g guard': 'gguardesports',
#  'g3x': 'g3nerationx',
#  'g7': 'gse7en',
#  'gambit': 'gambitesports',
#  'gamesboardteam': 'gamesboardteam',
#  'gb': 'goldenboys',
#  'geek': 'geekfam',
#  'getouts': 'getouts',
#  'gguard': 'gguardesports',
#  'godbless': 'godbless',
#  'goingin': 'goingin',
#  'gol': 'gameonline',
#  'goldenboys': 'goldenboys',
#  'goomba': 'goombagaming',
#  'gplay': 'gplay',
#  'greece': 'greece',
#  'gu': 'gameruniversity',
#  'gus': 'gusgaming',
#  'h2k': 'h2kgaming',
#  'h2k gaming': 'h2kgaming',
#  'happyfeet': 'happyfeet',
#  "hard'n'play!": 'hardnplay',
#  'hardnplay': 'hardnplay',
#  'heart get together': 'hypergloryteam',
#  'hehe': 'heheunited',
#  'hellraisers`': 'hellraisers',
#  'hgt': 'hypergloryteam',
#  'hnp': 'hardnplay',
#  'hog': 'houseofgamers',
#  'horde': 'horde',
#  'hot6': 'mvphot6ix',
#  'hr': 'hellraisers',
#  'hwa': 'hwagaming',
#  'ic': 'iceclimbers',
#  'iccup': 'iccup',
#  'iceberg': 'icebergesports',
#  'idealesports': 'idealesports',
#  'ig': 'invictusgaming',
#  'ig v': 'igvitality',
#  'ig.v': 'igvitality',
#  'igv': 'igvitality',
#  'ikea': 'ikea',
#  'iluminate': 'iluminate',
#  'imagine': 'teamimagine',
#  'imbagaming': 'imbagaming',
#  'img': 'imaginarygaming',
#  'immortal magneto': 'immortalmagnetogaming',
#  'immunity': 'teamimmunity',
#  'imperial': 'theimperial',
#  'impervious': 'teamimpervious',
#  'imt': 'immortals',
#  'inf': 'infamous',
#  'infamousblack': 'infamousblack',
#  'infernity': 'infernitygaming',
#  'infernoesports': 'infernoesports',
#  'infinityvn': 'infinityvn',
#  'infused': 'teaminfused',
#  'ins': 'insightesports',
#  'insane': 'insanegaming',
#  'insidiousidol': 'insidiousidol',
#  'insight': 'insightesports',
#  'intzesports': 'intzesports',
#  'invasionesports': 'invasionesports',
#  'invictus': 'invictusgaming',
#  'invictus gaming/ig vitality': 'igvitality',
#  'invictus gaming/invictus gaming': 'invictusgaming',
#  'isgg': 'isgg',
#  'isurusgaming': 'isurusgaming',
#  "it's gosu": 'itsgosuesports',
#  'its gosu': 'itsgosuesports',
#  'itsgosu': 'itsgosuesports',
#  'january25th': 'january25th',
#  'joenet': 'joenet',
#  'k2apes': 'k2apes',
#  'kaipi': 'kaipi',
#  'kazakhstan': 'kazakhstan',
#  'keen': 'keengaming',
#  'keita': 'keitagaming',
#  'keyd': 'keydstars',
#  'kg.l': 'keengamingluminous',
#  'kingao4': 'kingao4',
#  'kingdom': 'kingdom',
#  'kinguin': 'teamkinguin',
#  'komanda minus': 'komandaminus',
#  'kompas': 'kompasgaming',
#  'lai': 'laigaming',
#  'lajons': 'lajons',
#  'lc': 'londonconspiracy',
#  'ldi': 'letsdoit',
#  'lediondreamz': 'lediondreamz',
#  'lemondogs': 'lemondogs',
#  'level up': 'lvlup',
#  'leviathan': 'teamleviathan',
#  'lfy': 'lgdforeveryoung',
#  'lgd': 'lgdgaming',
#  'lgd gaming/lgd gaming': 'lgdgaming',
#  'lgd gaming/lgd international': 'lgdinternational',
#  'lgd gaming/lgd.cdec': 'lgdcdec',
#  'lgd gaming/lgd.forever young': 'lgdforeveryoung',
#  'lgd gaming/lgd.taobao.cn': 'lgdgaming',
#  'lgd-gaming': 'lgdgaming',
#  'lgd.cn': 'lgdgaming',
#  'lgd.foreveryoung': 'lgdforeveryoung',
#  'lgd.fy': 'lgdforeveryoung',
#  'lgd.int': 'lgdinternational',
#  'lgd.international': 'lgdinternational',
#  'lgd.taobao.cn': 'lgdgaming',
#  'lianghao': 'lianghao',
#  'life': 'teamlife',
#  'life.': 'teamlife',
#  'liquid': 'teamliquid',
#  'lll': 'lowlandlions',
#  'london conspiracy dota2': 'londonconspiracy',
#  'londonconspiracy': 'londonconspiracy',
#  'lotem': 'lotem',
#  'lq': 'lq',
#  'luccini': 'luccini',
#  'lv': 'lvgaming',
#  'lvt': 'teamleviathan',
#  'm19': 'm19',
#  'm5': 'moscowfive',
#  'made in thailand': 'mith',
#  'madkings': 'madkings',
#  'madlads': 'madlads',
#  'mamasboys': 'mamasboys',
#  'max': 'teammax',
#  'max/max.x': 'maxx',
#  'max/max.y': 'maxy',
#  'max/team max': 'teammax',
#  'meepwnd': 'meepwnd',
#  'meetyourmakers': 'meetyourmakers',
#  'mementomori': 'mementomori',
#  'menace': 'teammenacefi',
#  'menace.fi': 'teammenacefi',
#  'mff': 'monkeyfreedomfighters',
#  'midas ce': 'midasclub',
#  'midas club elite': 'midasclub',
#  'midas club/midas club elite': 'midasclub',
#  'midas club/midas club victory': 'midasclubvictory',
#  'midas victory': 'midasclubvictory',
#  'midorfeed': 'midorfeed',
#  'mineski infinity': 'mineski',
#  'mineski x': 'mineskix',
#  'mineski.kor': 'mineskikorea',
#  'mineski.kr': 'mineskikorea',
#  'mineski/mineski': 'mineski',
#  'mineski/mineski-x': 'mineskix',
#  'mineski/mineski.korea': 'mineskikorea',
#  'mischief': 'teammischief',
#  'mith trust': 'mith',
#  'mith.trust': 'mith',
#  'mithtrust': 'mith',
#  'mobilitygaming': 'mobilitygaming',
#  'mongolz': 'themongolz',
#  'monibbaray': 'monibbaray',
#  'monkey business': 'monkeybusiness',
#  'monkey bzns': 'monkeybusiness',
#  'monkeyspanner': 'monkeyspanner',
#  'monomaniacesports': 'monomaniacesports',
#  'moscow 5': 'moscowfive',
#  'mouz': 'mousesports',
#  'msi': 'msievolutiongamingteam',
#  'msi evogt': 'msievolutiongamingteam',
#  'msi-evogt.tnc': 'msievolutiongamingteam',
#  'msievogt': 'msievolutiongamingteam',
#  'mski': 'mineski',
#  'mtw': 'mtw',
#  'muhan': 'teammuhan',
#  'mvp hot6': 'mvphot6ix',
#  'mvp.p': 'mvpphoenix',
#  'mvp.revolution': 'mvprevolution',
#  'mvp/mvp aegis': 'mvpaegis',
#  'mvp/mvp hot6ix': 'mvphot6ix',
#  'mvp/mvp phoenix': 'mvpphoenix',
#  'mvp/mvp revolution': 'mvprevolution',
#  'mvpa': 'mvpaegis',
#  'mvph': 'mvphot6ix',
#  'mvphot6': 'mvphot6ix',
#  'mvpp': 'mvpphoenix',
#  'mvpphoenix': 'mvpphoenix',
#  'mvpr': 'mvprevolution',
#  'my': 'teammalaysia',
#  'myi': 'myinsanity',
#  'myintent': 'myintent',
#  'mym': 'meetyourmakers',
#  'n9': 'natural9',
#  "na'vi north america": 'natusvincerenorthamerica',
#  "na'vi.us": 'natusvincerenorthamerica',
#  'na`vi north america': 'natusvincerenorthamerica',
#  'nan': 'nan',
#  'nar': 'northamericanrejects',
#  'nasnedogonyat': 'nasnedogonyat',
#  'natit': 'natitgaming',
#  'natus vincere/natus vincere': 'natusvincere',
#  'natus vincere/natus vincere ladies': 'natusvincereladies',
#  'natus vincere/natus vincere north america': 'natusvincerenorthamerica',
#  'natusvincere': 'natusvincere',
#  'navi': 'natusvincere',
#  'navi ladies': 'natusvincereladies',
#  'navius': 'natusvincerenorthamerica',
#  'nb': 'newbee',
#  'nbb': 'newbeeboss',
#  'nby': 'newbeeyoung',
#  'ne': 'newelement',
#  'neolution': 'neolutionesport',
#  'newbee.m': 'newbeemiracle',
#  'newbee.y': 'newbeeyoung',
#  'newbee/newbee': 'newbee',
#  'newbee/newbee boss': 'newbeeboss',
#  'newbee/newbee.m': 'newbeemiracle',
#  'newbee/newbee.y': 'newbeeyoung',
#  'newbeem': 'newbeemiracle',
#  'newbeey': 'newbeeyoung',
#  'newmeta': 'newmeta',
#  'nex': 'neximpetus',
#  'next': 'nextkz',
#  'next gen': 'nextgeneration',
#  'next kz': 'nextkz',
#  'nextkz': 'nextkz',
#  'nip': 'ninjasinpyjamas',
#  'nl5': 'nolifer5',
#  'nl5r': 'nolifer5reborn',
#  'nlg': 'nologicgaming',
#  'nme': 'enemy',
#  'no vaseline': 'novaseline',
#  'noa': 'noanswer',
#  'nodiggity': 'nodiggity',
#  'noearthspirit': 'noearthspirit',
#  'noobsfinest': 'noobsfinest',
#  'nottoday': 'nottoday',
#  'np': 'teamnp',
#  'nt123': 'newteam123123',
#  'nt123123': 'newteam123123',
#  'nth': 'notidehunter',
#  'nvidia aces gaming': 'acesgaming',
#  'nvmi': 'nvmi',
#  'og dota2': 'og',
#  'ok': 'onlinekingdom',
#  'oldboys': 'oldboys',
#  'onyx': 'teamonyx',
#  'opk': 'operationkino',
#  'optic': 'opticgaming',
#  'orange': 'orangeesports',
#  'orange esports/orange esports': 'orangeesports',
#  'orange esports/orange.taring': 'orangetaring',
#  'orangeesportsorangeesports': 'orangeesportsorangeesports',
#  'orangeesportsorangetaring': 'orangeesportsorangetaring',
#  'orenda': 'orenda',
#  'osiris': 'osirisgaming',
#  'oslik': 'oslikgaming',
#  'osliki gaming': 'oslikgaming',
#  'pacific': 'pacificesports',
#  'pain': 'paingaming',
#  'penta': 'pentasports',
#  'perky': 'perkypepperonis',
#  'pewpew': 'pewpewvietnam',
#  'pichau': 'pichau',
#  'planetdog': 'planetdog',
#  'planetodd': 'planetodd',
#  'pof': 'poweroffriendship',
#  'pokerface': 'pokerface',
#  'polarity': 'polarity',
#  'pomoika2team': 'pomoika2team',
#  'portugal': 'portugal',
#  'pota2': 'pota2',
#  'potm': 'potmbottom',
#  'power': 'powergaming',
#  'pr': 'powerrangers',
#  'pries': 'priesgaming',
#  'prime': 'theprime',
#  'princessjellopy': 'princessjellopy',
#  'prodota': 'prodotagaming',
#  'prodota.x': 'prodotagamingx',
#  'psn': 'poseidon',
#  'pulse': 'pulseesports',
#  'qpad': 'qpadredpandas',
#  'qpad dragons': 'qpadredpandas',
#  'qpad redpandas': 'qpadredpandas',
#  'quantic': 'quanticgaming',
#  'quanticgaming': 'quanticgaming',
#  'qxg': 'quanticgaming',
#  'r a v e': 'rave',
#  'rageesports': 'rageesports',
#  'random': 'teamrandom',
#  'reason': 'reasongaming',
#  'rebels': 'rebels',
#  'red team': 'teamred',
#  'redeem': 'teamredemption',
#  'redemption': 'teamredemption',
#  "relax, you're doing fine": 'relax',
#  'rem1kz': 'dontdierem1kz',
#  'retry': 'theretry',
#  'revenge': 'revengeesports',
#  'revival.ru': 'revivalgaming',
#  'rexregum': 'rexregum',
#  'ritd': 'ratinthedark',
#  'rittermoest': 'rittermoest',
#  'rize': 'rizegaming',
#  'rocketscientists': 'rocketscientists',
#  'romania': 'romania',
#  'romyandtherest': 'romyandtherest',
#  'root': 'rootgaming',
#  'rootgaming': 'rootgaming',
#  'rox.kis': 'rox',
#  'rsnake': 'rattlesnake',
#  'rstars': 'risingstars',
#  'russia': 'russia',
#  's1': 's1lykos',
#  'sabunwarrior': 'sabunwarrior',
#  'sacred': 'sacred',
#  'sadboys': 'sadboys',
#  'samurai': 'samuraichamploo',
#  'sanguinesharks': 'sanguinesharks',
#  'satuduatiga': 'teamsatuduatiga',
#  'scaryfacezzz': 'scaryfacez',
#  'scenario': 'scenario',
#  'sct': 'spaccreators',
#  'scythe': 'scythegaming',
#  'secret': 'teamsecret',
#  'secret team': 'teamsecret',
#  'sectorv': 'sectorv',
#  'seeyouagain': 'seeyouagain',
#  'semxorah': 'semxorah',
#  'sfte': 'sftesports',
#  'sfz': 'scaryfacez',
#  'sg': 'sgesports',
#  'sg esports': 'sgesports',
#  'sgc': 'stormgamesclan',
#  'sgrejects': 'sgrejects',
#  'shadows': 'shadowsofthepast',
#  'shazam': 'shazam',
#  'shz': 'svenhunterz',
#  'siberianvalenkiblack': 'siberianvalenkiblack',
#  'sig.trust': 'signaturetrust',
#  'sigma': 'sigma',
#  'signature': 'signaturetrust',
#  'singularity': 'singularityesports',
#  'sk': 'skgaming',
#  'skorokhod4': 'skorokhod4',
#  'skyred': 'skyred',
#  'skåneselit': 'skåneselit',
#  'slayersofgods': 'slayersofgods',
#  'sna': 'sneakynyxassassins',
#  'sng': 'singularityesports',
#  'soggymitts': 'soggymitts',
#  'solidudes': 'solidudes',
#  'somanymidases': 'somanymidases',
#  'space': 'space',
#  'spartak': 'spartakesports',
#  'specialreactionteam': 'specialreactionteam',
#  'speed': 'speedgamingcn',
#  'speed gaming': 'speedgamingcn',
#  'speed gaming/speed gaming.cn': 'speedgamingcn',
#  'speed gaming/speed gaming.int': 'speedgamingint',
#  'speed.cn': 'speedgamingcn',
#  'speed.int': 'speedgamingint',
#  'speedgaming': 'speedgaming',
#  'speedgamingspeedgamingcn': 'speedgamingspeedgamingcn',
#  'speedgamingspeedgamingint': 'speedgamingspeedgamingint',
#  'spg.cn': 'speedgamingcn',
#  'spg.int': 'speedgamingint',
#  'spiderpigzs': 'spiderpigzs',
#  'spirit': 'teamspirit',
#  'sqreen': 'sqreenssquad',
#  'stark esports': 'stark',
#  'stars': 'stars',
#  'starsboba': 'starsboba',
#  'startale': 'startale',
#  'stayfree': 'stayfree',
#  'steak': 'steakgaming',
#  'stratos': 'stratosesports',
#  'summers': 'summersrift',
#  'sun': 'sungaming',
#  'superstrongdinosaurs': 'superstrongdinosaurs',
#  'swag': 'prettyboyswag',
#  'swagen': 'swagenteiger',
#  't.o.t': 'tobeornottobe',
#  'ta': 'teamarchon',
#  'taco': 'tacolife',
#  'takefive': 'takefive',
#  'taring': 'taring',
#  'taskustitans': 'taskustitans',
#  'tbe': 'teambadenglish',
#  'tbirds': 'thunderbirds',
#  'tcm': 'tcmgaming',
#  'team 123': 'teamsatuduatiga',
#  'team alternate': 'alternateattax',
#  'team animal planet': 'animalplanet',
#  'team b': 'teambesports',
#  'team bazaar/team bazaar.youth': 'teambazaaryouth',
#  'team braveheart': 'braveheart',
#  'team dk/dk academy': 'dkacademy',
#  'team dk/dk renaissance': 'dkrenaissance',
#  'team dk/dk scuderia': 'dkscuderia',
#  'team dk/team dk': 'teamdk',
#  'team eclipse': 'eclipseteam',
#  'team finland': 'finland',
#  'team germany': 'germany',
#  'team peru': 'peru',
#  'team sweden': 'sweden',
#  'team vgj': 'vgjthunder',
#  'team zephyr': 'zephyr',
#  'team. spirit': 'teamspirit',
#  'teamadmiral': 'teamadmiral',
#  'teambadenglish': 'teambadenglish',
#  'teambazaarteambazaaryouth': 'teambazaarteambazaaryouth',
#  'teamdkdkacademy': 'teamdkdkacademy',
#  'teamdkdkrenaissance': 'teamdkdkrenaissance',
#  'teamdkdkscuderia': 'teamdkdkscuderia',
#  'teamdkteamdk': 'teamdkteamdk',
#  'teamflash': 'teamflash',
#  'teamgamersleague': 'teamgamersleague',
#  'teamimagine': 'teamimagine',
#  'teamkharkiv': 'teamkharkiv',
#  'teammy': 'teammalaysia',
#  'teamnp': 'teamnp',
#  'teamone': 'teamone',
#  'teampheonix': 'teampheonix',
#  'teamproperty': 'teamproperty',
#  'teamshakira': 'teamshakira',
#  'teamspirit': 'teamspirit',
#  'teamworld': 'teamworld',
#  'terrafirmaesports': 'terrafirmaesports',
#  'tft': 'thefinaltribe',
#  'thd': 'thehouseisdown',
#  'the alliance': 'alliance',
#  'the animal kingdom': 'kingdomdota',
#  'the balkan bears': 'balkanbears',
#  'theanimalkingdom': 'theanimalkingdom',
#  'theateam': 'theateam',
#  'thedire': 'thedire',
#  'thegdbteam': 'thegdbteam',
#  'thetoughbananas': 'thetoughbananas',
#  'thid': 'thehouseisdown',
#  'thunderawaken': 'thunderawaken',
#  'tinker': 'teamtinker',
#  'titan': 'titan',
#  'tl': 'teamliquid',
#  'tnc': 'tncproteam',
#  'tnc gaming': 'tncproteam',
#  'toast': 'teamtoast',
#  'tongfu.ob': 'oldboys',
#  'tongfu.wz': 'tongfuwanzhou',
#  'tongfu/tongfu': 'tongfu',
#  'tongfu/tongfu.na': 'tongfuna',
#  'tongfu/tongfu.wanzhou': 'tongfuwanzhou',
#  'tongfu2': 'tongfuwanzhou',
#  'tongfuna': 'tongfuna',
#  'tongfunexon': 'tongfunexon',
#  'tongfuwz': 'tongfuwanzhou',
#  'tpsiapa': 'theprime',
#  'trg': 'thunderobotgaming',
#  'trickedesport': 'trickedesport',
#  'tridentesports': 'tridentesports',
#  'tshow': 'tshow',
#  'tspirit': 'teamspirit',
#  'ttd': 'terribleterribledamage',
#  'tuho': 'tuho',
#  'turkey': 'turkey',
#  'turtle': 'turtlemasters',
#  'tyloo': 'tyloo',
#  'uebelstgamyng': 'uebelstgamyng',
#  'ug': 'uniongaming',
#  'ukraine': 'ukraine',
#  'underminer': 'underminer',
#  'underrateds': 'underrateds',
#  'union': 'uniongaming',
#  'uniongamingbo': 'uniongamingbo',
#  'unitedstates': 'unitedstates',
#  'unitedwestand': 'unitedwestand',
#  'unknown': 'basicallyunknown',
#  'unknownxiu': 'unknownxiu',
#  'valkyrie': 'valkyrieesports',
#  'vastcast': 'vastcast',
#  'vb': 'voidboys',
#  'vduobao': 'vduobao',
#  'vega': 'vegasquadron',
#  'vega squadron g2a': 'vegasquadron',
#  'vegasquadron': 'vegasquadron',
#  'vegetablesesportsclub': 'vegetablesesportsclub',
#  'vg': 'vicigaming',
#  'vg potential': 'vicigamingpotential',
#  'vg reborn': 'vicigamingreborn',
#  'vg.p': 'vicigamingpotential',
#  'vg.r': 'vicigamingreborn',
#  'vg.reborn': 'vicigamingreborn',
#  'vgj': 'vgjthunder',
#  'vgj thunder': 'vgjthunder',
#  'vgj.s': 'vgjstorm',
#  'vgj.t': 'vgjthunder',
#  'vgj/vgj thunder': 'vgjthunder',
#  'vgj/vgj.storm': 'vgjstorm',
#  'vgj/vgj.thunder': 'vgjthunder',
#  'vgp': 'vicigamingpotential',
#  'vgr': 'vicigamingreborn',
#  'vici': 'vicigaming',
#  'vici gaming.p': 'vicigamingpotential',
#  'vici gaming/team vgj': 'vgjthunder',
#  'vici gaming/vici gaming': 'vicigaming',
#  'vici gaming/vici gaming potential': 'vicigamingpotential',
#  'vici gaming/vici gaming reborn': 'vicigamingreborn',
#  'views6': 'views6',
#  'vinceteipsum': 'vinceteipsum',
#  'virtualthrone': 'virtualthrone',
#  'virtus': 'virtuspro',
#  'virtus pro': 'virtuspro',
#  'virtus pro polar': 'asuspolar',
#  'virtus.pro polar': 'asuspolar',
#  'virtus.pro/asus polar': 'asuspolar',
#  'virtus.pro/virtus.pro': 'virtuspro',
#  'virtus.pro/virtus.pro ladies': 'virtusproladies',
#  'virtus.pro/virtus.pro polar': 'asuspolar',
#  'virtuspro': 'virtuspro',
#  'virtusproorganization': 'virtusproorganization',
#  'vivacityesports': 'vivacityesports',
#  'vp': 'virtuspro',
#  'vp polar': 'asuspolar',
#  'vp.polar': 'asuspolar',
#  'vppolar': 'asuspolar',
#  'vti': 'vinceteipsum',
#  'vti gaming': 'vinceteipsum',
#  'vultur': 'vultur',
#  'walruspunchteam': 'walruspunchteam',
#  'wanted': 'wanted',
#  'warmaker': 'warmaker',
#  'warriors gaming.youth': 'warriorsgamingyouth',
#  'warriorsgaming.unity/warriorsgaming.youth': 'warriorsgamingyouth',
#  'way': 'weareyoung',
#  'wayyy': 'weareyoung',
#  'wazangchang': 'wazangchang',
#  'we': 'worldelite',
#  'wfg': 'whitefriesgaming',
#  'wg.u': 'warriorsgamingunity',
#  'wg.unity': 'warriorsgamingunity',
#  'wg.unity.youth': 'warriorsgamingyouth',
#  'wg.y': 'warriorsgamingyouth',
#  'wg.youth': 'warriorsgamingyouth',
#  'wha': 'wehazasian',
#  'whb': 'wildhoneybadgers',
#  'wheel': 'wheelwhreckwhilewhistling',
#  'white rabbit': 'whiterabbitgaming',
#  'who2bet': 'who2bet',
#  'wim': 'wheninmood',
#  'wings': 'wingsgaming',
#  'wings gaming/wings gaming': 'wingsgaming',
#  'wings gaming/wings.red': 'wingsred',
#  'wings.r': 'wingsred',
#  'wizardspriests': 'wizardspriests',
#  'wolves': 'copenhagenwolves',
#  'wonder wolves': 'wonderwolfs',
#  'wpcteama': 'wpcteama',
#  'wrg': 'whiterabbitgaming',
#  'ww': 'westernwolves',
#  'wwww': 'wheelwhreckwhilewhistling',
#  'xctn': 'execration',
#  'xdoto': 'xdoto',
#  'xdotored': 'xdotored',
#  'xgame': 'xgamekz',
#  'xtremexpcinternational': 'xtremexpcinternational',
#  'xx5gaming': 'xx5gaming',
#  'yb': 'youboat',
#  'yellow submar1ne': 'yellowsubmarine',
#  'yes': 'yellowsubmarine',
#  'yp': 'teamyp',
#  'ysb': 'yellowsubmarine',
#  'ysub': 'yellowsubmarine',
#  'zenith': 'teamzenith',
#  'zero': 'teamzero',
#  'znation': 'znation',
#  'zr': 'zerorespect'}

# %%
len(df[df['place'] == '0.00'].team.unique())
# Out:
# 90

# %%
df[df['place'] == '0.00'][df[df['place'] == '0.00'].startelo.notnull()].drop_duplicates(['team', 'tour'])
# Out:
#                        team   pos             id  \
# 105         absolutelegends  pos1     comewithme
# 1946          quanticgaming  pos1          paris
# 1971               alliance  pos1           loda
# 1981       4friendschrillee  pos1       strangby
# 3451   superstrongdinosaurs  pos1       sneyking
# 3626         firstdeparture  pos1         chibix
# 5276             mvpphoenix  pos1  march haslink
# 5281                cisgame  pos1          black
# 5331              virtuspro  pos1        illidan
# 5866             teamempire  pos1         silent
# 5881                xgamekz  pos1         mantis
# 5916       complexitygaming  pos1        melonzz
# 5921     sneakynyxassassins  pos1             tc
# 5926         invictusgaming  pos1            luo
# 5931              lgdgaming  pos1          sylar
# 5936                   rave  pos1           jeyo
# 6846               alliance  pos1           loda
# 6871         invictusgaming  pos1        burning
# 6876                  ehome  pos1            end
# 6881                 newbee  pos1         rabbit
# 6891              lgdgaming  pos1          sylar
# 6896         hypergloryteam  pos1           zsmj
# 6906             cdecgaming  pos1       agressif
# 6911           natusvincere  pos1          xboct
# 6921          _powerrangers  pos1        dityara
# 7696             teamarchon  pos1            ush
# 7706           vegasquadron  pos2  noone haslink
# 7861              virtuspro  pos1        illidan
# 7866        ninjasinpyjamas  pos1            era
# 9101               ftdcluba  pos1        destiny
# 9346                 fnatic  pos1          mushi
# 9691               ftdcluba  pos1            yin
# 9886            avalon_club  pos1            杀戮秀
# 9926               ftdcluba  pos1           xinq
# 10091        execration安博电竞  pos1          nando
# 10141      complexitygaming  pos1        chessie
# 10281                    og  pos1
# 10286              alliance  pos1
# 10321              ftdcluba  pos1           xinq
# 10676              ftdcluba  pos1           xinq
# 10751               teamvgj  pos1       agressif
# 11451               teamvgj  pos1       agressif
# 11476               teamvgj  pos1       agressif
# 6896       36.736982       1691.496772
# 6906       36.999634       1696.777374
# 6911       41.768560       1663.491102
# 6921       39.376968       1591.594684
# 7696       57.194982       1596.657679
# 7706       42.898940       1693.637712
# 7861       46.556197       1745.098764
# 7866       47.106613       1662.879555
# 9101       49.916515       1415.948057
# 9346       42.403492       1818.513042
# 9691       50.689865       1410.090899
# 9886       65.459475       1305.266869
# 9926       50.191870       1607.757879
# 10091      41.629591       1617.470631
# 10141      44.024623       1684.729979
# 10281      43.693470       1881.199272
# 10286      47.813481       1754.805480
# 10321      66.902503       1574.182835
# 10676      68.525013       1570.126558
# 10751      45.162854       1655.568156
# 11451      55.935195       1628.637305
# 11476      61.499460       1614.726642
# 11571      46.825247       1794.721217
# 11741      63.245522       1610.361486
# 11891      66.600459       1601.974144
# 12111      48.319402       1715.333100

# %%
teamEasy['fnatic'] = 'fnaticeu'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-00ae82e890a1> in <module>()
# ----> 1 teamEasy['fnatic']
#
# KeyError: 'fnatic'

# %%
len(teamEasy)
# Out:
# 833

# %%
ptc
# Out:
# {'hellraisers': {'pos1': 'rmn',
#   'pos2': 'afoninje',
#   'pos3': 'gorec',
#   'pos4': 'goddam',
#   'pos5': 'dread'},
#  'invictusgaming': {'pos1': 'burning',
#   'pos2': 'ferrari_430',
#   'pos3': 'luo',
#   'pos4': 'chuan',
#   'pos5': 'faith'},
#  'summersrift': {'pos1': 'bananaslamjamma',
#   'pos2': 'brax',
#   'pos3': 'ixmike88',
#   'pos4': 'demon',
#   'pos5': 'whitebeard'},
#  'teammalaysia': {'pos1': 'kyxy',
#   'pos2': 'kecikimba',
#   'pos3': 'ohaiyo',
#   'pos4': 'johnny',
#   'pos5': 'mushi'},
#  'teamsecret': {'pos1': 'arteezy',
#   'pos2': 's4',
#   'pos3': 'zai',
#   'pos4': 'puppey',
#   'pos5': 'kuroky'}}

# %%
prz
# Out:
# {'hellraisers': {'place': '4', 'usdprize': '8,798'},
#  'invictusgaming': {'place': '2', 'usdprize': '25,239'},
#  'summersrift': {'place': '5', 'usdprize': '5,000'},
#  'teammalaysia': {'place': '3', 'usdprize': '10,697'},
#  'teamsecret': {'place': '1', 'usdprize': '38,561'}}

# %%
df
# Out:
#               team   pos               id  \
# 0     teammalaysia  pos1             kyxy
# 1     teammalaysia  pos2        kecikimba
# 2     teammalaysia  pos3           ohaiyo
# 3     teammalaysia  pos4           johnny
# 4     teammalaysia  pos5            mushi
# 5   invictusgaming  pos1          burning
# 6   invictusgaming  pos2      ferrari_430
# 7   invictusgaming  pos3              luo
# 8   invictusgaming  pos4            chuan
# 9   invictusgaming  pos5            faith
# 10     hellraisers  pos1              rmn
# 11     hellraisers  pos2         afoninje
# 12     hellraisers  pos3            gorec
# 13     hellraisers  pos4           goddam
# 14     hellraisers  pos5            dread
# 15      teamsecret  pos1          arteezy
# 16      teamsecret  pos2               s4
# 17      teamsecret  pos3              zai
# 18      teamsecret  pos4           puppey
# 19      teamsecret  pos5           kuroky
# 20     summersrift  pos1  bananaslamjamma
# 21     summersrift  pos2             brax
# 22     summersrift  pos3         ixmike88
# 23     summersrift  pos4            demon
# 17  10/05/2015  1261.828023     1998.434421        44.998455
# 18  10/05/2015  1261.828023     1998.434421        44.998455
# 19  10/05/2015  1261.828023     1998.434421        44.998455
# 20  10/05/2015          NaN             NaN              NaN
# 21  10/05/2015          NaN             NaN              NaN
# 22  10/05/2015          NaN             NaN              NaN
# 23  10/05/2015          NaN             NaN              NaN
# 24  10/05/2015          NaN             NaN              NaN
#
#     startglicko2rating       endelo  endglicko2mu  endglicko2phi  \
# 0          1737.209517  1086.465776   1877.482587      46.073665
# 1          1737.209517  1086.465776   1877.482587      46.073665
# 2          1737.209517  1086.465776   1877.482587      46.073665
# 3          1737.209517  1086.465776   1877.482587      46.073665
# 4          1737.209517  1086.465776   1877.482587      46.073665
# 5          1819.971339  1042.873249   1916.930558      35.472331
# 6          1819.971339  1042.873249   1916.930558      35.472331
# 7          1819.971339  1042.873249   1916.930558      35.472331
# 8          1819.971339  1042.873249   1916.930558      35.472331
# 9          1819.971339  1042.873249   1916.930558      35.472331
# 10                 NaN          NaN           NaN            NaN
# 11                 NaN          NaN           NaN            NaN
# 12                 NaN          NaN           NaN            NaN
# 13                 NaN          NaN           NaN            NaN
# 14                 NaN          NaN           NaN            NaN
# 15         1885.938285  1254.504563   1997.882142      45.765523
# 16         1885.938285  1254.504563   1997.882142      45.765523
# 17         1885.938285  1254.504563   1997.882142      45.765523
# 18         1885.938285  1254.504563   1997.882142      45.765523
# 19         1885.938285  1254.504563   1997.882142      45.765523
# 20                 NaN          NaN           NaN            NaN
# 21                 NaN          NaN           NaN            NaN
# 22                 NaN          NaN           NaN            NaN
# 23                 NaN          NaN           NaN            NaN
# 24                 NaN          NaN           NaN            NaN
#
#     endglicko2rating
# 0        1762.298425
# 1        1762.298425
# 2        1762.298425
# 3        1762.298425
# 4        1762.298425
# 5        1828.249730
# 6        1828.249730
# 7        1828.249730
# 8        1828.249730
# 9        1828.249730
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15       1883.468335
# 16       1883.468335
# 17       1883.468335
# 18       1883.468335
# 19       1883.468335
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN

# %% [markdown]
#     #Clean Data
#     df = df[df['id'] != '']
#     df.loc[(df['id'] == 'g haslink'), 'id'] = 'g'
#     df.loc[(df['id'] == 'noone haslink'), 'id'] = 'noone'
#     df.loc[(df['id'].str[:8] == 'paparazi'), 'id'] = 'paparazi'
#     df.pos = pd.to_numeric(df.pos.str[-1])

# %%
#    df[['team', 'pos', 'id', 'tour', 'prizeusd', 'start', 'startelo', 'end', 'endelo']].to_csv('elo.csv', encoding='utf-8', index=False)
df[['team', 'pos', 'id', 'tour', 'prizepool', 'place', 'prizeusd', 'start', 'startglicko2mu', 'startglicko2phi', 'startglicko2rating', 'end', 'endglicko2mu', 'endglicko2phi', 'endglicko2rating']].to_csv('glickoandprize.csv', encoding='utf-8', index=False)

# %%
df = df[df['id'] != '']
df.loc[(df['id'] == 'g haslink'), 'id'] = 'g'
df.loc[(df['id'] == 'noone haslink'), 'id'] = 'noone'
df.loc[(df['id'].str[:8] == 'paparazi'), 'id'] = 'paparazi'
df.pos = pd.to_numeric(df.pos.str[-1])
