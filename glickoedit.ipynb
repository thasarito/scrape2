# %%
from datetime import datetime
import requests
import numpy as np
import pandas as pd
import yaml
import re
from bs4 import BeautifulSoup
import wikitextparser as wtp
from ratelimit import rate_limited
from operator import *

def save_obj(obj, name ):
    import pickle
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
        
def load_obj(name ):
    import pickle
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
def dateToGlicko(startdate, enddate):
    stepo = (pd.to_datetime(startdate, format='%d/%m/%Y') - pd.to_datetime('1970-1-1')).total_seconds() * 1000
    enepo = (pd.to_datetime(enddate, format='%d/%m/%Y') - pd.to_datetime('1970-1-1')).total_seconds() * 1000
    glmo = 338400000
    week = 604800000
    two_hour = 7200000
    stgl = pd.to_datetime(stepo - (stepo % week) + (glmo) + two_hour, unit='ms', origin='unix')
    engl = pd.to_datetime(enepo - (enepo % week) + (glmo) + two_hour, unit='ms', origin='unix') if stgl != pd.to_datetime(enepo - (enepo % week) + (glmo) + two_hour, unit='ms', origin='unix') else pd.to_datetime(enepo - (enepo % week) + (glmo) + two_hour + week, unit='ms', origin='unix')                  
    return re.sub(r'(\d{4})-(\d{2})-(\d{2})', r'\3-\2-\1', str(stgl)[:10]), re.sub(r'(\d{4})-(\d{2})-(\d{2})', r'\3-\2-\1', str(engl)[:10])

# %%
def parseSquad(tourdict):
    '''
    input: title of tournament
    output: dictionary of participants of that tournament
    '''
    json = tourdict['wikitext']
    wiki = json.get('parse').get('wikitext').get('*')
    wiki = re.sub('\n', '', wiki)
    parsed = wtp.parse(wiki)
    templates = parsed.templates
    squad = {}
    for t in templates:
        if str(t)[:11] == '{{TeamCard|':
            for ar in t.arguments:
                if (str(ar)[:5] == '|team'):
                    teamname = re.sub(r'\W+', '', ar.value).lower()
                    squad[teamname] = {}
                for i in range(1, 6):
                    if (str(ar)[:4] == '|p' + str(i) + '='):
                        squad[teamname]['pos' + str(i)] = re.sub(r'\W+', '', ar.value).lower()  
    return squad, json

# %%
def getEloDict(ifd):
    '''
    receive infomation dictionary of tournament and
    return elodict
    '''
    start, end = dateToGlicko(ifd['start'], ifd['end'])
    #rating of startdate from datdota and turn into list of dict
    urldat = 'http://www.datdota.com/api/ratings?date=' + start
    htmldat = requests.get(urldat)
    htmldat.encoding = 'utf-8'
    elo = BeautifulSoup(htmldat.text, "lxml")
    elodict = yaml.load(elo.text)
    startelolist = elodict['data']   
    #rating of enddate from datdota and turn into list of dict
    urldat = 'http://www.datdota.com/api/ratings?date=' + end
    htmldat = requests.get(urldat)
    htmldat.encoding = 'utf-8'
    elo = BeautifulSoup(htmldat.text, "lxml")
    elodict = yaml.load(elo.text)
    endelolist = elodict['data']
    return (startelolist, endelolist)

# %%
def compareAndPut(df, squad, ifd, startelodict, endelodict):
    for lqn, pdc in squad.items():
        try:
            teamName = comparedict[lqn]
        except KeyError:
            teamName = lqn
        j = 0
        for srt in startelodict:
            for ert in endelodict:
                if (teamName == re.sub(r'\W+', '', srt['teamName']).lower()) & (teamName == re.sub(r'\W+', '', ert['teamName']).lower()):
                    j += 1
                    for pos, id in pdc.items():
                        df = df.append({
                            'team': teamName,
                            'position': pos,
                            'id': id,
                            'tour': ifd['title'],
                            'prizeusd': ifd['prize'],
                            'start': ifd['start'],
                            'end': ifd['end'],
                            'startelo': srt['elo64']['current'],
                            'startglicko2mu': srt['glicko2']['mu'],
                            'startglicko2phi': srt['glicko2']['phi'],
                            'startglicko2rating': srt['glicko2']['rating'],
                            'endelo': ert['elo64']['current'],
                            'endglicko2mu': ert['glicko2']['mu'],
                            'endglicko2phi': ert['glicko2']['phi'],
                            'endglicko2rating': ert['glicko2']['rating']
                        }, ignore_index=True)
        if j == 0:
            for pos, id in pdc.items():
                if id == '':
                    continue
                else:
                    df = df.append({
                        'team': teamName,
                        'position': pos,
                        'id': id,
                        'tour': ifd['title'],
                        'prizeusd': ifd['prize'],
                        'start': ifd['start'],
                        'end': ifd['end'],
                        'startelo': np.nan,
                        'startglicko2mu': np.nan,
                        'startglicko2phi': np.nan,
                        'startglicko2rating': np.nan,
                        'endelo': np.nan,
                        'endglicko2mu': np.nan,
                        'endglicko2phi': np.nan,
                        'endglicko2rating': np.nan
                    }, ignore_index=True)
        
    return df

# %%
alltour = load_obj('/dict/touranddate')
comparedict = load_obj('/dict/lqtodat')

# %%
endti2 = '2012-09-02'
endti7 = '2017-08-12'

# %%
# %%time
errortitle = []
df = pd.DataFrame(columns=['team', 'position', 'id', 'tour', 'prizeusd', 'start', 'end',
                           'startelo', 'startglicko2mu', 'startglicko2phi', 'startglicko2rating', 'endelo', 'endglicko2mu', 'endglicko2phi', 'endglicko2rating'])
for turl, ifd in alltour.items():
    try:
        if (pd.to_datetime(ifd['start'], format='%d/%m/%Y') > pd.to_datetime(endti2)) & (pd.to_datetime(ifd['end'], format='%d/%m/%Y') <= pd.to_datetime(endti7)):
            try:
                tourdict = load_obj('old/' + re.sub(r'\W+', '', ifd['title']).lower() )
                print ('Succesfully Loaded: ' + ifd['title'])
            except FileNotFoundError:
                print ('already glickod: ' + ifd['title'])
                continue
            except NameError:
                continue
            ptc, lqjson = parseSquad(tourdict)
            startelodict, endelodict = getEloDict(ifd)
            save_obj({'wikitext': lqjson, 'startelodict': startelodict, 'endelodict': endelodict}, re.sub(r'\W+', '', ifd['title']).lower() )
            df = compareAndPut(df, ptc, ifd, startelodict, endelodict)
    except:
        continue
# Out:
# Succesfully Loaded: WCG Asian Championship 2012
# Succesfully Loaded: RaidCall Dota 2 League Season 1
# Succesfully Loaded: StarLadder StarSeries Season 3
# Succesfully Loaded: GosuLeague Season 4
# Succesfully Loaded: GosuLeague Season 4 Division 1
# Succesfully Loaded: The Premier League Season 3
# Succesfully Loaded: G-1 Champions League Season 4
# Succesfully Loaded: Electronic Sports World Cup 2012
# Succesfully Loaded: GosuLeague Season 5
# Succesfully Loaded: GosuLeague Season 5 Division 1
# Succesfully Loaded: StarLadder StarSeries Season 4
# Succesfully Loaded: DreamHack Winter 2012
# Succesfully Loaded: The Defense Season 3
# Succesfully Loaded: World Cyber Games 2012
# Succesfully Loaded: Thor Open 2012
# Succesfully Loaded: RaidCall Dota 2 League Season 2
# Succesfully Loaded: ASUS Open 2012 Finals
# Succesfully Loaded: The Asia 2012
# Succesfully Loaded: G-League 2012 Season 2
# Succesfully Loaded: The Premier League Season 4
# Succesfully Loaded: StarLadder StarSeries Season 5
# Succesfully Loaded: Armaggeddon Dota 2 Grand Slam Asia 2013
# Succesfully Loaded: WePlay Dota2 League Season 1
# Succesfully Loaded: DreamHack Dota 2 Invitational
# Succesfully Loaded: G-1 Champions League Season 5
# Succesfully Loaded: RaidCall EMS One Spring Season
# Succesfully Loaded: Ritmix Russian DOTA 2 League
# Succesfully Loaded: Techlabs Cup 2013 Season 1
# Succesfully Loaded: Curse Dota 2 Invitational
# Succesfully Loaded: AMD Premier League Season 1
# Succesfully Loaded: Dota 2 Super League
# Succesfully Loaded: Rapture Gaming Network League 2013/2014
# Succesfully Loaded: StarLadder StarSeries Season 6
# Succesfully Loaded: The Premier League Season 5
# Succesfully Loaded: RaidCall Dota 2 League Season 3
# Succesfully Loaded: The Defense Season 4
# Succesfully Loaded: American Dota League Season 1
# Succesfully Loaded: DreamHack Summer 2013
# Succesfully Loaded: Alienware Cup
# Succesfully Loaded: RaidCall EMS One Summer Season
# Succesfully Loaded: Corsair Gaming Summer Tournament 2013
# Succesfully Loaded: Nexon Starter League
# Succesfully Loaded: E2MAX L33t Championship
# Succesfully Loaded: Red Bull ECL 2013 Dota 2 Season
# Succesfully Loaded: AMD Premier League Season 2
# Succesfully Loaded: The International 2013
# Succesfully Loaded: The International 2013: Solo Tournament
# Succesfully Loaded: The International 2013: All-Star Match
# Succesfully Loaded: Techlabs Cup 2013 Season 2
# Succesfully Loaded: StarLadder StarSeries Season 7
# Succesfully Loaded: RaidCall EMS One Fall Season
# Succesfully Loaded: Sina Cup Supernova Dota 2 Open/Season 1
# Succesfully Loaded: WePlay Dota2 League Season 2
# Succesfully Loaded: 2013 WPC ACE Dota 2 League
# Succesfully Loaded: Techlabs Cup 2013 Season 3
# Succesfully Loaded: Nexon Sponsorship League Season 1
# Succesfully Loaded: Dota 2 Champions League Season 1
# Succesfully Loaded: MLG Fall Invitational
# Succesfully Loaded: Fragbite Masters 2013
# Succesfully Loaded: Electronic Sports World Cup 2013
# Succesfully Loaded: ASUS ROG DreamLeague Kick-Off Season
# Succesfully Loaded: National Electronic Sports Tournament 2013
# Succesfully Loaded: Techlabs Cup 2013 Grand Finals
# Succesfully Loaded: MLG Championship Columbus
# Succesfully Loaded: StarLadder StarSeries Season 8
# Succesfully Loaded: Sina Cup Supernova Dota 2 Open/Season 2
# Succesfully Loaded: Nexon Sponsorship League Season 2
# Succesfully Loaded: Netolic Pro League #4 West
# Succesfully Loaded: G-League 2013
# Succesfully Loaded: Fengyun Dota 2 Tournament
# Succesfully Loaded: Asian Cyber Games
# Succesfully Loaded: Red Bull ECL 2013 Grand Finals
# Succesfully Loaded: Pinnacle Sports Pro-Am
# Succesfully Loaded: Nexon Sponsorship League Season 3
# Succesfully Loaded: Dota 2 League Season 4
# Succesfully Loaded: Electronic Sports Prime Shock Therapy Cup
# Succesfully Loaded: MLG T.K.O. Europe
# Succesfully Loaded: MLG T.K.O. America
# Succesfully Loaded: Dota 2 Champions League Season 2
# Succesfully Loaded: Korean Dota League
# Succesfully Loaded: Korean Dota League - Tier 1
# Succesfully Loaded: XMG Captains Draft Invitational
# Succesfully Loaded: Netolic Pro League #5 East
# Succesfully Loaded: Sina Cup Supernova Dota 2 Open/Season 3
# Succesfully Loaded: ASUS ROG DreamLeague Season 1
# Succesfully Loaded: StarLadder StarSeries Season 9
# Succesfully Loaded: Monster Energy Invitational
# Succesfully Loaded: ECL 2014 Spring
# Succesfully Loaded: Excellent Moscow Cup Season 1
# Succesfully Loaded: WPC 2014
# Succesfully Loaded: HyperX D2L Western Challenge
# Succesfully Loaded: Fragbite Masters 2014
# Succesfully Loaded: Techlabs Cup 2014 Season 1
# Succesfully Loaded: American Dota League Season 2
# Succesfully Loaded: WVW National Electronic Sports Classic/April
# Succesfully Loaded: Dota 2 Champions League Season 3
# Succesfully Loaded: DreamHack Bucharest Invitational
# Succesfully Loaded: Korea Dota League Season 2
# Succesfully Loaded: Korea Dota League Season 2 - Tier 1
# Succesfully Loaded: MarsTV Dota 2 League 2014
# Succesfully Loaded: Techlabs Cup 2014 Season 2
# Succesfully Loaded: V Games Tournament
# Succesfully Loaded: CDEC New Star Challenge
# Succesfully Loaded: The Summit 1
# Succesfully Loaded: WVW National Electronic Sports Classic June
# Succesfully Loaded: GEST The Challenge June
# Succesfully Loaded: ESL One Frankfurt 2014
# Succesfully Loaded: The International 2014
# Succesfully Loaded: The International 2014: Solo Tournament
# Succesfully Loaded: Korea Dota League Season 3
# Succesfully Loaded: i-League Season 1
# Succesfully Loaded: StarLadder StarSeries Season 10
# Succesfully Loaded: Megafon Battle Arena
# Succesfully Loaded: Excellent Moscow Cup Season 2
# Succesfully Loaded: Dota 2 Champions League Season 4
# Succesfully Loaded: World E-sport Championships 2014
# Succesfully Loaded: Sina Cup Supernova Dota 2 Open Season 5
# Succesfully Loaded: Game Show League Season 1
# Succesfully Loaded: ECL 2014 Autumn
# Succesfully Loaded: IeSF Asian Championships
# Succesfully Loaded: NVIDIA Game 24
# Succesfully Loaded: Dota Pit League Season 2
# Succesfully Loaded: Synergy League Season 1
# Succesfully Loaded: World Cyber Arena 2014
# Succesfully Loaded: ASUS ROG DreamLeague Season 2
# Succesfully Loaded: Brasil Game Cup 2014
# Succesfully Loaded: ESL One New York 2014
# Succesfully Loaded: G-League 2014
# Succesfully Loaded: Korea Dota League Season 4
# Succesfully Loaded: National Electronic Sports Tournament 2014
# Succesfully Loaded: XMG Captains Draft 2.0
# Succesfully Loaded: MSI Beat IT 2014
# Succesfully Loaded: Battle of Central Europe Season 3
# Succesfully Loaded: IeSF 2014 World Championship
# Succesfully Loaded: StarLadder StarSeries Season 11
# Succesfully Loaded: i-League Season 2
# Succesfully Loaded: Esportal Dota 2 League
# Succesfully Loaded: The Summit 2
# Succesfully Loaded: National Electronic Sports Open 2014
# Succesfully Loaded: Esportal Dota 2 League Invitational Tournament 1
# Succesfully Loaded: OK.- Dota 2 Cup
# Succesfully Loaded: Dota 2 League Season 5
# Succesfully Loaded: Dota Pit League Season 3
# Succesfully Loaded: joinDOTA MLG Pro League Season 1
# Succesfully Loaded: Dota 2 Asia Championships 2015
# Succesfully Loaded: Dota 2 Champions League Season 5
# Succesfully Loaded: StarLadder StarSeries Season 12
# Succesfully Loaded: Major All Stars Dota 2 Tournament
# Succesfully Loaded: ASUS ROG DreamLeague Season 3
# Succesfully Loaded: i-League Season 3
# Succesfully Loaded: 2015 Red Bull Battle Grounds: Dota 2
# Succesfully Loaded: VPGame Pro League Season 1
# Succesfully Loaded: ECL 2015 Spring
# Succesfully Loaded: World Cyber Arena 2015 - Chinese Pro Qualifiers
# Succesfully Loaded: joinDOTA MLG Pro League Season 2
# Succesfully Loaded: RoG Play It Cool Dota 2 Invitational
# Succesfully Loaded: World Cyber Arena 2015 - American Pro Qualifiers
# Succesfully Loaded: MarsTV Dota 2 League 2015 Spring - Chinese League
# Succesfully Loaded: MPGL/Season 7/SEA
# Succesfully Loaded: G-League 2015
# Succesfully Loaded: The Summit 3
# Succesfully Loaded: MarsTV Dota 2 League 2015 Spring
# Succesfully Loaded: ESL One Frankfurt 2015
# Succesfully Loaded: VIP LAN CENTER
# Succesfully Loaded: The International 2015
# Succesfully Loaded: The Defense Season 5
# Succesfully Loaded: Gaming Paradise 2015
# Succesfully Loaded: Dota 2 Champions League Season 6
# Succesfully Loaded: World Cyber Arena 2015 - European Pro Qualifiers
# Succesfully Loaded: ASUS ROG DreamLeague Season 4
# Succesfully Loaded: ESL One New York 2015
# Succesfully Loaded: World Cyber Arena 2015 - SEA Pro Qualifiers
# Succesfully Loaded: MLG World Finals 2015
# Succesfully Loaded: ECL 2015 Autumn
# Succesfully Loaded: Nanyang Dota 2 Championships Season 1
# Succesfully Loaded: PGL Dota 2 Pro-AM
# Succesfully Loaded: Dota2 Battle Arena
# Succesfully Loaded: Frankfurt Major 2015
# Succesfully Loaded: Dota 2 Canada Cup Season 6
# Succesfully Loaded: Game Show Global eSports Cup Season 1
# Succesfully Loaded: Dota 2 Champions League Christmas Charity Magic
# Succesfully Loaded: The Summit 4
# Succesfully Loaded: World Cyber Arena 2015
# Succesfully Loaded: Dota 2 Radiant & Dire Cup 2015
# Succesfully Loaded: Shanghai Dota 2 Open #1
# Succesfully Loaded: SL i-League StarSeries Season 1
# Succesfully Loaded: Captains Draft 3.0
# Succesfully Loaded: MarsTV Dota 2 League 2015 Winter
# Succesfully Loaded: The Shanghai Major 2016
# Succesfully Loaded: Dota Pit League Season 4
# Succesfully Loaded: World Cyber Arena 2016 Chinese Qualifiers S1
# Succesfully Loaded: Russian e-Sports Cup 2016
# Succesfully Loaded: StarLadder i-League Invitational Season 1
# Succesfully Loaded: ESL One Manila 2016
# Succesfully Loaded: WePlay Dota2 League Season 3
# Succesfully Loaded: World Cyber Arena 2016 SEA Qualifiers
# Succesfully Loaded: EPICENTER 2016
# Succesfully Loaded: Dota2 Professional League Season 1
# Succesfully Loaded: DreamLeague Season 5
# Succesfully Loaded: The Manila Major 2016
# Succesfully Loaded: World Cyber Arena 2016 Chinese Qualifiers S2
# Succesfully Loaded: ESL One Frankfurt 2016
# Succesfully Loaded: G-League 2016
# Succesfully Loaded: National Electronic Arena 2016
# Succesfully Loaded: Global Grand Masters
# Succesfully Loaded: Nanyang Dota 2 Championships Season 2
# Succesfully Loaded: The Summit 5
# Succesfully Loaded: VPGame Pro League Season 2
# Succesfully Loaded: SL i-League StarSeries Season 2
# Succesfully Loaded: Pro Gamer League 2016 (PGL 2016) - Summer
# Succesfully Loaded: The International 2016
# Succesfully Loaded: World Cyber Arena 2016 EU Main Qualifier
# Succesfully Loaded: World Electronic Sports Games 2016 Middle East & Africa Finals
# Succesfully Loaded: MPGL Southeast Asian Championship
# Succesfully Loaded: Red Bull Heroicks
# Succesfully Loaded: Dota2 Professional League Season 2 - Secondary
# Succesfully Loaded: Shanghai Dota 2 Open #2
# Succesfully Loaded: Dota2 Professional League Season 2 - Top
# Succesfully Loaded: Mars Dota 2 League 2016 Autumn
# Succesfully Loaded: World Cyber Arena 2016 Chinese Qualifiers S3
# Succesfully Loaded: World Electronic Sports Games 2016 Europe & CIS Finals
# Succesfully Loaded: DreamLeague Season 6 League Play
# Succesfully Loaded: Nanyang Dota 2 Championships  - Cruise Cup #1
# Succesfully Loaded: Dota2 ACE - Provisional
# Succesfully Loaded: FACEIT Invitational
# Succesfully Loaded: World Electronic Sports Games 2016 Americas Finals
# Succesfully Loaded: ROG MASTERS 2016
# Succesfully Loaded: Northern Arena BEAT Invitational
# Succesfully Loaded: World Electronic Sports Games 2016 Asia Pacific Finals
# Succesfully Loaded: World Cyber Arena 2016 AM Qualifiers
# Succesfully Loaded: The Summit 6
# Succesfully Loaded: ASUS ROG DreamLeague Season 6
# Succesfully Loaded: The Boston Major 2016
# Succesfully Loaded: World Cyber Arena 2016
# Succesfully Loaded: China Top 2016
# Succesfully Loaded: ESL One Genting 2017
# Succesfully Loaded: World Electronic Sports Games 2016
# Succesfully Loaded: Dota Pit League Season 5
# Succesfully Loaded: Elimination Mode 3.0
# Succesfully Loaded: StarLadder i-League StarSeries Season 3
# Succesfully Loaded: Dota2 Professional League Season 3 (2017 S1) - Top
# Succesfully Loaded: Dota 2 Asia Championships 2017
# Succesfully Loaded: Russian e-Sports Cup 2017
# Succesfully Loaded: The Kiev Major 2017
# Succesfully Loaded: Mr. Cat Invitational Europe
# Succesfully Loaded: DreamLeague Season 7 EU Division
# Succesfully Loaded: StarLadder i-League Invitational Season 2
# Succesfully Loaded: The Manila Masters
# Succesfully Loaded: DreamLeague Season 7 NA Division
# Succesfully Loaded: ZOTAC Cup Masters
# Succesfully Loaded: EPICENTER 2017
# Succesfully Loaded: DOTA Summit 7
# Succesfully Loaded: Galaxy Battles
# Succesfully Loaded: Mars Dota 2 League 2017
# Succesfully Loaded: The Final Match Season 1
# Succesfully Loaded: DreamLeague Season 7
# Succesfully Loaded: The International 2017
# Succesfully Loaded: The International 2017: Special Events
# Wall time: 17min 57s
